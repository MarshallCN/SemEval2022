# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install conllu
# Out:
# Collecting conllu
#   Downloading conllu-4.4.1-py2.py3-none-any.whl (15 kB)
# Installing collected packages: conllu
# Successfully installed conllu-4.4.1

# %%
pip install farm-haystack[faiss]
# Out:
# Collecting farm-haystack[faiss]
#   Downloading farm_haystack-1.2.0-py3-none-any.whl (430 kB)
#      |████████████████████████████████| 430 kB 17.0 MB/s
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 29.1 MB/s
# Collecting tika
#   Downloading tika-1.24.tar.gz (28 kB)
# Collecting mmh3
#   Downloading mmh3-3.0.0-cp37-cp37m-manylinux2010_x86_64.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.9 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (2.23.0)
# Collecting elasticsearch<=7.10,>=7.7
#   Downloading elasticsearch-7.10.0-py2.py3-none-any.whl (321 kB)
#      |████████████████████████████████| 321 kB 52.5 MB/s
# Collecting quantulum3
#   Downloading quantulum3-0.7.10-py3-none-any.whl (10.7 MB)
#      |████████████████████████████████| 10.7 MB 53.2 MB/s
# Requirement already satisfied: torch<1.11,>1.9 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (1.10.0+cu111)
# Collecting elastic-apm
#   Downloading elastic_apm-6.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (359 kB)
#      |████████████████████████████████| 359 kB 44.9 MB/s
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (2.6.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (4.11.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (1.3.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (4.62.3)
# Collecting sentence-transformers>=0.4.0
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 3.2 MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (3.2.5)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      |████████████████████████████████| 43 kB 1.1 MB/s
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (8.12.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (1.4.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (1.0.2)
# Collecting pydantic
#   Downloading pydantic-1.9.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.9 MB)
#      |████████████████████████████████| 10.9 MB 33.9 MB/s
# Collecting mlflow<=1.13.1
#   Downloading mlflow-1.13.1-py3-none-any.whl (14.1 MB)
#      |████████████████████████████████| 14.1 MB 39.2 MB/s
# Collecting transformers==4.13.0
#   Downloading transformers-4.13.0-py3-none-any.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 57.8 MB/s
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      |████████████████████████████████| 5.6 MB 42.4 MB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm-haystack[faiss]) (0.3.4)
# Collecting azure-ai-formrecognizer==3.2.0b2
#   Downloading azure_ai_formrecognizer-3.2.0b2-py2.py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 38.0 MB/s
# Collecting azure-common~=1.1
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Collecting msrest>=0.6.21
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.5 MB/s
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack[faiss]) (1.15.0)
# Collecting azure-core<2.0.0,>=1.13.0
#   Downloading azure_core-1.22.1-py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 46.4 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 40.8 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack[faiss]) (1.21.5)
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 52.7 MB/s
# Collecting sacremoses
#   Downloading sacremoses-0.0.47-py2.py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 51.0 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack[faiss]) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack[faiss]) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 4.6 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack[faiss]) (2019.12.20)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack[faiss]) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack[faiss]) (2021.10.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.13.0->farm-haystack[faiss]) (3.10.0.2)
# Collecting azure-storage-blob>=12.0.0
#   Downloading azure_storage_blob-12.9.0-py2.py3-none-any.whl (356 kB)
#      |████████████████████████████████| 356 kB 52.8 MB/s
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack[faiss]) (0.4.2)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 59.5 MB/s
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.18.7-py3-none-any.whl (17 kB)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack[faiss]) (1.4.31)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack[faiss]) (3.17.3)
# Collecting alembic<=1.4.1
#   Downloading alembic-1.4.1.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 53.9 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack[faiss]) (7.1.2)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack[faiss]) (1.1.4)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 50.0 MB/s
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack[faiss]) (1.3.0)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.16.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 5.3 MB/s
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack[faiss]) (2.8.2)
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.5 MB/s
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack[faiss]) (0.4)
# Collecting Mako
#   Downloading Mako-1.1.6-py2.py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 4.3 MB/s
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting cryptography>=2.1.4
#   Downloading cryptography-36.0.1-cp36-abi3-manylinux_2_24_x86_64.whl (3.6 MB)
#      |████████████████████████████████| 3.6 MB 51.5 MB/s
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack[faiss]) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack[faiss]) (2.21)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.7->mlflow<=1.13.1->farm-haystack[faiss]) (0.8.9)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.3.1-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 1.8 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack[faiss]) (1.3.1)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 534 kB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.13.0->farm-haystack[faiss]) (3.0.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack[faiss]) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack[faiss]) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack[faiss]) (3.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack[faiss]) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack[faiss]) (3.1.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.0->farm-haystack[faiss]) (0.11.1+cu111)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 46.0 MB/s
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->mlflow<=1.13.1->farm-haystack[faiss]) (1.1.2)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 42.8 MB/s
# Collecting sqlalchemy-utils
#   Downloading SQLAlchemy_Utils-0.38.2-py3-none-any.whl (100 kB)
#      |████████████████████████████████| 100 kB 9.5 MB/s
# Collecting faiss-cpu<2,>=1.6.3
#   Downloading faiss_cpu-1.7.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 55.2 MB/s
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack[faiss]) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack[faiss]) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack[faiss]) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->mlflow<=1.13.1->farm-haystack[faiss]) (2.0.1)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.7/dist-packages (from gunicorn->mlflow<=1.13.1->farm-haystack[faiss]) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->farm-haystack[faiss]) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->farm-haystack[faiss]) (2018.9)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from prometheus-flask-exporter->mlflow<=1.13.1->farm-haystack[faiss]) (0.13.1)
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx->farm-haystack[faiss]) (4.2.6)
# Collecting num2words
#   Downloading num2words-0.5.10-py3-none-any.whl (101 kB)
#      |████████████████████████████████| 101 kB 11.6 MB/s
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack[faiss]) (2.1.0)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words->quantulum3->farm-haystack[faiss]) (0.6.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.0->farm-haystack[faiss]) (7.1.2)
# Building wheels for collected packages: alembic, databricks-cli, sentence-transformers, langdetect, python-docx, seqeval, tika
#   Building wheel for alembic (setup.py) ... done
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158171 sha256=e9b5d0e588da022011ebbf8f1af11607e85c0e3453bc2c8fbaaab5047faf445e
#   Stored in directory: /root/.cache/pip/wheels/be/5d/0a/9e13f53f4f5dfb67cd8d245bb7cdffe12f135846f491a283e3
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.16.4-py3-none-any.whl size=106877 sha256=856c9c68904c4f3ff41bf1cc4f755e57566c1a1605fda24bedea747b2679011b
#   Stored in directory: /root/.cache/pip/wheels/a2/a1/6d/fa1d22ea25ed8593887437fe1c7e00f6ef307fc240ccd4dc5c
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=889fae6114b7012b7abe3c79f2a181441dcc5c3369228a1674a359125c9b65ac
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=78d7139ab9de2b8a32208fad0c8e79fc5e425eea643c8b3aeaad170dc85e3527
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184507 sha256=a6186bd48dcd2a7075eec1aa9618a8395ab72642fb6703f766fcb265e869cce8
#   Stored in directory: /root/.cache/pip/wheels/f6/6f/b9/d798122a8b55b74ad30b5f52b01482169b445fbb84a11797a6
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16180 sha256=dcee02a43af2442172722b1cbab466f2a0a4f4480494273c7401468dcc55f006
#   Stored in directory: /root/.cache/pip/wheels/05/96/ee/7cac4e74f3b19e3158dce26a20a1c86b3533c43ec72a549fd7
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-py3-none-any.whl size=32893 sha256=3c0e6315c5d5d4b99538b4413bd8a391a19c944bec7c937ed81ab1a911a79c6b
#   Stored in directory: /root/.cache/pip/wheels/ec/2b/38/58ff05467a742e32f67f5d0de048fa046e764e2fbb25ac93f3
# Successfully built alembic databricks-cli sentence-transformers langdetect python-docx seqeval tika
# Installing collected packages: smmap, pyyaml, isodate, websocket-client, tokenizers, sacremoses, python-editor, msrest, Mako, huggingface-hub, gitdb, cryptography, azure-core, transformers, sentencepiece, querystring-parser, prometheus-flask-exporter, num2words, gunicorn, gitpython, docker, databricks-cli, azure-storage-blob, azure-common, alembic, tika, seqeval, sentence-transformers, quantulum3, python-docx, pydantic, mmh3, mlflow, langdetect, elasticsearch, elastic-apm, azure-ai-formrecognizer, sqlalchemy-utils, psycopg2-binary, farm-haystack, faiss-cpu
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed Mako-1.1.6 alembic-1.4.1 azure-ai-formrecognizer-3.2.0b2 azure-common-1.1.28 azure-core-1.22.1 azure-storage-blob-12.9.0 cryptography-36.0.1 databricks-cli-0.16.4 docker-5.0.3 elastic-apm-6.7.2 elasticsearch-7.10.0 faiss-cpu-1.7.2 farm-haystack-1.2.0 gitdb-4.0.9 gitpython-3.1.27 gunicorn-20.1.0 huggingface-hub-0.4.0 isodate-0.6.1 langdetect-1.0.9 mlflow-1.13.1 mmh3-3.0.0 msrest-0.6.21 num2words-0.5.10 prometheus-flask-exporter-0.18.7 psycopg2-binary-2.9.3 pydantic-1.9.0 python-docx-0.8.11 python-editor-1.0.4 pyyaml-6.0 quantulum3-0.7.10 querystring-parser-1.2.4 sacremoses-0.0.47 sentence-transformers-2.2.0 sentencepiece-0.1.96 seqeval-1.2.2 smmap-5.0.0 sqlalchemy-utils-0.38.2 tika-1.24 tokenizers-0.10.3 transformers-4.13.0 websocket-client-1.3.1

# %% [markdown]
# # Parse data

# %%
from conllu import parse

input_file = "/content/drive/MyDrive/PY/SemEval2022/crl_srl.csv"

with open(input_file, mode='r') as fp:
    input_data = fp.read()
    
sentences = parse(input_data)

# %%
import pandas as pd
df_img = pd.read_csv('/content/drive/MyDrive/PY/SemEval2022/df_img.csv')

# %%
import ast
# ast.literal_eval(df_img.caption[0]) # string to py list
df_img['caption'] = [ast.literal_eval(df_img.caption[i]) for i in range(len(df_img))]

# %%
df_img.caption[0]
# Out:
# [['a', 'person', 'in', 'tomatoes,', 'pink', 'frosting', '<end>'],
#  ['blurry',
#   'air',
#   'white',
#   'vegetables',
#   'arranged',
#   'on',
#   'display',
#   'at',
#   'market.',
#   '<end>'],
#  ['the', 'woman', 'has', 'a', 'variety', 'of', 'pastries.', '<end>']]

# %%
df_img
# Out:
#       Unnamed: 0  ...                                            caption
# 0              0  ...  [[a, person, in, tomatoes,, pink, frosting, <e...
# 1              1  ...  [[a, massive, pizza, filled, with, remote, on,...
# 2              2  ...  [[a, close, up, of, a, knife, cutting, a, knif...
# 3              3  ...  [[a, pan, is, preparing, bread, has, a, dinner...
# 4              4  ...  [[an, [UNK], blue, at, a, sign., <end>], [the,...
# ...          ...  ...                                                ...
# 1684        1684  ...  [[a, hot, face, being, face, <end>], [a, woman...
# 1685        1685  ...  [[pizza, on, the, grill., <end>], [a, glass, y...
# 1686        1686  ...  [[two, people, take, off, of, equipment., <end...
# 1687        1687  ...  [[a, hospital, being, cut, in, an, [UNK], <end...
# 1688        1688  ...  [[a, woman, holds, up, picture, of, a, piece, ...
#
# [1689 rows x 6 columns]

# %%
' '.join(df_img.caption[0][0])
# Out:
# 'a person in tomatoes, pink frosting <end>'

# %%
sentences[0].metadata['metadata:url']
# Out:
# 'https://foodista.com/recipe/6VWP66LZ/vegetables-and-minced-meat-casserole'

# %%
sentences[0].__dict__
# Out:
# {'default_fields': ('id',
#   'form',
#   'lemma',
#   'upos',
#   'xpos',
#   'feats',
#   'head',
#   'deprel',
#   'deps',
#   'misc'),
#  'metadata': {'answer 0-0': '1',
#   'answer 0-1': '1',
#   'answer 0-2': '1',
#   'answer 1-0': 'the cooked rice and vegetables and minced meat casserole',
#   'answer 12-0': 'to the cooked vegetables',
#   'answer 13-0': 'with cooked rice or something similar ( couscous , mashed potatoes )',
#   'answer 18-0': 'N/A',
#   'answer 18-1': 'N/A',
#   'answer 2-0': 'by using a knife',
#   'answer 2-1': 'by using a knife',
#   'answer 2-2': 'pan',
#   'answer 2-3': 'pan',
#   'answer 3-0': 'the meat',
#   'answer 3-1': 'the chopped vegetables',
#   'answer 3-2': 'the broccoli and stem',
#   'answer 3-3': 'by adding the chopped vegetables to the pan',
#   'answer 3-4': 'by cutting the broccoli and stem with the knife',
#   'answer 4-0': 'the first event',
#   'answer 4-1': 'the second event',
#   'answer 4-2': 'the second event',
#   'answer 4-3': 'the second event',
#   'answer 4-4': 'the first event',
#   'answer 4-5': 'the first event',
#   'answer 5-0': 'into cubes',
#   'answer 6-0': 'saute onion in 2 tablespoons of olive oil',
#   'answer 8-0': 'into the pan with the vegetables',
#   'answer 8-1': 'in a separate pan',
#   'metadata:avg_len_steps': '16',
#   'metadata:cluster': 'old',
#   'metadata:num_ingres': '9',
#   'metadata:num_steps': '6',
#   'metadata:url': 'https://foodista.com/recipe/6VWP66LZ/vegetables-and-minced-meat-casserole',
#   'newdoc id': 'f-6VWP66LZ',
#   'newpar id': 'f-6VWP66LZ::ingredients',
#   'question 0-0': 'How many actions does it take to process the mashed potato?',
#   'question 0-1': 'How many actions does it take to process the minced meat?',
#   'question 0-2': 'How many spatulas are used?',
#   'question 1-0': 'What should be served?',
#   'question 12-0': 'Where do you add the tinned tomatoes?',
#   'question 13-0': 'What do you serve the vegetables and minced meat casserole with?',
#   'question 18-0': "What's in the ingred mix?",
#   'question 18-1': 'Cooking the ingredient over a low heat until the water is absorbed and putting all the ingredients into a large saucepan, which comes first?',
#   'question 2-0': 'How do you cut the broccoli and stem?',
#   'question 2-1': 'How do you cut the carrots and zucchini?',
#   'question 2-2': 'Where should you add the chopped vegetables?',
#   'question 2-3': 'Where should you saute the onion?',
#   'question 3-0': "What's in the vegetables and minced meat casserole?",
#   'question 3-1': "What's in the cooked vegetable?",
#   'question 3-2': "What's in the chopped vegetable?",
#   'question 3-3': 'How did you get the cooked vegetable?',
#   'question 3-4': 'How did you get the chopped vegetable?',
#   'question 4-0': 'Transferring the meat into the pan with the vegetables and seasoning the meat, which comes first?',
#   'question 4-1': 'Transferring the meat into the pan with the vegetables and adding chopped vegetables, which comes first?',
#   'question 4-2': 'Sauting minced meat in a separate pan and cutting carrots and zucchini into cubes, which comes first?',
#   'question 4-3': 'Combining all ingredients and transferring the meat into the pan with the vegetables, which comes first?',
#   'question 4-4': 'Cutting carrots and zucchini into cubes and adding the tinned tomatoes, which comes first?',
#   'question 4-5': 'Cutting the stem into bite - size pieces into bite - size pieces and sauting minced meat in a separate pan, which comes first?',
#   'question 5-0': 'To what extent do you cut carrots and zucchini?',
#   'question 6-0': 'How do you saute onion?',
#   'question 8-0': 'Where do you transfer the meat?',
#   'question 8-1': 'Where do you saute minced meat?',
#   'sent_id': 'f-6VWP66LZ::ingredients::sent01',
#   'text': '500g broccoli'}}

# %%
sentences[25].__dict__
# Out:
# {'default_fields': ('id',
#   'form',
#   'lemma',
#   'upos',
#   'xpos',
#   'feats',
#   'head',
#   'deprel',
#   'deps',
#   'misc'),
#  'metadata': {'newpar id': 'f-GGX2LSGX::step01',
#   'sent_id': 'f-GGX2LSGX::step01::sent01',
#   'text': 'Preheat the oven to 350deg F.'}}

# %%
sentences[25].__len__()
# Out:
# 6

# %%
type(sentences[0])
# Out:
# conllu.models.TokenList

# %%
sentences[0].metadata
# Out:
# {'answer 0-0': '1',
#  'answer 0-1': '1',
#  'answer 0-2': '1',
#  'answer 1-0': 'the cooked rice and vegetables and minced meat casserole',
#  'answer 12-0': 'to the cooked vegetables',
#  'answer 13-0': 'with cooked rice or something similar ( couscous , mashed potatoes )',
#  'answer 18-0': 'N/A',
#  'answer 18-1': 'N/A',
#  'answer 2-0': 'by using a knife',
#  'answer 2-1': 'by using a knife',
#  'answer 2-2': 'pan',
#  'answer 2-3': 'pan',
#  'answer 3-0': 'the meat',
#  'answer 3-1': 'the chopped vegetables',
#  'answer 3-2': 'the broccoli and stem',
#  'answer 3-3': 'by adding the chopped vegetables to the pan',
#  'answer 3-4': 'by cutting the broccoli and stem with the knife',
#  'answer 4-0': 'the first event',
#  'answer 4-1': 'the second event',
#  'answer 4-2': 'the second event',
#  'answer 4-3': 'the second event',
#  'answer 4-4': 'the first event',
#  'answer 4-5': 'the first event',
#  'answer 5-0': 'into cubes',
#  'answer 6-0': 'saute onion in 2 tablespoons of olive oil',
#  'answer 8-0': 'into the pan with the vegetables',
#  'answer 8-1': 'in a separate pan',
#  'metadata:avg_len_steps': '16',
#  'metadata:cluster': 'old',
#  'metadata:num_ingres': '9',
#  'metadata:num_steps': '6',
#  'metadata:url': 'https://foodista.com/recipe/6VWP66LZ/vegetables-and-minced-meat-casserole',
#  'newdoc id': 'f-6VWP66LZ',
#  'newpar id': 'f-6VWP66LZ::ingredients',
#  'question 0-0': 'How many actions does it take to process the mashed potato?',
#  'question 0-1': 'How many actions does it take to process the minced meat?',
#  'question 0-2': 'How many spatulas are used?',
#  'question 1-0': 'What should be served?',
#  'question 12-0': 'Where do you add the tinned tomatoes?',
#  'question 13-0': 'What do you serve the vegetables and minced meat casserole with?',
#  'question 18-0': "What's in the ingred mix?",
#  'question 18-1': 'Cooking the ingredient over a low heat until the water is absorbed and putting all the ingredients into a large saucepan, which comes first?',
#  'question 2-0': 'How do you cut the broccoli and stem?',
#  'question 2-1': 'How do you cut the carrots and zucchini?',
#  'question 2-2': 'Where should you add the chopped vegetables?',
#  'question 2-3': 'Where should you saute the onion?',
#  'question 3-0': "What's in the vegetables and minced meat casserole?",
#  'question 3-1': "What's in the cooked vegetable?",
#  'question 3-2': "What's in the chopped vegetable?",
#  'question 3-3': 'How did you get the cooked vegetable?',
#  'question 3-4': 'How did you get the chopped vegetable?',
#  'question 4-0': 'Transferring the meat into the pan with the vegetables and seasoning the meat, which comes first?',
#  'question 4-1': 'Transferring the meat into the pan with the vegetables and adding chopped vegetables, which comes first?',
#  'question 4-2': 'Sauting minced meat in a separate pan and cutting carrots and zucchini into cubes, which comes first?',
#  'question 4-3': 'Combining all ingredients and transferring the meat into the pan with the vegetables, which comes first?',
#  'question 4-4': 'Cutting carrots and zucchini into cubes and adding the tinned tomatoes, which comes first?',
#  'question 4-5': 'Cutting the stem into bite - size pieces into bite - size pieces and sauting minced meat in a separate pan, which comes first?',
#  'question 5-0': 'To what extent do you cut carrots and zucchini?',
#  'question 6-0': 'How do you saute onion?',
#  'question 8-0': 'Where do you transfer the meat?',
#  'question 8-1': 'Where do you saute minced meat?',
#  'sent_id': 'f-6VWP66LZ::ingredients::sent01',
#  'text': '500g broccoli'}

# %%
sentences[0].metadata['metadata:url'].split('/')[-1]
# Out:
# 'vegetables-and-minced-meat-casserole'

# %%
# # add imgage caption data
# recipes = []
# titles = []
# doc_ID = []
# temp = []
# # stepnames = []
# for i, sentence in enumerate(sentences):
#     #if 'metadata:num_ingres' in sentence.metadata.keys() and 'metadata:num_steps' in sentence.metadata.keys() :
#     if 'newdoc id' in sentence.metadata.keys():
#         recipes.append(" ".join(temp))
#         temp = []
#         if 'metadata:url' in sentence.metadata.keys():
#           titles.append(sentence.metadata['metadata:url'].split('/')[-1])  #.replace('-',' ').replace('_',' ')
#     # print(sentence.metadata)
#     if 'newdoc id' in sentence.metadata.keys():
#       doc_ID.append(sentence.metadata['newdoc id'])
#     if 'text' in sentence.metadata.keys():
#         temp.append(sentence.metadata['text'])
#     if 'newpar id' in sentence.metadata.keys() and 'sent_id' in sentence.metadata.keys():
#         stepname = sentence.metadata['sent_id'].replace('::','_')
# #         stepnames.append(stepname)
#         if stepname in df_img.f_step.values:
#             temp.append(' '.join(df_img[df_img.f_step==stepname]['caption'].values[0][0])) #add img. caption to step      
#             temp.append(' '.join(df_img[df_img.f_step==stepname]['caption'].values[0][1])) #add img. caption to step            
#             temp.append(' '.join(df_img[df_img.f_step==stepname]['caption'].values[0][2])) #add img. caption to step            
            
# recipes.append(" ".join(temp))
        
# recipes = recipes[1:]

# %%
# input_data = []
# count = 0
# for i, sentence in enumerate(sentences):
#     if 'newdoc id' in sentence.metadata.keys():        
#         data = dict()
#         for key in sentence.metadata.keys():
#             if 'question ' in key:
#                 question = sentence.metadata[key]
#                 answer = sentence.metadata[key.replace('question', 'answer')]
#                 #print(count)
#                 # text = recipes[count]
#                 recipeID = count

#                 input_data.append({'recipeID':count, 'recipeTitle':titles[count], 'question':question, 'answer':answer})
#         count += 1

# %%
df_img
# Out:
#       Unnamed: 0  ...                                            caption
# 0              0  ...  [[a, person, in, tomatoes,, pink, frosting, <e...
# 1              1  ...  [[a, massive, pizza, filled, with, remote, on,...
# 2              2  ...  [[a, close, up, of, a, knife, cutting, a, knif...
# 3              3  ...  [[a, pan, is, preparing, bread, has, a, dinner...
# 4              4  ...  [[an, [UNK], blue, at, a, sign., <end>], [the,...
# ...          ...  ...                                                ...
# 1684        1684  ...  [[a, hot, face, being, face, <end>], [a, woman...
# 1685        1685  ...  [[pizza, on, the, grill., <end>], [a, glass, y...
# 1686        1686  ...  [[two, people, take, off, of, equipment., <end...
# 1687        1687  ...  [[a, hospital, being, cut, in, an, [UNK], <end...
# 1688        1688  ...  [[a, woman, holds, up, picture, of, a, piece, ...
#
# [1689 rows x 6 columns]

# %%
 sentences[1].metadata['sent_id'].split('::')[0]
# Out:
# 'f-6VWP66LZ'

# %% [markdown]
# # New parse

# %%
def parseFileNew(input_file):

  with open(input_file, mode='r') as fp:
      data = fp.read()
  sentences = parse(data)
  recipes = {}
  ingredients = {}
  titles = {}
  input_data = []
  for i, sentence in enumerate(sentences):
    if len(sentence.metadata)>0:
      if 'newdoc id' in sentence.metadata.keys(): # sentences[0]
          doc_id = sentence.metadata['newdoc id']
          recipes[doc_id] = ''
          ingredients[doc_id] = [sentence.metadata['text']]

          # if 'metadata:url' in sentence.metadata.keys():
          title = sentence.metadata['metadata:url'].split('/')[-1]  #.replace('-',' ').replace('_',' ')
          titles[doc_id] = title 

          for key in sentence.metadata.keys():
            if 'question ' in key:
              question = sentence.metadata[key]
              answer = ''
              if key.replace('question', 'answer') in sentence.metadata:
                answer = sentence.metadata[key.replace('question', 'answer')]

              input_data.append({'doc_ID':doc_id, 'recipeTitle':title, 
                                     'question':question,'qkey':key, 'answer':answer})
          
      else:
        if 'newpar id' in sentence.metadata.keys():
          doc_id = sentence.metadata['newpar id'].split('::')[0]
          recipes[doc_id] += sentence.metadata['text']
          stepname = sentence.metadata['sent_id'].replace('::','_')

          if stepname in df_img.f_step.values:
            imgCaption = ' '.join([i for t in df_img[df_img.f_step==stepname]['caption'].values[0] for i in t[:-1]])
            recipes[doc_id] += imgCaption


        else:
          doc_id = sentence.metadata['sent_id'].split('::')[0]
          ingredients[doc_id] += [sentence.metadata['text']]

  return recipes, ingredients, titles, input_data

# %%
recipes['f-YJNCYBQY']
# Out:
# "Preheat oven to 325.Cream butter well.Pour into pan and bake for 60 to 75 minutes or until a cake tester comes out clean.As with any cake you're supposed to allow it to cool before slicing but I love a piece when the top is slightly crusty and the inside is soft,warm and that vanilla, buttery aroma steams up to your nose with each bite!For the topping, slice strawberries.Sprinkle with sugar.Pour in rum.Stir and let sit for 1 to 2 hours so juices release and alcohol soaks into he berries.Slice cake layers.Top with strawberries and whipped creme!"

# %%
ingredients['f-26574QCW']
# Out:
# ['3 tbsp olive oil',
#  '3 cups apple cider',
#  '1 cup apple cider vinegar',
#  '1 1/2 tbsp Tomato & Parsley Vinaigrette',
#  '1 1/4 lb turnips',
#  '1 1/4 lb parsnip',
#  '1 1/4 lb carrots',
#  '1 1/4 lb red or sweet potatoes (I like leaving the skins on)',
#  '1 large red onion, quartered',
#  '1 med chopped zucchini for color (optional)']

# %%
recipes['f-26574QCW']
# Out:
# ['Boil apple juice and wine in a large saucepan until reduced to 3/4 cup, about 30 min.',
#  'Whisk in olive oil and Veggie Rub.',
#  'Preheat oven to 425 f.',
#  'Peel and cut vegetables into 1/2 inch pieces.',
#  'Divide between 2 roasting pans.',
#  'Pour apple juice mixture over vegetables.',
#  'Toss to coat.',
#  'Roast until vegetables are tender & golden, stirring occasionally, about 40 min.']

# %%
len(recipes), len(titles), len(ingredients)
# Out:
# (800, 800, 800)

# %%
sentences[0].metadata
# Out:
# {'answer 0-0': '1',
#  'answer 0-1': '1',
#  'answer 0-2': '1',
#  'answer 1-0': 'the cooked rice and vegetables and minced meat casserole',
#  'answer 12-0': 'to the cooked vegetables',
#  'answer 13-0': 'with cooked rice or something similar ( couscous , mashed potatoes )',
#  'answer 18-0': 'N/A',
#  'answer 18-1': 'N/A',
#  'answer 2-0': 'by using a knife',
#  'answer 2-1': 'by using a knife',
#  'answer 2-2': 'pan',
#  'answer 2-3': 'pan',
#  'answer 3-0': 'the meat',
#  'answer 3-1': 'the chopped vegetables',
#  'answer 3-2': 'the broccoli and stem',
#  'answer 3-3': 'by adding the chopped vegetables to the pan',
#  'answer 3-4': 'by cutting the broccoli and stem with the knife',
#  'answer 4-0': 'the first event',
#  'answer 4-1': 'the second event',
#  'answer 4-2': 'the second event',
#  'answer 4-3': 'the second event',
#  'answer 4-4': 'the first event',
#  'answer 4-5': 'the first event',
#  'answer 5-0': 'into cubes',
#  'answer 6-0': 'saute onion in 2 tablespoons of olive oil',
#  'answer 8-0': 'into the pan with the vegetables',
#  'answer 8-1': 'in a separate pan',
#  'metadata:avg_len_steps': '16',
#  'metadata:cluster': 'old',
#  'metadata:num_ingres': '9',
#  'metadata:num_steps': '6',
#  'metadata:url': 'https://foodista.com/recipe/6VWP66LZ/vegetables-and-minced-meat-casserole',
#  'newdoc id': 'f-6VWP66LZ',
#  'newpar id': 'f-6VWP66LZ::ingredients',
#  'question 0-0': 'How many actions does it take to process the mashed potato?',
#  'question 0-1': 'How many actions does it take to process the minced meat?',
#  'question 0-2': 'How many spatulas are used?',
#  'question 1-0': 'What should be served?',
#  'question 12-0': 'Where do you add the tinned tomatoes?',
#  'question 13-0': 'What do you serve the vegetables and minced meat casserole with?',
#  'question 18-0': "What's in the ingred mix?",
#  'question 18-1': 'Cooking the ingredient over a low heat until the water is absorbed and putting all the ingredients into a large saucepan, which comes first?',
#  'question 2-0': 'How do you cut the broccoli and stem?',
#  'question 2-1': 'How do you cut the carrots and zucchini?',
#  'question 2-2': 'Where should you add the chopped vegetables?',
#  'question 2-3': 'Where should you saute the onion?',
#  'question 3-0': "What's in the vegetables and minced meat casserole?",
#  'question 3-1': "What's in the cooked vegetable?",
#  'question 3-2': "What's in the chopped vegetable?",
#  'question 3-3': 'How did you get the cooked vegetable?',
#  'question 3-4': 'How did you get the chopped vegetable?',
#  'question 4-0': 'Transferring the meat into the pan with the vegetables and seasoning the meat, which comes first?',
#  'question 4-1': 'Transferring the meat into the pan with the vegetables and adding chopped vegetables, which comes first?',
#  'question 4-2': 'Sauting minced meat in a separate pan and cutting carrots and zucchini into cubes, which comes first?',
#  'question 4-3': 'Combining all ingredients and transferring the meat into the pan with the vegetables, which comes first?',
#  'question 4-4': 'Cutting carrots and zucchini into cubes and adding the tinned tomatoes, which comes first?',
#  'question 4-5': 'Cutting the stem into bite - size pieces into bite - size pieces and sauting minced meat in a separate pan, which comes first?',
#  'question 5-0': 'To what extent do you cut carrots and zucchini?',
#  'question 6-0': 'How do you saute onion?',
#  'question 8-0': 'Where do you transfer the meat?',
#  'question 8-1': 'Where do you saute minced meat?',
#  'sent_id': 'f-6VWP66LZ::ingredients::sent01',
#  'text': '500g broccoli'}

# %%
sentences[1].metadata
# Out:
# {'sent_id': 'f-6VWP66LZ::ingredients::sent02', 'text': '300g carrots'}

# %%
sentences[9].metadata
# Out:
# {'newpar id': 'f-6VWP66LZ::step01',
#  'sent_id': 'f-6VWP66LZ::step01::sent01',
#  'text': 'Cut the broccoli into flowerets and the stem into bite-size pieces; cut carrots and zucchini into cubes.'}

# %%
len(recipes)
# Out:
# 800

# %%
len(doc_IDs)
# Out:
# 800

# %%
len(titles)
# Out:
# 800

# %%
# input_file = "/content/drive/MyDrive/PY/SemEval2022/crl_srl.csv"

def parseFile(input_file):
  with open(input_file, mode='r') as fp:
      input_data = fp.read()
      
  sentences = parse(input_data)
  recipes = []
  titles = []
  # doc_IDs = []
  temp = []
  # for i, sentence in enumerate(sentences):
  #     #if 'metadata:num_ingres' in sentence.metadata.keys() and 'metadata:num_steps' in sentence.metadata.keys() :
  #     if 'newdoc id' in sentence.metadata.keys():
  #         recipes.append(" ".join(temp))
  #         temp = []
  #         if 'metadata:url' in sentence.metadata.keys():
  #           titles.append(sentence.metadata['metadata:url'].split('/')[-1])  #.replace('-',' ').replace('_',' ')
  #     # print(sentence.metadata)
  #     if 'text' in sentence.metadata.keys():
  #         temp.append(sentence.metadata['text'])
  # recipes.append(" ".join(temp))
          
  # recipes = recipes[1:]
  for i, sentence in enumerate(sentences):
    #if 'metadata:num_ingres' in sentence.metadata.keys() and 'metadata:num_steps' in sentence.metadata.keys() :
    if 'newdoc id' in sentence.metadata.keys():
        recipes.append(" ".join(temp))
        temp = []
        if 'metadata:url' in sentence.metadata.keys():
          titles.append(sentence.metadata['metadata:url'].split('/')[-1])  #.replace('-',' ').replace('_',' ')
    # print(sentence.metadata)
    # if 'newdoc id' in sentence.metadata.keys():
    #   doc_IDs.append(sentence.metadata['newdoc id'])
    if 'text' in sentence.metadata.keys():
        temp.append(sentence.metadata['text'])
    if 'newpar id' in sentence.metadata.keys() and 'sent_id' in sentence.metadata.keys():
        stepname = sentence.metadata['sent_id'].replace('::','_')
#         stepnames.append(stepname)
        if stepname in df_img.f_step.values:
            temp.append(' '.join(df_img[df_img.f_step==stepname]['caption'].values[0][0])) #add img. caption to step      
            temp.append(' '.join(df_img[df_img.f_step==stepname]['caption'].values[0][1])) #add img. caption to step            
            temp.append(' '.join(df_img[df_img.f_step==stepname]['caption'].values[0][2])) #add img. caption to step      
        
  input_data = []
  count = 0
  for i, sentence in enumerate(sentences):
      if 'newdoc id' in sentence.metadata.keys():   
          doc_ID = sentence.metadata['newdoc id']     
          data = dict()
          for key in sentence.metadata.keys():
              if 'question ' in key:
                  question = sentence.metadata[key]
                  #print(count)
                  # text = recipes[count]
                  recipeID = count
                  answer = ''
                  if key.replace('question', 'answer') in sentence.metadata:
                      answer = sentence.metadata[key.replace('question', 'answer')]

                  
                  input_data.append({'doc_ID':doc_ID,'recipeID':count, 'recipeTitle':titles[count],
                                     'question':question,'qkey':key.replace(' ','_'), 'answer':answer})
          count += 1

  return recipes, titles, input_data

# %%
recipes, ingredients, titles, input_data  = parseFileNew("/content/drive/MyDrive/PY/SemEval2022/crl_srl.csv")
# recipes_val, titles_val, input_data_val  = parseFile("/content/drive/MyDrive/PY/SemEval2022/crl_srl_val.csv")
recipes_test, ingredients_test, titles_test, input_data_test  = parseFileNew("/content/drive/MyDrive/PY/SemEval2022/crl_srl_test.csv")

# %%
len(recipes), len(titles), len(input_data)
# Out:
# (800, 800, 26526)

# %%
len(recipes_test), len(titles_test), len(input_data_test)
# Out:
# (100, 100, 3442)

# %%
len(recipes)
# Out:
# 800

# %%
len(input_data)
# Out:
# 26526

# %%
recipes.extend(recipes_test)
titles.extend(titles_test)

# %% [markdown]
# # RAG
# https://github.com/deepset-ai/haystack
#
# https://github.com/deepset-ai/haystack/blob/master/tutorials/Tutorial7_RAG_Generator.ipynb
#
# https://github.com/facebookresearch/DPR

# %%
# !pip install grpcio-tools==1.34.1
# !pip install git+https://github.com/deepset-ai/haystack.git
# Out:
# Collecting grpcio-tools==1.34.1
#   Downloading grpcio_tools-1.34.1-cp37-cp37m-manylinux2014_x86_64.whl (2.5 MB)
#      |████████████████████████████████| 2.5 MB 17.3 MB/s
# Requirement already satisfied: grpcio>=1.34.1 in /usr/local/lib/python3.7/dist-packages (from grpcio-tools==1.34.1) (1.44.0)
# Requirement already satisfied: protobuf<4.0dev,>=3.5.0.post1 in /usr/local/lib/python3.7/dist-packages (from grpcio-tools==1.34.1) (3.17.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from grpcio-tools==1.34.1) (57.4.0)
# Requirement already satisfied: six>=1.5.2 in /usr/local/lib/python3.7/dist-packages (from grpcio>=1.34.1->grpcio-tools==1.34.1) (1.15.0)
# Installing collected packages: grpcio-tools
# Successfully installed grpcio-tools-1.34.1
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-jihjozfo
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-jihjozfo
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: tika in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.24)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (4.62.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (4.11.1)
# Requirement already satisfied: sentence-transformers>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (2.2.0)
# Requirement already satisfied: azure-ai-formrecognizer==3.2.0b2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (3.2.0b2)
# Requirement already satisfied: mlflow<=1.13.1 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.13.1)
# Requirement already satisfied: transformers==4.13.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (4.13.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (3.2.5)
# Requirement already satisfied: torch<1.11,>1.9 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.10.0+cu111)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (8.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (2.23.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.3.5)
# Requirement already satisfied: mmh3 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (3.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (2.6.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.4.1)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.0.9)
# Requirement already satisfied: seqeval in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.2.2)
# Requirement already satisfied: elastic-apm in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (6.7.2)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (0.8.11)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.9.0)
# Requirement already satisfied: quantulum3 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (0.7.10)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (0.3.4)
# Requirement already satisfied: elasticsearch<=7.10,>=7.7 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (7.10.0)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from farm-haystack==1.2.0) (1.0.2)
# Requirement already satisfied: msrest>=0.6.21 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.2.0) (0.6.21)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.2.0) (1.15.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.2.0) (1.22.1)
# Requirement already satisfied: azure-common~=1.1 in /usr/local/lib/python3.7/dist-packages (from azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.2.0) (1.1.28)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.2.0) (6.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.2.0) (0.0.47)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.2.0) (1.21.5)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.2.0) (0.10.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.2.0) (2019.12.20)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.2.0) (0.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.2.0) (3.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers==4.13.0->farm-haystack==1.2.0) (21.3)
# Requirement already satisfied: urllib3<2,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.2.0) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.2.0) (2021.10.8)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers==4.13.0->farm-haystack==1.2.0) (3.10.0.2)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (3.17.3)
# Requirement already satisfied: databricks-cli>=0.8.7 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (0.16.4)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (7.1.2)
# Requirement already satisfied: azure-storage-blob>=12.0.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (12.9.0)
# Requirement already satisfied: querystring-parser in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (1.2.4)
# Requirement already satisfied: gunicorn in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (20.1.0)
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (0.4.2)
# Requirement already satisfied: alembic<=1.4.1 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (1.4.1)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (1.4.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (2.8.2)
# Requirement already satisfied: docker>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (5.0.3)
# Requirement already satisfied: prometheus-flask-exporter in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (0.18.7)
# Requirement already satisfied: gitpython>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (3.1.27)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (1.3.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (0.4)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from mlflow<=1.13.1->farm-haystack==1.2.0) (1.1.4)
# Requirement already satisfied: python-editor>=0.3 in /usr/local/lib/python3.7/dist-packages (from alembic<=1.4.1->mlflow<=1.13.1->farm-haystack==1.2.0) (1.0.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic<=1.4.1->mlflow<=1.13.1->farm-haystack==1.2.0) (1.1.6)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.2.0) (36.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.2.0) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.2.0) (2.21)
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.7/dist-packages (from databricks-cli>=0.8.7->mlflow<=1.13.1->farm-haystack==1.2.0) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python3.7/dist-packages (from docker>=4.0.0->mlflow<=1.13.1->farm-haystack==1.2.0) (1.3.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack==1.2.0) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack==1.2.0) (5.0.0)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.2.0) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.2.0) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers==4.13.0->farm-haystack==1.2.0) (3.0.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.2.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->farm-haystack==1.2.0) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer==3.2.0b2->farm-haystack==1.2.0) (3.2.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack==1.2.0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=1.0.0->farm-haystack==1.2.0) (3.1.0)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.0->farm-haystack==1.2.0) (0.1.96)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.0->farm-haystack==1.2.0) (0.11.1+cu111)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy->mlflow<=1.13.1->farm-haystack==1.2.0) (1.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.2.0) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.2.0) (1.1.0)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.2.0) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->mlflow<=1.13.1->farm-haystack==1.2.0) (2.0.1)
# Requirement already satisfied: setuptools>=3.0 in /usr/local/lib/python3.7/dist-packages (from gunicorn->mlflow<=1.13.1->farm-haystack==1.2.0) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->farm-haystack==1.2.0) (3.7.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->farm-haystack==1.2.0) (2018.9)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from prometheus-flask-exporter->mlflow<=1.13.1->farm-haystack==1.2.0) (0.13.1)
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from python-docx->farm-haystack==1.2.0) (4.2.6)
# Requirement already satisfied: inflect in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack==1.2.0) (2.1.0)
# Requirement already satisfied: num2words in /usr/local/lib/python3.7/dist-packages (from quantulum3->farm-haystack==1.2.0) (0.5.10)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from num2words->quantulum3->farm-haystack==1.2.0) (0.6.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.0->farm-haystack==1.2.0) (7.1.2)

# %%
from typing import List
import requests
import pandas as pd
from haystack import Document
from haystack.document_stores import FAISSDocumentStore
from haystack.nodes import RAGenerator, DensePassageRetriever
# Out:
# INFO - haystack.modeling.model.optimization -  apex not found, won't use it. See https://nvidia.github.io/apex/

# %%
pd.DataFrame({'recipes':pd.Series(recipes),'title':pd.Series(titles)})
# Out:
#                                                                                     recipes                                       title
# f-6VWP66LZ  Cut the broccoli into flowerets and the stem into bite-size pieces; cut carr...        vegetables-and-minced-meat-casserole
# f-GGX2LSGX  Preheat the oven to 350deg F.Heat the olive oil and butter in a large skille...                caramelized-onion-bacon-tart
# f-GPT7GGG6  Cook pasta in large salted pot of boiling water according to pasta package d...  ink-pasta-with-shrimps-tomatoes-and-garlic
# f-Y2HTQLYW  Combine all of the above ingredients in a food processor and process until s...                     chickpea-patty-sandwich
# f-DXL86CWX  Boil the potatoes for 20 minutes or until cooked.Peel the potatoes and slice...              trout-with-creamy-potato-salad
# ...                                                                                     ...                                         ...
# f-NNCLJCD3  Mix the finely chopped dill with the panko breadcrumbs in a shallow bowl.Dus...                             shrimps-fingers
# r-1388      Preheat an oven to 350 degF (175 degC).Mix flour, baking powder, salt, and s...                            Irish_Soda_Bread
# r-1751      Finely dice all the ingredients and mix with the mayonnaise.a young lady cut...                                Fleischsalat
# r-4833      For cocoa mix, in a storage container combine dry milk powder, cocoa powder,...                 Mexican-style_Hot_Chocolate
# r-3509      Combine soup, pimientos, 1/4 cup parsley and Onion in large bowl.Add rice an...                   Cheese_and_Rice_Casserole
#
# [800 rows x 2 columns]

# %%
len(question_combine)
# Out:
# 26526

# %%
input_data[0]
# Out:
# {'answer': '1',
#  'doc_ID': 'f-6VWP66LZ',
#  'qkey': 'question 0-1',
#  'question': 'How many actions does it take to process the minced meat?',
#  'recipeTitle': 'vegetables-and-minced-meat-casserole'}

# %%
def prepareText(recipes, titles, input_data):
  df = pd.DataFrame({'title':titles,'text':recipes})
  df = df.fillna('N/A')
  df_qa = pd.DataFrame(input_data)
  df_qa['dummy'] = [' in '] * len(df_qa)
  df_qa['question'] = df_qa['question'].apply(lambda x: x[:-1])
  df_qa['question'] = df_qa['question'] + df_qa['dummy'] + df_qa['recipeTitle']

  df_new = pd.DataFrame({'title':pd.concat([df.title,df_qa.iloc[100:,].reset_index().answer]), 
                        'text':pd.concat([df.text,df_qa.iloc[100:,].reset_index().question])})
  df_new.fillna('')
  return df_new, df_qa

# %%
def parseQA(recipes,input_data): 
  question_combine = []
  answers = []
  for i in input_data:
    ques  = i['question'] + ' ' +recipes[i['doc_ID']]
    answer = i['answer'] + i['recipeTitle']
    question_combine.append(ques)
    answers.append(answer)
  return  question_combine, answers

# %%
ques_train, answers_train = parseQA(recipes, input_data)
# _, df_qa_val = prepareText(recipes_val, titles_val, input_data_val)
ques_test, answers_test = parseQA(recipes_test, input_data_test)

# %%
len(ques_train),len(ques_test), len(answers_train),len(answers_test)
# Out:
# (26526, 3442, 26526, 3442)

# %% [markdown]
# ## Forward to RAG

# %%
# Use data to initialize Document objects
titles = answers_train[:100] + answers_test
texts = ques_train[:100] + ques_test
documents: List[Document] = []
for title, text in zip(titles, texts):
    documents.append(
        Document(
            content=text,
            meta={
                "name": title or ""
            }
        )
    )

# %%
# Initialize FAISS document store.
# Set `return_embedding` to `True`, so generator doesn't have to perform re-embedding
document_store = FAISSDocumentStore(
    faiss_index_factory_str="Flat",
    return_embedding=True
)

# Initialize DPR Retriever to encode documents, encode question and query documents
retriever = DensePassageRetriever(
    document_store=document_store,
    query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
    passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
    use_gpu=True,
    embed_title=True,
)

# Initialize RAG Generator
generator = RAGenerator(
    model_name_or_path="facebook/rag-token-nq",
    use_gpu=True,
    top_k=1,
    max_length=200,
    min_length=2,
    embed_title=True,
    num_beams=2,
)
# Out:
# INFO - haystack.modeling.utils -  Using devices: CUDA:0
# INFO - haystack.modeling.utils -  Number of GPUs: 1
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/493 [00:00<?, ?B/s]
# INFO - haystack.modeling.model.language_model -  LOADING MODEL
# INFO - haystack.modeling.model.language_model -  =============
# INFO - haystack.modeling.model.language_model -  Could not find facebook/dpr-question_encoder-single-nq-base locally.
# INFO - haystack.modeling.model.language_model -  Looking on Transformers Model Hub (in local cache and online)...
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# INFO - haystack.modeling.model.language_model -  Loaded facebook/dpr-question_encoder-single-nq-base
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/492 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizerFast'.
# INFO - haystack.modeling.model.language_model -  LOADING MODEL
# INFO - haystack.modeling.model.language_model -  =============
# INFO - haystack.modeling.model.language_model -  Could not find facebook/dpr-ctx_encoder-single-nq-base locally.
# INFO - haystack.modeling.model.language_model -  Looking on Transformers Model Hub (in local cache and online)...
# Downloading:   0%|          | 0.00/418M [00:00<?, ?B/s]
# INFO - haystack.modeling.model.language_model -  Loaded facebook/dpr-ctx_encoder-single-nq-base
# INFO - haystack.modeling.utils -  Using devices: CUDA
# INFO - haystack.modeling.utils -  Number of GPUs: 1
# Downloading:   0%|          | 0.00/4.49k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/bart/configuration_bart.py:178: UserWarning: Please make sure the config includes `forced_bos_token_id=0` in future versions. The config can simply be saved and uploaded again to be fixed.
#   f"Please make sure the config includes `forced_bos_token_id={self.bos_token_id}` in future versions. "
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/772 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.
# Downloading:   0%|          | 0.00/1.92G [00:00<?, ?B/s]
# Some weights of RagTokenForGeneration were not initialized from the model checkpoint at facebook/rag-token-nq and are newly initialized: ['rag.generator.lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Delete existing documents in documents store
document_store.delete_documents()

# Write documents to document store
document_store.write_documents(documents)

# Add documents embeddings to index
document_store.update_embeddings(
    retriever=retriever
)
# Out:
# Writing Documents:   0%|          | 0/3542 [00:00<?, ?it/s]
# INFO - haystack.document_stores.faiss -  Updating embeddings for 3481 docs...
# Updating Embedding:   0%|          | 0/3481 [00:00<?, ? docs/s]
# Create embeddings:   0%|          | 0/3488 [00:00<?, ? Docs/s]

# %%
import pickle
# with open('/content/drive/MyDrive/PY/SemEval2022/document_store.pickle', 'wb') as handle:
#     pickle.dump(document_store, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('/content/drive/MyDrive/PY/SemEval2022/generator.pickle', 'wb') as handle:
    pickle.dump(generator, handle, protocol=pickle.HIGHEST_PROTOCOL)
# with open('/content/drive/MyDrive/PY/SemEval2022/retriever.pickle', 'wb') as handle:
#     pickle.dump(retriever, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
df_qa_test.question
# Out:
# 0                              Where should you drain the water and eggplant in Zaalouk
# 1                                                   How many spoons are used in Zaalouk
# 2          Where do you add the eggplant when the egg plant is almost cooked in Zaalouk
# 3        Heating the oil in a pan and cooling the mixture, which comes first in Zaalouk
# 4       Putting the mixture in a wood container and grating carrots, which comes fir...
#                                              ...
# 3437                                                What's in the mixture in Huzarensla
# 3438     Where was the mixture before it was refrigerated for best flavor in Huzarensla
# 3439                                          How did you get the mixture in Huzarensla
# 3440                 How many actions does it take to process the paprika in Huzarensla
# 3441          For how long do you refrigerate the mixture for best flavor in Huzarensla
# Name: question, Length: 3442, dtype: object

# %%
from tqdm import tqdm

# %%
pred_answers = [] 
for question in tqdm(ques_test):
    # Retrieve related documents from retriever
    retriever_results = retriever.retrieve(
        query=question
    )

    # Now generate answer from question and retrieved documents
    predicted_result = generator.predict(
        query=question,
        documents=retriever_results,
        top_k=1
    )

    # Print you answer
    answers = predicted_result["answers"]
    pred_answers.append(answers[0].answer)
    # print(f'Generated answer is \'{answers[0].answer}\' for the question = \'{question}\'')
# Out:
#   0%|          | 0/3442 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/transformers/models/rag/tokenization_rag.py:97: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1749: UserWarning: `max_length` is deprecated in this function, use `stopping_criteria=StoppingCriteriaList(MaxLengthCriteria(max_length=max_length))` instead.
#   UserWarning,
# 100%|██████████| 3442/3442 [33:58<00:00,  1.69it/s]

# %%
doc_IDs,qkeys = [],[]
for i in input_data_test:
  doc_IDs.append(i['doc_ID'])
  qkeys.append(i['qkey'])

df_res = pd.DataFrame({'doc_ID':doc_IDs, 'qkeys':qkeys, 'pred':pred_answers})
dict_res = dict(df_res.groupby('doc_ID').apply(lambda x: dict(zip(x['qkeys'],x['pred']))))

import json
with open("/content/drive/MyDrive/PY/SemEval2022/new_res.json", "w") as outfile:
    json.dump(dict_res, outfile)

dict_res
# Out:
# {'f-24CZS5LF': {'question 0-0': ' four',
#   'question 0-1': ' two',
#   'question 0-2': ' three',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 0-5': ' two',
#   'question 1-0': ' potatoes',
#   'question 1-1': ' potatoes',
#   'question 1-2': ' potatoes',
#   'question 18-0': ' in a large bowl',
#   'question 18-1': ' three',
#   'question 18-2': ' the packaging',
#   'question 18-3': ' dessert or compote',
#   'question 2-0': ' where you place the potatoes',
#   'question 2-1': ' sliced up into bite size pieces',
#   'question 3-0': ' mayonnaise',
#   'question 3-1': ' in',
#   'question 4-0': ' potatoes',
#   'question 4-1': ' potatoes',
#   'question 4-2': ' potatoes',
#   'question 4-3': ' potatoes',
#   'question 4-4': ' in',
#   'question 4-5': ' chopped celery and sweet peppers',
#   'question 5-0': ' boil potatoes until fork tender',
#   'question 8-0': ' in a small bowl',
#   'question 8-1': ' in a serving bowl'},
#  'f-26NF6ZNY': {'question 0-0': ' four',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 1-0': ' j',
#   'question 1-1': 'refreshing - strawberry -limeade',
#   'question 1-2': 'refreshing - strawberry -limeade',
#   'question 1-3': ' lemon lime soda',
#   'question 1-4': ' strawberry',
#   'question 1-5': ' strawberry',
#   'question 10-0': ' pulse until smooth',
#   'question 12-0': ' to the pitcher',
#   'question 12-1': ' in a large pitcher',
#   'question 12-2': ' a food processor',
#   'question 17-0': ' in a large pitcher',
#   'question 18-0': ' in the',
#   'question 18-1': ' sugar',
#   'question 2-0': ' in a large pitcher',
#   'question 3-0': ',',
#   'question 3-1': ' strawberry',
#   'question 3-2': ' lemon lime soda',
#   'question 3-3': ' strawberry',
#   'question 3-4': ',',
#   'question 3-5': ',',
#   'question 4-0': ' in a large pitcher',
#   'question 4-1': ' in a large pitcher',
#   'question 4-2': ' lemon lime soda',
#   'question 4-3': ' in a large pitcher',
#   'question 5-0': ' until smooth',
#   'question 7-0': ' 30 minutes',
#   'question 8-0': ' the pitcher',
#   'question 8-1': ' in a large pitcher',
#   'question 9-0': ' about 1 / 3 of the way'},
#  'f-2PMMKJ2X': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' put a pan to heat',
#   'question 1-0': 'pyaaz - ki - kadhi',
#   'question 1-1': ' kadhi',
#   'question 1-2': ' curd',
#   'question 1-3': ' coriander leaves',
#   'question 10-0': ' in a bowl',
#   'question 10-1': ' put a pan to heat',
#   'question 12-0': ' in a bowl',
#   'question 15-0': ' put another pan to heat',
#   'question 18-0': ' pyaaz - ki - kadhi',
#   'question 18-1': ' the',
#   'question 18-2': ' in a bowl',
#   'question 18-3': ' two',
#   'question 18-4': ' put a pan to heat',
#   'question 3-0': ' in a bowl',
#   'question 3-1': ' pyaaz - ki - kadhi',
#   'question 3-2': ' cumin seeds',
#   'question 3-3': ' p',
#   'question 4-0': ' pyaaz - ki - kadhi',
#   'question 4-1': ' the kadhi',
#   'question 4-2': ' put a pan to heat',
#   'question 4-3': ' put a pan to heat',
#   'question 5-0': ' until boil appears',
#   'question 6-0': ' let onions soften',
#   'question 8-0': ' in a bowl'},
#  'f-3PMSLV76': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' three steps',
#   'question 1-0': ' cornstarch',
#   'question 1-1': ' biscuit',
#   'question 1-2': '350 ° f',
#   'question 1-3': ' dessert or compote',
#   'question 1-4': ' cookies',
#   'question 10-0': ' drop by teaspoons',
#   'question 10-1': ' drop by teaspoons',
#   'question 14-0': ' how to pre heat oven',
#   'question 16-0': ' drop by teaspoons',
#   'question 17-0': ' drop by teaspoons',
#   'question 17-1': ' the',
#   'question 18-0': ' cornstarch',
#   'question 18-1': " `` apricot ''",
#   'question 2-0': ' spade',
#   'question 2-1': ' spade',
#   'question 2-2': ' spoonful of cream',
#   'question 2-3': ' spoonful of coconut',
#   'question 2-4': ' 350 ° f',
#   'question 3-0': ' the',
#   'question 3-1': ' the',
#   'question 3-2': ' your mother and cousins',
#   'question 3-3': ' cornstarch',
#   'question 3-4': ' craisins',
#   'question 3-5': ' the',
#   'question 3-6': ' sugar was a mystery ingredient',
#   'question 3-7': ' your grandfather',
#   'question 4-0': ' in',
#   'question 4-1': ' cornstarch',
#   'question 4-2': " `` angel food '' cookies",
#   'question 5-0': ' to perfection',
#   'question 5-1': ' first',
#   'question 5-2': ' the',
#   'question 6-0': ' drop by teaspoons',
#   'question 6-1': " `` bobbing ''",
#   'question 7-0': ' bake 23 - 33 minutes',
#   'question 7-1': ' 23 -- 33 minutes',
#   'question 7-2': ' 23 -- 33 minutes',
#   'question 7-3': ' bake 23 - 33 minutes',
#   'question 8-0': ' in a large bowl',
#   'question 8-1': ' the middle of the playground',
#   'question 8-2': ' 1 / 2 tsp',
#   'question 8-3': ' in a small bowl',
#   'question 8-4': ' in a small bowl',
#   'question 8-5': ' the puff pastry part',
#   'question 8-6': ' in prepared muffin pans'},
#  'f-3X45Z8TR': {'question 0-0': ' three',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' four',
#   'question 1-0': ' baking soda',
#   'question 1-1': ' baking soda',
#   'question 1-2': ' baking soda',
#   'question 1-3': ' biscuit',
#   'question 1-4': ' baking soda',
#   'question 10-0': ' drop by teaspoons',
#   'question 10-1': ' baking soda',
#   'question 12-0': ' butter in a large bowl',
#   'question 15-0': ' drop by teaspoons',
#   'question 16-0': ' drop by teaspoons',
#   'question 17-0': ' the packaging',
#   'question 17-1': " `` bounce mat ''",
#   'question 18-0': ' to',
#   'question 18-1': ' right or left leg',
#   'question 2-0': ' on lightly buttered cookie sheets',
#   'question 2-1': ' on lightly buttered cookie sheets',
#   'question 2-2': ' baking soda',
#   'question 2-3': ' baking soda',
#   'question 2-4': ' drop by teaspoons',
#   'question 3-0': ' baking soda',
#   'question 3-1': ' baking soda',
#   'question 3-2': ' baking soda',
#   'question 3-3': ' craisins',
#   'question 3-4': ' baking soda',
#   'question 3-5': ' baking',
#   'question 3-6': ' drop by teaspoons',
#   'question 3-7': ' drop by teaspoons',
#   'question 4-0': ' baking soda',
#   'question 4-1': ' baking soda',
#   'question 4-2': ' baking soda',
#   'question 4-3': ' baking soda',
#   'question 4-4': ' baking soda',
#   'question 4-5': ' craisins',
#   'question 5-0': ' baking soda',
#   'question 5-1': ' baking soda',
#   'question 5-2': ' baking soda',
#   'question 5-3': ' baking soda',
#   'question 6-0': ' baking soda',
#   'question 7-0': ' baking soda',
#   'question 7-1': ' 12 - 14 minutes',
#   'question 8-0': ' on lightly buttered cookie sheets',
#   'question 8-1': ' in a large bowl',
#   'question 8-2': ' on lightly buttered cookie sheets'},
#  'f-4BPH5RC2': {'question 0-0': ' two steps',
#   'question 0-1': ' four actions',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 1-0': ' whiskey',
#   'question 1-1': ' flour',
#   'question 1-2': ' the',
#   'question 1-3': ' craisins',
#   'question 1-4': ' flour',
#   'question 10-0': ' pina colina',
#   'question 15-0': ' a thin batter',
#   'question 18-0': ' beat the egg white',
#   'question 18-1': ' potatoes',
#   'question 18-2': ' baking soda',
#   'question 18-3': ' cream',
#   'question 18-4': ' in a bowl',
#   'question 2-0': " `` scramble ''",
#   'question 3-0': " philippe's 1645 poem l'allegro",
#   'question 4-0': ' first',
#   'question 4-1': ' the',
#   'question 4-2': ' baking soda',
#   'question 5-0': ' the',
#   'question 6-0': ' a thin batter',
#   'question 8-0': ' the',
#   'question 8-1': ' a bowl',
#   'question 8-2': ' newspaper'},
#  'f-4HWM88HF': {'question 12-0': ' besan',
#   'question 18-0': ' potato slices',
#   'question 18-1': ' 40 minutes',
#   'question 18-2': ' the packaging',
#   'question 18-3': ' heat oil in a karahi',
#   'question 4-0': ' heat oil in a karahi',
#   'question 4-1': ' karahi',
#   'question 4-2': ' a bater',
#   'question 4-3': ' dipping potato slices in besan bater',
#   'question 4-4': ' karahi',
#   'question 4-5': ' frying potato slices',
#   'question 5-0': ' in a karahi',
#   'question 8-0': ' in a karahi',
#   'question 8-1': ' karahi'},
#  'f-4Z5SV5FY': {'question 0-0': ' two',
#   'question 0-1': ' three',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 10-0': ' saute the scaloppine on one side',
#   'question 16-0': ' from where?',
#   'question 18-0': ' four',
#   'question 18-1': ' six to seven days',
#   'question 18-2': ' the synagogue',
#   'question 18-3': ' toasters',
#   'question 4-0': ' deglaze pan with wine',
#   'question 4-1': ' saute the scaloppine',
#   'question 4-2': ' deglaze pan with wine',
#   'question 4-3': ' the other side',
#   'question 4-4': ' saute the scaloppine 2 - 3 minutes',
#   'question 6-0': ' minced garlic',
#   'question 6-1': ' deglaze pan with wine',
#   'question 7-0': ' saute the scaloppine 2 - 3 minutes',
#   'question 7-1': ' 2 - 3 minutes',
#   'question 8-0': ' to a warmed platter',
#   'question 8-1': ' season veal scaloppine with salt and pepper',
#   'question 8-2': ' the',
#   'question 8-3': ' the caribbean'},
#  'f-67M2BXM3': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 1-0': ' chocolate - chip cookies',
#   'question 1-1': ' sugar',
#   'question 10-0': ' eggs',
#   'question 10-1': " `` whisk ''",
#   'question 16-0': ' the fridge',
#   'question 18-0': ' sugar',
#   'question 18-1': ' whisk the flour in',
#   'question 18-2': ' center of the plate',
#   'question 18-3': ' in a',
#   'question 2-0': " `` buttery ''",
#   'question 3-0': ' sugar',
#   'question 3-1': ' sugar',
#   'question 3-2': ' baking soda',
#   'question 3-3': ' sugar',
#   'question 3-4': ' take the butter out of the fridge',
#   'question 3-5': ' the',
#   'question 3-6': ' the',
#   'question 3-7': ' the',
#   'question 4-0': 'Preheat the stove at 350f',
#   'question 5-0': ' 20 - 25 minutes',
#   'question 7-0': ' bake for hours',
#   'question 8-0': ' the middle of the playground'},
#  'f-88XKC27N': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 1-0': ' rice, noodles or as is',
#   'question 10-0': ' as is',
#   'question 18-0': ' three',
#   'question 18-1': ' as is',
#   'question 18-2': ' before serving',
#   'question 18-3': ' the',
#   'question 2-0': ' before serving',
#   'question 2-1': ' saucepot',
#   'question 3-0': ' vinegar',
#   'question 3-1': ' lentils',
#   'question 3-2': ' lentils',
#   'question 3-3': ' lentils',
#   'question 3-4': ' lentils',
#   'question 3-5': ' rinse the lentils with water',
#   'question 3-6': ' rinse the lentils with water',
#   'question 3-7': ' rinse the lentils with water',
#   'question 3-8': ' rinse the lentils with water',
#   'question 3-9': ' rinse the lentils with water',
#   'question 4-0': ' before serving',
#   'question 4-1': ' before serving',
#   'question 4-2': ' before serving',
#   'question 4-3': ' before serving',
#   'question 4-4': ' as is',
#   'question 6-0': ' Rinse the lentils with water'},
#  'f-8KG2VBC7': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 1-0': ' rice',
#   'question 1-1': ' soy beans',
#   'question 1-2': ' soy beans',
#   'question 10-0': ' remove bones from canned fish',
#   'question 13-0': ' soy beans',
#   'question 15-0': ' when',
#   'question 16-0': ' remove bones from canned fish',
#   'question 18-0': ' two steps',
#   'question 18-1': ' edamame',
#   'question 3-0': ' edamame',
#   'question 3-1': ' remove bones from canned fish',
#   'question 4-0': ' when rice is almost cooked',
#   'question 4-1': 'When rice is almost cooked',
#   'question 4-2': ' remove bones from canned fish',
#   'question 4-3': ' removal of bones',
#   'question 4-4': ' removal of bones',
#   'question 4-5': ' remove bones from canned fish',
#   'question 7-0': ' when rice is almost cooked',
#   'question 7-1': ' when rice is almost cooked',
#   'question 8-0': ' one or two fingers'},
#  'f-8Q86RWDJ': {'question 0-0': ' four',
#   'question 0-1': ' how many pots are used',
#   'question 0-2': ' two',
#   'question 0-3': ' 7',
#   'question 1-0': ' pudding mix',
#   'question 1-1': ' pudding mix',
#   'question 1-2': 'vegetarian - french - onion - soup',
#   'question 1-3': 'vegetarian - french - onion - soup',
#   'question 10-0': ' in a large skillet',
#   'question 12-0': ' the top of the dish',
#   'question 12-1': ' oil',
#   'question 14-0': ' preheat the oven to 350deg f',
#   'question 15-0': ' 7',
#   'question 18-0': ' wine',
#   'question 18-1': ' cream the butter or margarine',
#   'question 2-0': ' the',
#   'question 2-1': " `` throwing ''",
#   'question 2-2': ' how do you stir the cognac',
#   'question 2-3': ' whisk together in a large bowl',
#   'question 2-4': ' where you ladle the soup',
#   'question 2-5': ' where you set the bowls',
#   'question 2-6': ' baking soda',
#   'question 3-0': ' 7',
#   'question 3-1': ' 7',
#   'question 4-0': " `` the last one ''",
#   'question 4-1': ' whiskey',
#   'question 4-2': ' cheese on top',
#   'question 4-3': ' first',
#   'question 4-4': ' 7',
#   'question 5-0': ' stir the onion mixture frequently',
#   'question 6-0': ' 7',
#   'question 7-0': ' slowly melt the butter',
#   'question 7-1': ' 40 minutes',
#   'question 8-0': ' where you set the bowls',
#   'question 8-1': ' set the bowl on the table',
#   'question 8-2': ' in a large skillet'},
#  'f-CKJFC4NR': {'question 0-0': ' three',
#   'question 0-1': ' two',
#   'question 0-2': ' four actions',
#   'question 0-3': ' four actions',
#   'question 1-0': ' jam',
#   'question 18-0': ',',
#   'question 18-1': ' jam',
#   'question 18-2': ' in the digestive tract',
#   'question 2-0': ' in a large bowl',
#   'question 2-1': ' in a small bowl',
#   'question 2-2': ' in a large bowl',
#   'question 2-3': ' in a large bowl',
#   'question 2-4': ' whisk together jam and water',
#   'question 3-0': ' jam',
#   'question 3-1': ' jam',
#   'question 3-2': ',',
#   'question 3-3': ',',
#   'question 4-0': ' place all salad ingredients in a large bowl',
#   'question 4-1': ' serve salad sprinkled with cashews',
#   'question 4-2': ' jam',
#   'question 4-3': ' jam and water',
#   'question 4-4': ' dressing',
#   'question 4-5': ' jam and water',
#   'question 5-0': ' toss',
#   'question 8-0': ' in a small bowl',
#   'question 8-1': ' in a large bowl'},
#  'f-CYTQDZKG': {'question 0-0': ' 10 to 14 hours',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 1-0': ' milk',
#   'question 1-1': ' milk',
#   'question 1-2': ' milk',
#   'question 1-3': ' milk',
#   'question 1-4': ' milk',
#   'question 1-5': ' milk',
#   'question 1-6': ' milk',
#   'question 10-0': ' the yogurt maker',
#   'question 11-0': ' the',
#   'question 12-0': ' in a sterile glass bowl or measuring cup',
#   'question 12-1': ' container i make the yogurt in',
#   'question 12-2': ' the yogurt maker',
#   'question 14-0': ' heat the milk in a sterilized saucepan',
#   'question 17-0': ' the',
#   'question 17-1': ' the',
#   'question 17-10': ' in a sterile glass bowl or measuring cup',
#   'question 17-2': ' in a sterile glass bowl',
#   'question 17-3': ' in a sterile glass bowl or measuring cup',
#   'question 17-4': ' in',
#   'question 17-5': ' the',
#   'question 17-6': ' the',
#   'question 17-7': ' the',
#   'question 17-8': ' in the fridge',
#   'question 17-9': ' the fridge',
#   'question 18-0': ' the packaging',
#   'question 18-1': " `` boiling ''",
#   'question 18-2': ' the yogurt maker',
#   'question 18-3': ' the middle of the bowl',
#   'question 2-0': ' the',
#   'question 2-1': ' strain your milk mixture',
#   'question 2-10': ' the yogurt maker',
#   'question 2-11': ' the fridge',
#   'question 2-2': ' the yogurt maker',
#   'question 2-3': ' the',
#   'question 2-4': ' in a sterile glass bowl',
#   'question 2-5': ' the yogurt maker',
#   'question 2-6': ' the yogurt maker',
#   'question 2-7': ' in a sterile glass bowl or measuring cup',
#   'question 2-8': ' in a sterile glass bowl',
#   'question 2-9': ' the yogurt maker',
#   'question 3-0': ' milk',
#   'question 3-1': ' milk',
#   'question 4-0': ' milk',
#   'question 4-1': ' milk',
#   'question 4-2': ' the',
#   'question 5-0': ' the yogurt maker',
#   'question 5-1': ' to',
#   'question 5-2': ' strain the mixture',
#   'question 6-0': " `` patty ''",
#   'question 7-0': ' 10 to 14 hours',
#   'question 8-0': ' the yogurt maker',
#   'question 8-1': ' in a sterile glass bowl or measuring cup',
#   'question 8-2': ' in my saucepan',
#   'question 8-3': ' the packaging',
#   'question 8-4': ' the yogurt maker',
#   'question 9-0': ' 1 / 2 tsp',
#   'question 9-1': ' half gallon'},
#  'f-D7RYT56T': {'question 0-0': ' four',
#   'question 0-1': ' four',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 1-0': ' j',
#   'question 1-1': ' pasty dough',
#   'question 10-0': ' form a pasty dough',
#   'question 14-0': ' how to preheat oven',
#   'question 15-0': ' pasty dough',
#   'question 18-0': ' in a large bowl',
#   'question 18-1': ' in your garret',
#   'question 18-2': ' the',
#   'question 18-3': ' pudding mix',
#   'question 18-4': ' in a large bowl',
#   'question 2-0': ' form small crumbs',
#   'question 2-1': ' form a pasty dough',
#   'question 2-2': ' form a pasty dough',
#   'question 2-3': ' the',
#   'question 2-4': ' pasty dough',
#   'question 3-0': ' the',
#   'question 3-1': ' craisins',
#   'question 4-0': ' craisins',
#   'question 4-1': ' pasty',
#   'question 4-2': ' baking soda',
#   'question 6-0': ' form a pasty dough',
#   'question 6-1': ' form a pasty dough',
#   'question 7-0': ' 30 minutes before serving',
#   'question 8-0': ' in a large bowl'},
#  'f-F5SF7H44': {'question 0-0': ' 10',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' 5',
#   'question 1-0': ' whole wheat flour',
#   'question 10-0': ' whole wheat flour',
#   'question 10-1': ' whole wheat flour',
#   'question 12-0': ' changing the capsium',
#   'question 13-0': ' whole wheat flour',
#   'question 15-0': ' whole wheat flour',
#   'question 18-0': ' two',
#   'question 18-1': ' two',
#   'question 18-2': ' whole wheat flour',
#   'question 18-3': ' two',
#   'question 18-4': ' tomato sauce',
#   'question 2-0': ' whole wheat flour',
#   'question 2-1': ' whole wheat flour',
#   'question 4-0': ' whole wheat flour',
#   'question 4-1': ' whole wheat flour',
#   'question 4-2': ' whole wheat flour',
#   'question 5-0': ' whole wheat flour',
#   'question 8-0': ' toasted tofu',
#   'question 8-1': ' whole wheat flour',
#   'question 8-2': ' whole wheat flour'},
#  'f-FS6V8XD5': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two steps',
#   'question 0-5': ' two steps',
#   'question 1-0': ' scones',
#   'question 1-1': ' flour',
#   'question 1-2': ' loin',
#   'question 1-3': ' flour',
#   'question 10-0': ' baking soda',
#   'question 10-1': ' gently wash the tops of the scones',
#   'question 14-0': ' how to preheat your oven',
#   'question 17-0': ' in',
#   'question 17-1': ' in',
#   'question 18-0': " `` throwing ''",
#   'question 18-1': ' in the digestive tract',
#   'question 18-2': ' in the digestive tract',
#   'question 2-0': ' in',
#   'question 2-1': 'Make a well in the center',
#   'question 2-2': ' in a large bowl',
#   'question 2-3': ' cut in the butter',
#   'question 2-4': ' in a large bowl',
#   'question 2-5': ' in a large bowl',
#   'question 2-6': ' in',
#   'question 2-7': ' baking soda',
#   'question 3-0': ' the',
#   'question 3-1': ' pudding mix',
#   'question 3-2': ' the',
#   'question 3-3': ',',
#   'question 3-4': ' the',
#   'question 3-5': ' the',
#   'question 3-6': ' the',
#   'question 4-0': ' baking soda',
#   'question 4-1': ' baking soda',
#   'question 4-2': ' baking soda',
#   'question 4-3': ' baking soda',
#   'question 4-4': ' the',
#   'question 4-5': ' baking',
#   'question 5-0': ' cut in the butter',
#   'question 5-1': ' the',
#   'question 5-2': ' baking soda',
#   'question 6-0': ' with your fingers',
#   'question 6-1': ' ``',
#   'question 7-0': ' 40 minutes',
#   'question 8-0': ' in a large bowl',
#   'question 8-1': 'Make a well in the center',
#   'question 8-2': ' in the digestive tract',
#   'question 8-3': ' between two pieces of wax paper'},
#  'f-HX4T28NM': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two steps',
#   'question 1-0': ' crushed roasted chickpeas',
#   'question 1-1': ' curried - cauliflower - and - ginger',
#   'question 1-2': ' cauliflower',
#   'question 1-3': ' cauliflower',
#   'question 1-4': ' cauliflower',
#   'question 1-5': ' cauliflower',
#   'question 1-6': ' cauliflower',
#   'question 1-7': ' salt and pepper',
#   'question 10-0': ' with crushed roasted chickpeas',
#   'question 16-0': ' from the',
#   'question 18-0': ' milk',
#   'question 18-1': ' curried - cauliflower',
#   'question 18-2': ' baking',
#   'question 18-3': ' curried - cauliflower - and - ginger',
#   'question 18-4': ' three steps',
#   'question 2-0': ' cauliflower in the pot',
#   'question 2-1': ' in a pot with',
#   'question 2-2': ' saucepot',
#   'question 3-0': ' chicken stock',
#   'question 3-1': ' crushed roasted chickpeas',
#   'question 3-2': ' placing the cauliflower in the pot',
#   'question 3-3': ' placing the cauliflower in the pot',
#   'question 3-4': ' the',
#   'question 4-0': ' cauliflower',
#   'question 4-1': ' cauliflower',
#   'question 4-2': ' cauliflower is tender',
#   'question 4-3': ' process the cauliflower',
#   'question 4-4': ' puree using an immersion blender',
#   'question 4-5': ' chicken stock',
#   'question 5-0': ' to saute the onion',
#   'question 5-1': ' until the cauliflower is tender',
#   'question 5-2': ' until tender',
#   'question 6-0': ' process the cauliflower',
#   'question 6-1': ' using an immersion blender',
#   'question 7-0': ' 15 minuets',
#   'question 8-0': ' in the pot',
#   'question 8-1': ' in a medium - sized dutch oven'},
#  'f-JLH74DCR': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' in a medium, securely sealable container',
#   'question 0-3': ' in a medium, securely sealable container',
#   'question 0-4': ' three',
#   'question 1-0': ' pickled - cucumbers',
#   'question 12-0': ' the marinade',
#   'question 18-0': ' rough chop cucumbers',
#   'question 18-1': ' two',
#   'question 18-2': ' three',
#   'question 2-0': ' rough chop cucumbers',
#   'question 3-0': ' rough chop cucumbers',
#   'question 3-1': ' in',
#   'question 3-2': ' sesame oil',
#   'question 3-3': ' the',
#   'question 4-0': ' the',
#   'question 4-1': ' the',
#   'question 8-0': ' in a medium, securely sealable container',
#   'question 8-1': ' in a medium, securely sealable container'},
#  'f-KTQ82N6L': {'question 0-0': ' two',
#   'question 0-1': ' four',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 0-5': ' three',
#   'question 1-0': ' cheese',
#   'question 1-1': ' bread',
#   'question 1-2': ' cream',
#   'question 10-0': ' a large bowl',
#   'question 10-1': ' a hollowed - out bread round',
#   'question 16-0': " `` thirteenth '' moment",
#   'question 17-0': ' in a small skillet',
#   'question 18-0': ' how do you toast saffron threads',
#   'question 18-1': ' in a small skillet',
#   'question 18-2': ' three',
#   'question 18-3': ' potatoes',
#   'question 2-0': ' whisk in the flour',
#   'question 2-1': ' in a large bowl',
#   'question 2-2': ' in a saucepan',
#   'question 2-3': ' in a small skillet',
#   'question 2-4': ' whisk the flour over low heat',
#   'question 3-0': ' easy -',
#   'question 3-1': ' easy -',
#   'question 3-2': ' cream',
#   'question 3-3': ' cream',
#   'question 4-0': ' tabasco',
#   'question 4-1': ' cheese',
#   'question 4-2': ' bacon grease',
#   'question 4-3': ' Bacon',
#   'question 4-4': ' bacon',
#   'question 4-5': ' bacon',
#   'question 5-0': ' heat the bacon until crisp',
#   'question 8-0': " `` trolley ''",
#   'question 8-1': ' in a small skillet'},
#  'f-KWBKC77L': {'question 0-0': ' three',
#   'question 0-1': ' three',
#   'question 0-2': ' three',
#   'question 0-3': ' three',
#   'question 0-4': ' two',
#   'question 1-0': ' potatoes',
#   'question 1-1': ' potatoes',
#   'question 1-2': ' potatoes',
#   'question 1-3': ' olive oil',
#   'question 1-4': ' onions',
#   'question 1-5': ' potatoes',
#   'question 1-6': ' onions',
#   'question 1-7': ' potatoes',
#   'question 13-0': ' serving bowl',
#   'question 15-0': ' boil potatoes until fork tender',
#   'question 17-0': ' the',
#   'question 17-1': ' quick',
#   'question 17-2': ' ``',
#   'question 17-3': ' sliced onion',
#   'question 17-4': ' where were the chopped garlic',
#   'question 17-5': ' before it was served',
#   'question 17-6': ' quick - and -',
#   'question 17-7': ' quick -',
#   'question 17-8': ' quick - and -',
#   'question 18-0': ' two',
#   'question 18-1': " `` trichotillomania ''",
#   'question 18-2': ' boil potatoes until fork tender',
#   'question 18-3': ' quick - and - easy',
#   'question 2-0': ' quick - and - easy',
#   'question 2-1': ' serving bowl',
#   'question 2-2': ' boil potatoes until fork tender',
#   'question 2-3': ' quick - and - easy',
#   'question 2-4': ' olive oil',
#   'question 2-5': ' serving bowl',
#   'question 2-6': ' boil potatoes until fork tender',
#   'question 4-0': ' potatoes',
#   'question 4-1': ' serving the potatoes first',
#   'question 4-2': ' the',
#   'question 5-0': ' to',
#   'question 5-1': ' quick - and - easy',
#   'question 6-0': ' drizzle of olive oil',
#   'question 8-0': ' quick - and - easy',
#   'question 8-1': ' serving bowl',
#   'question 8-2': ' serving bowl',
#   'question 8-3': ' serving bowl'},
#  'f-PT5ZVJYJ': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' on a shallow dish',
#   'question 0-3': ' two',
#   'question 1-0': ' bread crumbs',
#   'question 1-1': ' the',
#   'question 1-2': ' chicken',
#   'question 1-3': ' the pie crust',
#   'question 18-0': ' heavy cream',
#   'question 18-1': ' on a shallow dish',
#   'question 18-2': ' immersion oil',
#   'question 18-3': ' heavy cream',
#   'question 18-4': ' chicken loin',
#   'question 2-0': ' both sides',
#   'question 2-1': ' pound the chicken with your multi-tool',
#   'question 2-2': ' coat the chicken on both sides',
#   'question 2-3': ' on the',
#   'question 2-4': ' both sides',
#   'question 2-5': ' placed prior to the carving',
#   'question 2-6': " `` thopter ''",
#   'question 3-0': ' cheese',
#   'question 3-1': ' on a shallow dish',
#   'question 4-0': ' chicken',
#   'question 4-1': ' chicken',
#   'question 4-2': ' even',
#   'question 4-3': ' chicken loin',
#   'question 4-4': ' the chicken',
#   'question 4-5': ' chicken',
#   'question 5-0': ' pound the chicken breast or tights',
#   'question 5-1': ' heat the oil',
#   'question 6-0': ' on medium high',
#   'question 6-1': ' on a shallow dish',
#   'question 7-0': ' 2 to 3 minutes',
#   'question 8-0': ' smear tomato sauce over the chicken',
#   'question 8-1': ' in',
#   'question 8-10': ' on a shallow dish',
#   'question 8-2': ' on a shallow dish',
#   'question 8-3': ' on both sides',
#   'question 8-4': ' the chicken',
#   'question 8-5': ' in a large bowl',
#   'question 8-6': ' both sides',
#   'question 8-7': ' the egg mixture',
#   'question 8-8': ' in a large saute pan',
#   'question 8-9': ' in a'},
#  'f-Q7FS58VW': {'question 0-0': ' two',
#   'question 0-1': ' two or four',
#   'question 0-2': ' three',
#   'question 0-3': ' two',
#   'question 1-0': ' mozzarella',
#   'question 1-1': ' mussels',
#   'question 1-10': ' tomatoes',
#   'question 1-11': ' mussels',
#   'question 1-12': ' mussels',
#   'question 1-13': ' mussels',
#   'question 1-14': ' mussels',
#   'question 1-2': ' mussels',
#   'question 1-3': ' heavy cream',
#   'question 1-4': ' mozzarella',
#   'question 1-5': ' mussels',
#   'question 1-6': ' mint',
#   'question 1-7': ' heavy cream',
#   'question 1-8': ' mussels',
#   'question 1-9': ' mussels',
#   'question 10-0': ' mint leaves',
#   'question 10-1': ' Wash mussels and de-beard',
#   'question 10-2': ' top with mint and coriander',
#   'question 12-0': ' the',
#   'question 13-0': ' big chilies',
#   'question 14-0': ' cook mussels',
#   'question 17-0': ' the',
#   'question 17-1': ' where the accent was',
#   'question 17-2': ' the',
#   'question 17-3': ' washing the mussels',
#   'question 17-4': ' the',
#   'question 18-0': ' in the',
#   'question 18-1': ' serve on a platter',
#   'question 2-0': ' in a large bowl',
#   'question 2-1': ' in a mixing bowl',
#   'question 2-2': ' top with mint and coriander leaves',
#   'question 2-3': ' sliced tomatoes into thin wedges',
#   'question 2-4': ' a hole in the ground',
#   'question 2-5': ' a pot of water',
#   'question 2-6': ' Wash mussels and de-beard',
#   'question 2-7': ' the',
#   'question 2-8': ' the',
#   'question 2-9': ' Wash squids and de-beard',
#   'question 3-0': ' Wash mussels and de-beard',
#   'question 3-1': ' mussels',
#   'question 4-0': ' mussels',
#   'question 4-1': ' mussels',
#   'question 4-2': ' mint leave',
#   'question 4-3': ' Wash squids and de-beard',
#   'question 4-4': ' the',
#   'question 6-0': ' Wash squids and cut into bite size',
#   'question 8-0': ' a mixing bowl',
#   'question 8-1': ' platter lined with lettuce',
#   'question 8-2': ' mussels'},
#  'f-RYVXFZFV': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 1-0': ' gremolata',
#   'question 1-1': ' potatoes',
#   'question 1-2': ' rice, noodles or as is',
#   'question 12-0': ' the pot you are in',
#   'question 18-0': ' heat a small frying pan',
#   'question 18-1': ' in a sauce pot',
#   'question 18-2': ' potatoes',
#   'question 18-3': ' potatoes',
#   'question 2-0': ' in the small bowl',
#   'question 2-1': ' a large saute pan',
#   'question 2-2': ' in a sauce pot',
#   'question 2-3': " `` thirteenth '' task",
#   'question 2-4': " `` patty ''",
#   'question 4-0': 'When ready to serve',
#   'question 4-1': ' strat',
#   'question 6-0': ' heat a small frying pan',
#   'question 8-0': ' in a large saute pan',
#   'question 8-1': ' in a small bowl'},
#  'f-SJGXB864': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' four',
#   'question 0-5': ' three',
#   'question 1-0': ' onions',
#   'question 1-1': ' thyme',
#   'question 10-0': 'Divide the beets and the onion into small groups',
#   'question 10-1': ' warm or chilled',
#   'question 10-2': ' in a bowl',
#   'question 10-3': 'Divide the beets into small groups',
#   'question 10-4': ' let them cook until they can be handled',
#   'question 13-0': ' Divide the beets into small groups',
#   'question 14-0': ' preheat the oven to 350 f',
#   'question 15-0': ' until they can be handled',
#   'question 17-0': ' the',
#   'question 17-1': ' beets',
#   'question 17-2': ' in mixing bowl',
#   'question 17-3': ' the',
#   'question 18-0': ' the pie crust',
#   'question 18-1': ' beet',
#   'question 18-2': ' divided equally',
#   'question 18-3': ' grate 1 / 2 tsp',
#   'question 18-4': ' roll out the pie crust',
#   'question 2-0': ' warm or chilled',
#   'question 2-1': ' peel the beets',
#   'question 2-2': 'Divide the beets and the onion into small groups',
#   'question 2-3': ' preheat oven to 350f',
#   'question 2-4': ' in',
#   'question 3-0': ' beets',
#   'question 3-1': ' beets',
#   'question 3-2': ' heavy cream and eggs',
#   'question 3-3': 'Divide the beets and the onion into small groups',
#   'question 4-0': ' beets',
#   'question 4-1': ' the onion',
#   'question 4-2': ' the beets',
#   'question 5-0': ' wrap the groups in aluminum foil',
#   'question 6-0': 'Divide the beets and the onion into small groups',
#   'question 7-0': ' until they are tender',
#   'question 8-0': ' in a bowl',
#   'question 8-1': ' a serving bowl'},
#  'f-SJPFNVTY': {'question 0-0': ' two',
#   'question 0-1': ' 12',
#   'question 0-2': ' two',
#   'question 0-3': ' four',
#   'question 1-0': ' the',
#   'question 1-1': ' the',
#   'question 1-2': ' ice cream',
#   'question 1-3': ' chocolate chips',
#   'question 1-4': ' heavy cream',
#   'question 10-0': ' one by one',
#   'question 10-1': ' one',
#   'question 12-0': ' warm water',
#   'question 17-0': ' the',
#   'question 17-1': ' in the moulds',
#   'question 17-2': ' the',
#   'question 17-3': ' the',
#   'question 18-0': ' 40 minutes',
#   'question 18-1': ' the',
#   'question 18-2': ' in the',
#   'question 2-0': ' a large bowl',
#   'question 2-1': ' set aside',
#   'question 2-2': ' one by one',
#   'question 2-3': ' one by one',
#   'question 2-4': ' on lightly buttered cookie sheets',
#   'question 2-5': ' the packaging',
#   'question 3-0': ' your parents',
#   'question 3-1': ' heavy cream',
#   'question 4-0': ' adding the wet ingredients',
#   'question 4-1': ' first',
#   'question 4-2': 'Mix all the dry ingredients',
#   'question 4-3': ' the',
#   'question 4-4': ' polish raais',
#   'question 4-5': ' first',
#   'question 5-0': ' baking soda',
#   'question 6-0': ' with a wire whisk',
#   'question 6-1': ' with an ice cream scoop',
#   'question 7-0': ' 20 minutes',
#   'question 8-0': ' in the moulds',
#   'question 9-0': ' 3 / 4 full'},
#  'f-XNVJGJVP': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 0-5': ' two tablespoons',
#   'question 1-0': ' potatoes',
#   'question 1-1': ' pan',
#   'question 1-2': ' heavy cream',
#   'question 1-3': ' heavy cream',
#   'question 1-4': ' excess juice',
#   'question 1-5': ' placed on paper towels',
#   'question 10-0': ' heavy cream',
#   'question 10-1': ' turn over the batter',
#   'question 15-0': ' placed on paper towels',
#   'question 17-0': ' sliced onion before it was tossed',
#   'question 17-1': ' in a large skillet',
#   'question 17-2': ' place about 1 / 2 inch',
#   'question 17-3': ' in a kitchen towel',
#   'question 17-4': ' in a kitchen towel',
#   'question 17-5': ' in a kitchen towel',
#   'question 17-6': ' in a kitchen towel',
#   'question 18-0': ' heavy cream',
#   'question 18-1': ' in a large bowl',
#   'question 18-2': ' place about 1 / 2 inch',
#   'question 18-3': ' in a food processor',
#   'question 18-4': ' a gps tracker',
#   'question 2-0': ' using two tablespoons',
#   'question 2-1': ' into the oil',
#   'question 2-2': ' in a large skillet',
#   'question 2-3': ' in large bowl',
#   'question 2-4': ' in a large bowl',
#   'question 3-0': ' the',
#   'question 3-1': ' the',
#   'question 3-2': ' heavy cream',
#   'question 3-3': ' heavy cream',
#   'question 4-0': ' on the other side',
#   'question 4-1': ' first',
#   'question 4-2': ' food processor',
#   'question 4-3': ' first',
#   'question 4-4': ' place on paper towels',
#   'question 4-5': ' place the shredded potato and onion in a kitchen towel',
#   'question 6-0': ' using two tablespoons',
#   'question 6-1': ' place the shredded potato and onion in a kitchen towel',
#   'question 8-0': ' in a kitchen towel',
#   'question 8-1': ' in a large cast iron frying pan',
#   'question 8-2': ' in a kitchen towel',
#   'question 8-3': ' in the food processor',
#   'question 8-4': ' on paper towels',
#   'question 8-5': ' in a large skillet'},
#  'f-YGBD7J2L': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two identical 2x2 pictures',
#   'question 0-4': ' two',
#   'question 1-0': ' kidney beans',
#   'question 1-1': ' pudding mix',
#   'question 1-2': ' tortilla',
#   'question 1-3': ' heart',
#   'question 14-0': ' cut into squares',
#   'question 14-1': ' preheat the oven to 350 ° f',
#   'question 17-0': ' the',
#   'question 17-1': ' in',
#   'question 17-2': ' in a food processor',
#   'question 17-3': ' the packaging',
#   'question 18-0': ' arranging the spears in alphabetical order',
#   'question 18-1': ' heart',
#   'question 18-2': ' baking soda',
#   'question 2-0': ' in a food processor',
#   'question 2-1': ' in a food processor',
#   'question 2-2': ' in a food processor',
#   'question 2-3': ' puree kidney beans and beets',
#   'question 3-0': ' in',
#   'question 3-1': ' kidney beans',
#   'question 4-0': ' baking soda',
#   'question 4-1': ' preheat oven to 350 ° f',
#   'question 4-2': ' in a food processor',
#   'question 4-3': ' baking soda',
#   'question 4-4': ' preheat the oven to 350 ° f',
#   'question 5-0': ' by hand',
#   'question 6-0': ' puree kidney beans and beets',
#   'question 6-1': ' in a food processor',
#   'question 7-0': ' 35 - 40 minutes',
#   'question 7-1': ' five days',
#   'question 8-0': ' the packaging',
#   'question 8-1': ' into the greased pan',
#   'question 8-2': ' in'},
#  'f-Z82FPVW4': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' three',
#   'question 1-0': ' garlic',
#   'question 1-1': ' garlic',
#   'question 1-2': ' garlic',
#   'question 10-0': ' as is',
#   'question 17-0': ' the',
#   'question 17-1': ' chopped garlic',
#   'question 17-2': ' the',
#   'question 18-0': ' vinegar',
#   'question 18-1': ' tort',
#   'question 2-0': ' a small frying pan',
#   'question 2-1': ' a sauce pot',
#   'question 2-2': ' sauce pot',
#   'question 2-3': ' on low',
#   'question 2-4': ' sauce pot',
#   'question 2-5': ' the',
#   'question 2-6': ' the',
#   'question 3-0': ',',
#   'question 3-1': ' grated romano cheese',
#   'question 4-0': ' before serving',
#   'question 4-1': ' the',
#   'question 4-2': ' the lentil mixture',
#   'question 4-3': ' garlic',
#   'question 4-4': ' garlic',
#   'question 4-5': ' onion',
#   'question 5-0': ' toss the breadcrumbs',
#   'question 6-0': ' on low',
#   'question 7-0': ' 25 - 30 minutes'},
#  'r-1007': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two steps',
#   'question 1-0': ' the',
#   'question 1-1': ' cake',
#   'question 17-0': ' in',
#   'question 17-1': ' the',
#   'question 17-2': ' in a',
#   'question 18-0': ' two',
#   'question 18-1': ' in a pre-heated oven',
#   'question 2-0': ' when cool',
#   'question 2-1': ' in a pre-heated oven',
#   'question 2-2': ' put the mixture in 12 paper liners',
#   'question 2-3': ' in a bun tin',
#   'question 3-0': ' craisins',
#   'question 3-1': ' the',
#   'question 3-2': ' the',
#   'question 4-0': ' put the mixture into a piping - bag',
#   'question 4-1': ' put the mixture into a bun tin',
#   'question 4-2': ' putting the mixture into a piping - bag',
#   'question 4-3': ' when cool',
#   'question 4-4': ' baking soda',
#   'question 4-5': ' baking soda',
#   'question 5-0': ' bake',
#   'question 6-0': ' drop by teaspoons',
#   'question 6-1': ' using a circular movement',
#   'question 8-0': ' in a bun tin',
#   'question 8-1': ' place butter in a large bowl',
#   'question 8-2': ' the middle of the playground',
#   'question 8-3': ' in a bun tin',
#   'question 8-4': ' in a bun tin',
#   'question 8-5': ' placed in a bun tin',
#   'question 8-6': ' placed prior to the bake'},
#  'r-103': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 1-0': ' split peas',
#   'question 12-0': ' in',
#   'question 14-0': ' deep - fry',
#   'question 18-0': ' how to puree the chicken stock cauliflower',
#   'question 18-1': ' two',
#   'question 18-2': ' the',
#   'question 18-3': ' split peas',
#   'question 2-0': ' split peas',
#   'question 2-1': ' slightly flatten the balls',
#   'question 2-2': ' split peas',
#   'question 4-0': ' the',
#   'question 4-1': ' split peas',
#   'question 8-0': ' in a large bowl',
#   'question 9-0': ' slightly flatten the balls'},
#  'r-1031': {'question 0-0': ' four',
#   'question 0-1': ' four',
#   'question 0-2': ' two',
#   'question 0-3': ' four steps',
#   'question 0-4': ' three steps',
#   'question 1-0': ' heavy cream',
#   'question 1-1': ' hard cooked eggs',
#   'question 1-2': ' heavy cream',
#   'question 1-3': ' heavy cream',
#   'question 1-4': ' chopped ham',
#   'question 1-5': ' bacon',
#   'question 12-0': ' lettuce',
#   'question 12-1': ' in a large bowl',
#   'question 17-0': ' add hot mashed potatoes',
#   'question 17-1': ' in a small skillet',
#   'question 18-0': ' heavy cream',
#   'question 18-1': ' tortilla',
#   'question 2-0': ' in a small skillet',
#   'question 2-1': ' in a small skillet',
#   'question 2-2': ' blend vinegar and sugar',
#   'question 2-3': ' in a large bowl',
#   'question 2-4': ' pour over hot dressing',
#   'question 2-5': ' in',
#   'question 2-6': ' in',
#   'question 3-0': ',',
#   'question 3-1': ' hot mashed potatoes',
#   'question 3-2': ' a boy',
#   'question 3-3': ' onion',
#   'question 3-4': ' chopped ham',
#   'question 4-0': ' d',
#   'question 4-1': ' bacon',
#   'question 4-2': ' d',
#   'question 4-3': ' frying bacon',
#   'question 4-4': 'Add hot mashed potatoes',
#   'question 4-5': ' bacon drippings',
#   'question 8-0': ' in a large bowl',
#   'question 8-1': ' in'},
#  'r-1043': {'question 0-0': ' three steps',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 1-0': ' yeast',
#   'question 1-1': ' yeast',
#   'question 1-2': ' pie crust',
#   'question 1-3': ' bread',
#   'question 1-4': ' bread',
#   'question 1-5': ' yeast',
#   'question 1-6': ' bread',
#   'question 1-7': ' yeast',
#   'question 12-0': ' alcohol',
#   'question 15-0': ' to rise',
#   'question 15-1': ' the',
#   'question 15-2': ' to rise',
#   'question 15-3': ' a soft batter',
#   'question 17-0': ' in',
#   'question 17-1': ' the',
#   'question 17-2': ' in',
#   'question 18-0': ' in mixing bowl',
#   'question 18-1': ' in a large bowl',
#   'question 18-2': ' spade',
#   'question 18-3': ' Dissolve yeast in warm water',
#   'question 2-0': ' in a large bowl',
#   'question 2-1': ' a',
#   'question 2-2': ' in',
#   'question 2-3': ' Dissolve yeast in warm water',
#   'question 2-4': ' beat eggs',
#   'question 2-5': ' in a small skillet',
#   'question 2-6': ' Dissolve yeast in warm water',
#   'question 2-7': ' in a large bowl',
#   'question 2-8': ' Dissolve yeast in warm water',
#   'question 3-0': ' raised yeast',
#   'question 3-1': ' cheese',
#   'question 3-2': ' raised yeast',
#   'question 3-3': ' raised yeast',
#   'question 3-4': ' raised yeast',
#   'question 4-0': ' baking',
#   'question 4-1': ' beat eggs',
#   'question 4-2': ' the',
#   'question 4-3': ' a soft batter',
#   'question 4-4': ' first',
#   'question 4-5': ' bacon',
#   'question 5-0': ' heat the oil and butter',
#   'question 6-0': ' in warm water',
#   'question 7-0': ' 2 minutes',
#   'question 7-1': ' about 2 or 3 hours',
#   'question 7-2': ' 40 minutes',
#   'question 8-0': ' a large bowl'},
#  'r-1094': {'question 0-0': ' three',
#   'question 0-1': ' two',
#   'question 0-2': ' three',
#   'question 0-3': ' four',
#   'question 0-4': ' three',
#   'question 1-0': ' chicken - curry salad',
#   'question 1-1': ' chicken',
#   'question 10-0': ' by itself or over a bed of greens',
#   'question 15-0': ',',
#   'question 17-0': ' the',
#   'question 17-1': ' in',
#   'question 18-0': 'combine water and beaten eggs',
#   'question 18-1': ' the',
#   'question 18-2': ' chicken',
#   'question 18-3': ' mayonnaise',
#   'question 2-0': ' over chicken mixture',
#   'question 2-1': ' a large bowl',
#   'question 2-2': ' over a bed of greens',
#   'question 2-3': ' chicken --',
#   'question 3-0': ' celery',
#   'question 3-1': ',',
#   'question 4-0': ' chicken -- curry salad',
#   'question 4-1': ' chicken --',
#   'question 4-2': 'Chicken --',
#   'question 4-3': ' the',
#   'question 4-4': ' chicken,',
#   'question 4-5': ' the',
#   'question 8-0': ' a large bowl',
#   'question 8-1': ' over chicken mixture'},
#  'r-1159': {'question 0-0': ' 5',
#   'question 0-1': ' three',
#   'question 0-2': ' shrikand',
#   'question 1-0': ' plain greek style yogurt',
#   'question 1-1': ' plain greek style yogurt',
#   'question 1-2': ' saffron',
#   'question 1-3': ' saffron',
#   'question 1-4': ' saffron',
#   'question 15-0': ' in muslin cloth',
#   'question 18-0': ' shrikand',
#   'question 18-1': ' water',
#   'question 18-2': ' the packaging',
#   'question 2-0': ' in a bowl',
#   'question 2-1': ' in a bowl',
#   'question 2-2': ' in a bowl',
#   'question 2-3': ' in muslin cloth',
#   'question 2-4': ' in muslin cloth',
#   'question 3-0': ' in muslin cloth',
#   'question 4-0': ' shrikand',
#   'question 4-1': ' plain greek style yogurt',
#   'question 7-0': ' 5 - 6 hours',
#   'question 8-0': ' in a bowl',
#   'question 8-1': ' in muslin cloth'},
#  'r-1165': {'question 0-0': ' two or four',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' three',
#   'question 0-4': ' three',
#   'question 1-0': ' bread',
#   'question 1-1': ' lettuce',
#   'question 1-2': ' sliced tomato',
#   'question 10-0': ' sliced hard boiled egg',
#   'question 10-1': " `` throwing ''",
#   'question 15-0': ' for best flavor',
#   'question 17-0': ' the',
#   'question 17-1': ' the',
#   'question 18-0': ' soup maker',
#   'question 18-1': ' two',
#   'question 18-2': ' with blender running',
#   'question 2-0': ' over the top',
#   'question 2-1': ' a dusting of paprika',
#   'question 2-2': ' refrigerator',
#   'question 2-3': ' in a large bowl',
#   'question 3-0': ' pudding mix',
#   'question 3-1': ' sliced hard boiled egg',
#   'question 3-2': " `` three rivers ''",
#   'question 3-3': ' h',
#   'question 4-0': ' sliced hard boiled egg',
#   'question 4-1': ' sliced hard boiled egg',
#   'question 4-2': ' the',
#   'question 4-3': ' sliced hard boiled egg',
#   'question 4-4': ' sliced hard boiled egg',
#   'question 4-5': ' the',
#   'question 7-0': 'Refrigerate for a couple of hours',
#   'question 8-0': ' spread on a platter',
#   'question 8-1': ' over the top'},
#  'r-1166': {'question 0-0': ' two',
#   'question 0-1': ' two to four minutes',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 1-0': ' mayonnaise',
#   'question 1-1': ' her',
#   'question 1-2': ' mayonnaise',
#   'question 1-3': ' herring',
#   'question 1-4': ' herring',
#   'question 10-0': ' decorate an oblong dish with lettuce leaves',
#   'question 10-1': ' gherkin and parsley',
#   'question 10-2': ' spread the mixture evenly',
#   'question 12-0': ' herring',
#   'question 15-0': ' for the garnish',
#   'question 17-0': ' the',
#   'question 17-1': ' the',
#   'question 18-0': ' two',
#   'question 18-1': ' the',
#   'question 18-2': ' the',
#   'question 2-0': ' for the garnish',
#   'question 2-1': ' peel and dice the apples',
#   'question 2-2': ' in',
#   'question 2-3': ' her',
#   'question 2-4': ' spread the mixture evenly',
#   'question 2-5': ' decorate an oblong dish with lettuce leaves',
#   'question 2-6': ' on the mayonnaise',
#   'question 2-7': ' over the lettuce leaves',
#   'question 3-0': ' the',
#   'question 3-1': ' herring',
#   'question 4-0': ' for the garnish',
#   'question 4-1': ' the',
#   'question 4-2': ' the',
#   'question 4-3': ' decorate an oblong dish with lettuce leaves',
#   'question 4-4': ' dicing the apples',
#   'question 4-5': ' herring',
#   'question 8-0': ' on the mayonnaise'},
#  'r-117': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 0-5': ' two',
#   'question 1-0': ' fish fritters',
#   'question 1-1': ' fish',
#   'question 1-2': ' fish',
#   'question 1-3': ' fish',
#   'question 1-4': ' fish',
#   'question 14-0': ' fish fritters',
#   'question 16-0': ' fish fritters',
#   'question 17-0': ' the',
#   'question 18-0': ' fish fritters',
#   'question 18-1': ' fish',
#   'question 2-0': ' fish fritters',
#   'question 2-1': ' moisten your hands with water',
#   'question 2-2': ' fish fritters',
#   'question 2-3': ' fish fritters',
#   'question 2-4': ' in a mortar',
#   'question 2-5': ' in a mortar',
#   'question 3-0': ' the',
#   'question 3-1': ' fish fritters',
#   'question 4-0': ' fish fritters',
#   'question 4-1': ' fish fritters',
#   'question 4-2': ' fish fritters',
#   'question 5-0': ' heat oil in a pan',
#   'question 6-0': ' fish fritters',
#   'question 6-1': ' fish fritters',
#   'question 7-0': ' 10 - 12 minutes',
#   'question 7-1': ' 4 -- 5 minutes',
#   'question 8-0': ' fish fritters',
#   'question 8-1': ' on your palm',
#   'question 8-2': ' in a pan'},
#  'r-1275': {'question 0-0': ' four',
#   'question 0-1': ' two',
#   'question 0-2': ' five',
#   'question 0-3': ' two steps',
#   'question 1-0': ' spreading with the spatula',
#   'question 1-1': ' the topping',
#   'question 1-2': ' cake flour',
#   'question 1-3': ' the',
#   'question 1-4': ' butter',
#   'question 1-5': ' pie crust',
#   'question 10-0': ' beat the eggs and sugar',
#   'question 10-1': ' beat the butter with a multi-tool',
#   'question 10-2': ' cut the cake in two',
#   'question 10-3': ' press chopped almonds lightly',
#   'question 17-0': ' when the cake is cold',
#   'question 18-0': ' four actions',
#   'question 18-1': ' first',
#   'question 18-2': ' marble',
#   'question 18-3': ' bake',
#   'question 2-0': ' spread the filling over the top',
#   'question 2-1': ' press chopped almonds around the edge',
#   'question 2-2': 'When the cake is cold',
#   'question 2-3': ' press chopped almonds lightly',
#   'question 2-4': ' beat the butter with a multi-tool',
#   'question 2-5': ' beat the eggs and sugar',
#   'question 2-6': ' in a large bowl',
# ...
#   'question 8-1': ' with blender running'},
#  'r-4856': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' three',
#   'question 0-3': ' four',
#   'question 0-4': ' two',
#   'question 1-0': ' heavy cream',
#   'question 1-1': ' pie crust',
#   'question 1-2': ' pie crust',
#   'question 1-3': ' cookie sheet',
#   'question 1-4': ' the',
#   'question 1-5': ' scones',
#   'question 10-0': 'Cool thoroughly before serving',
#   'question 10-1': ' drop by teaspoons',
#   'question 17-0': ' polish raais',
#   'question 18-0': ' four',
#   'question 18-1': ' drop by teaspoons',
#   'question 18-2': ' two',
#   'question 18-3': ' in a large skillet',
#   'question 2-0': ' on greased baking sheet',
#   'question 2-1': ' in aieve',
#   'question 3-0': ',',
#   'question 3-1': ' peanut butter',
#   'question 3-2': ',',
#   'question 3-3': ',',
#   'question 3-4': ' heavy cream',
#   'question 3-5': ' peanut butter',
#   'question 4-0': ' polish raais',
#   'question 4-1': ' roll into walnut sized balls',
#   'question 4-2': ' cookies',
#   'question 4-3': ' peanut butter',
#   'question 4-4': 'oatouse',
#   'question 4-5': ' polish raisin',
#   'question 6-0': ' roll into walnut sized balls',
#   'question 6-1': ' flatten with a fork',
#   'question 7-0': ' 3 hours',
#   'question 7-1': ' 10 to 12 minutes',
#   'question 8-0': ' placed prior to the carving'},
#  'r-4969': {'question 0-0': ' four',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 1-0': ' tomato',
#   'question 1-1': ' tortilla chips',
#   'question 10-0': ' coarsely mash',
#   'question 10-1': ' serve with tortilla chips',
#   'question 18-0': ' coarsely mash ( do not puree )',
#   'question 18-1': ' chilies',
#   'question 18-2': ' 3 / 4 tsp',
#   'question 18-3': ' cereal bowl',
#   'question 2-0': ' coarsely mash',
#   'question 3-0': ' chilies',
#   'question 3-1': ' chilies',
#   'question 3-2': ' from a victim',
#   'question 4-0': 'Coarsely mash california avocados',
#   'question 4-1': ' tomato',
#   'question 4-2': 'Coarsely mash ( do not puree )',
#   'question 4-3': ' co',
#   'question 4-4': ' tomato',
#   'question 4-5': ' serving the guacamole first',
#   'question 8-0': ' in a food processor'},
#  'r-5062': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' three',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 1-0': ' potatoes',
#   'question 1-1': " vegetables'n'things",
#   'question 10-0': ' beer - fried',
#   'question 10-1': ' beer - fried',
#   'question 14-0': ' beer - fried',
#   'question 18-0': ' four',
#   'question 18-1': ' artichoke mixture',
#   'question 2-0': ' in large bowl',
#   'question 2-1': ' beer - fried',
#   'question 3-0': ' beer',
#   'question 3-1': " suggested veggies'n'things",
#   'question 3-2': " dip suggested veggies'n'things",
#   'question 3-3': ' beer',
#   'question 4-0': ' beer - fried',
#   'question 4-1': ' beer - fried',
#   'question 4-2': ' beer - fried',
#   'question 4-3': ' beer',
#   'question 4-4': ' the fryer',
#   'question 5-0': ' process the mustard',
#   'question 5-1': ' fry the coated veggy',
#   'question 6-0': ' beer - fried',
#   'question 7-0': ' 10 minutes',
#   'question 8-0': ' the digestive tract',
#   'question 8-1': ' deep fat fryer',
#   'question 8-2': ' deep fat fryer',
#   'question 8-3': ' in large bowl'},
#  'r-5079': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' four',
#   'question 1-0': ' tortilla chips',
#   'question 1-1': ' tomatoes',
#   'question 10-0': ' the',
#   'question 18-0': ' tortilla',
#   'question 18-1': " `` creeper ''",
#   'question 18-2': ' stirred together',
#   'question 18-3': ' in a saucepot',
#   'question 18-4': ' where were the cumin?',
#   'question 2-0': ' bowl',
#   'question 2-1': ' in',
#   'question 3-0': ',',
#   'question 3-1': ',',
#   'question 3-2': ' chopped cilantro',
#   'question 4-0': ' serve with tortilla chips',
#   'question 4-1': ' serve with tortilla chips',
#   'question 4-2': ' guacamole',
#   'question 4-3': ' in',
#   'question 4-4': ' serve with tortilla chips',
#   'question 4-5': ' serving the guacamole',
#   'question 8-0': ' in one bowl',
#   'question 8-1': ' in'},
#  'r-5105': {'question 0-0': ' two steps',
#   'question 0-1': ' two different processes',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 1-0': ' yeast',
#   'question 1-1': ' oats',
#   'question 1-2': ' spice',
#   'question 1-3': ' spice',
#   'question 1-4': ' covered with a multi-tool',
#   'question 1-5': ' oats',
#   'question 1-6': ' oats',
#   'question 1-7': " `` bounce ''",
#   'question 1-8': ' air',
#   'question 1-9': ' oats',
#   'question 10-0': " `` throwing ''",
#   'question 10-1': ' gradually beat in about 4 cups',
#   'question 10-2': ' beat the yeast mix to blend',
#   'question 15-0': ' to prevent sticking',
#   'question 15-1': ' to make a stiff dough',
#   'question 15-2': ' why not',
#   'question 17-0': " `` bounce mat ''",
#   'question 17-1': ' the',
#   'question 17-2': ' cover and let rise',
#   'question 17-3': " `` bounce mat ''",
#   'question 17-4': " `` bounce mat ''",
#   'question 18-0': ' how to preheat the oven',
#   'question 18-1': ' bake 350 degrees',
#   'question 18-2': " `` apricot preserve ''",
#   'question 2-0': ' in a large bowl',
#   'question 2-1': " `` christmas cookie '' shape",
#   'question 2-10': ' in a',
#   'question 2-11': " `` cobwebs ''",
#   'question 2-12': " `` bounce mat ''",
#   'question 2-13': ' the middle of the playground',
#   'question 2-14': ' in a large bowl',
#   'question 2-2': ' turn dough over',
#   'question 2-3': ' turn dough out onto a floured board',
#   'question 2-4': ' in a large bowl',
#   'question 2-5': " `` whirlywalks ''",
#   'question 2-6': ' how to beat the yeast mix',
#   'question 2-7': ' beat the butter at medium speed',
#   'question 2-8': ' in a large bowl',
#   'question 2-9': ' in large bowl',
#   'question 3-0': ' your parents',
#   'question 3-1': ' yeast',
#   'question 4-0': ' bake 350 ° f',
#   'question 4-1': " baker's block",
#   'question 4-2': ' letting the',
#   'question 4-3': ' the yeast',
#   'question 4-4': ' Division of',
#   'question 5-0': " `` throwing ''",
#   'question 5-1': " `` flight ''",
#   'question 5-2': ' cover and let rise',
#   'question 6-0': ' dissolve yeast in water',
#   'question 7-0': " `` bob ''",
#   'question 7-1': ' cover and let rise',
#   'question 8-0': ' in 2 greased 9 - inch round baking pans',
#   'question 8-1': ' in a large bowl',
#   'question 8-2': " `` throwing ''",
#   'question 8-3': ' baking pan',
#   'question 8-4': ' cover and let rise',
#   'question 8-5': ' on a lightly floured board'},
#  'r-648': {'question 0-0': ' three',
#   'question 0-1': ' four',
#   'question 0-2': ' two',
#   'question 18-0': ' bean sprouts',
#   'question 18-1': ' 15 minutes',
#   'question 18-2': ' in the digestive tract',
#   'question 2-0': ' in a saucepot',
#   'question 2-1': ' saucepot',
#   'question 4-0': ' cook the noodles in water',
#   'question 4-1': ' cook the noodles in water',
#   'question 4-2': ' fish sauce',
#   'question 4-3': ' cook',
#   'question 4-4': ' cooking the noodle',
#   'question 4-5': ' the',
#   'question 6-0': ' cook the noodles in water',
#   'question 7-0': ' 15 minutes'},
#  'r-679': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 1-0': ' the',
#   'question 1-1': ' rolls',
#   'question 15-0': ' salt and pepper are ineffective',
#   'question 18-0': ' the packaging',
#   'question 18-1': ' in a bowl',
#   'question 18-2': ' the',
#   'question 4-0': ' a',
#   'question 4-1': ' the',
#   'question 4-2': ' a small lump of butter',
#   'question 4-3': ' a',
#   'question 4-4': ' a small lump of butter',
#   'question 4-5': ' the',
#   'question 6-0': ' cream'},
#  'r-716': {'question 0-0': ' three',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 1-0': ' potatoes',
#   'question 1-1': ' sliced egg',
#   'question 10-0': ' gently but thoroughly',
#   'question 10-1': ' whisk together the salt and pepper',
#   'question 18-0': ' the',
#   'question 18-1': ' four',
#   'question 18-2': ' as is',
#   'question 18-3': ' the skin',
#   'question 18-4': ' sliced egg',
#   'question 2-0': ' before serving',
#   'question 3-0': ' the',
#   'question 3-1': ' the',
#   'question 3-2': ' the',
#   'question 3-3': ' the',
#   'question 4-0': ' the',
#   'question 4-1': ' potato salad',
#   'question 4-2': ' adjust seasoning',
#   'question 4-3': ' potato salad',
#   'question 4-4': ' adjusted seasoning',
#   'question 4-5': ' first',
#   'question 5-0': ' whisk the salt and pepper together',
#   'question 8-0': ' in a bowl',
#   'question 8-1': ' in a bowl'},
#  'r-815': {'question 0-0': ' two steps',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' three',
#   'question 1-0': ' lamb',
#   'question 1-1': ' lamb',
#   'question 1-2': ' tomatoes',
#   'question 1-3': ' lamb',
#   'question 1-4': ' lamb',
#   'question 1-5': ' as is',
#   'question 1-6': ' tomatoes',
#   'question 1-7': ' lamb',
#   'question 10-0': ' as is',
#   'question 12-0': ' the',
#   'question 17-0': ' the',
#   'question 17-1': ' the',
#   'question 17-2': ' the',
#   'question 17-3': ' the',
#   'question 17-4': ' the',
#   'question 18-0': ' two',
#   'question 18-1': ' lamb',
#   'question 2-0': ' a frying pan',
#   'question 2-1': ' heat the butter',
#   'question 2-10': ' Divide each lamb slice into two pieces',
#   'question 2-2': ' heat the butter',
#   'question 2-3': ' the',
#   'question 2-4': ' in the yogurt',
#   'question 2-5': 'Mix the fennel and ginger powders',
#   'question 2-6': ' the',
#   'question 2-7': ' the',
#   'question 2-8': ' heat a saucepot with a drizzle of olive oil',
#   'question 2-9': ' divided equally',
#   'question 3-0': ' the',
#   'question 3-1': ' the',
#   'question 3-2': ' mix the fennel and ginger powders',
#   'question 3-3': ',',
#   'question 4-0': ' the',
#   'question 4-1': ' the',
#   'question 4-2': ' the',
#   'question 4-3': ' first',
#   'question 4-4': ' the',
#   'question 7-0': ' 40 minutes',
#   'question 7-1': ' 40 minutes',
#   'question 8-0': ' in the yogurt'},
#  'r-857': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' three',
#   'question 0-4': ' three',
#   'question 1-0': ' olive oil',
#   'question 1-1': ' mozzarella',
#   'question 10-0': ' arrange the tomatoes and mozzarella',
#   'question 10-1': ' arrange the tomatoes and mozzarella alternating',
#   'question 17-0': ' the',
#   'question 17-1': ' 2018',
#   'question 17-2': ' the',
#   'question 17-3': ' 2018',
#   'question 17-4': ' 2018',
#   'question 17-5': ' ``',
#   'question 18-0': ' mozzarella',
#   'question 18-1': ' cutting boards',
#   'question 18-2': ' sliced tomatoes and mozzarella',
#   'question 2-0': ' sliced tomatoes and mozzarella cheese',
#   'question 2-1': ' around a decorative serving dish',
#   'question 2-2': ' around a decorative serving dish',
#   'question 2-3': ' around a decorative serving dish',
#   'question 4-0': ' serve with salt and pepper',
#   'question 4-1': ' mozzarella cheese',
#   'question 4-2': ' mozzarella cheese',
#   'question 4-3': ' serve with salt and pepper',
#   'question 4-4': ' mozzarella cheese',
#   'question 4-5': ' mozzarella cheese',
#   'question 6-0': ' olive oil',
#   'question 8-0': ' around a decorative serving dish',
#   'question 9-0': ' slice tomatoes and mozzarella cheese same thickness'},
#  'r-872': {'question 0-0': ' 10 minutes',
#   'question 0-1': ' two',
#   'question 0-2': ' three',
#   'question 0-3': ' three',
#   'question 1-0': ' the white flesh',
#   'question 1-1': ' the',
#   'question 1-2': ' shells',
#   'question 1-3': ' the',
#   'question 1-4': ' white flesh',
#   'question 1-5': ' scallops',
#   'question 1-6': ' scallops',
#   'question 1-7': ' the scallops',
#   'question 10-0': ' serve with a dry rose wine',
#   'question 10-1': ' the',
#   'question 10-2': ' cook the white flesh until tender',
#   'question 12-0': ' the',
#   'question 16-0': ' from the pan',
#   'question 17-0': ' the',
#   'question 17-1': ' the',
#   'question 17-10': ' the',
#   'question 17-2': ' the',
#   'question 17-3': ' the',
#   'question 17-4': ' the',
#   'question 17-5': ' the',
#   'question 17-6': ' the',
#   'question 17-7': ' the',
#   'question 17-8': ' the',
#   'question 17-9': ' the',
#   'question 18-0': ' the',
#   'question 18-1': ' in a saucepan',
#   'question 18-2': ' 40 minutes',
#   'question 18-3': ' the',
#   'question 18-4': ' how do you preheat the oven',
#   'question 2-0': ' the',
#   'question 2-1': ' peel and smash the garlic',
#   'question 2-2': ' in',
#   'question 2-3': ' season',
#   'question 2-4': ' the',
#   'question 2-5': ' in',
#   'question 2-6': ' the',
#   'question 2-7': ' in a saucepan',
#   'question 2-8': ' scallops',
#   'question 3-0': ' the',
#   'question 3-1': ' the',
#   'question 4-0': ' the',
#   'question 4-1': ' the',
#   'question 5-0': ' cook the white flesh very gently',
#   'question 7-0': ' 10 minutes',
#   'question 7-1': ' 10 minutes',
#   'question 8-0': ' center of the shell',
#   'question 8-1': ' in a saucepan'},
#  'r-900': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' two',
#   'question 0-4': ' two',
#   'question 1-0': ' the',
#   'question 1-1': ' the',
#   'question 1-2': ' the',
#   'question 10-0': ' as is',
#   'question 10-1': ' the',
#   'question 16-0': ' bring stock and remaining water',
#   'question 18-0': ' the',
#   'question 18-1': ' bake',
#   'question 18-2': ' the',
#   'question 2-0': ' the',
#   'question 3-0': ' the',
#   'question 3-1': ' the',
#   'question 3-2': ' the',
#   'question 3-3': ' the',
#   'question 4-0': ' the',
#   'question 4-1': ' the',
#   'question 4-2': ' before serving',
#   'question 4-3': ' the',
#   'question 4-4': ' the',
#   'question 4-5': ' the',
#   'question 6-0': ' the',
#   'question 7-0': ' 2 - 3 minutes'},
#  'r-901': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' three',
#   'question 0-4': ' three',
#   'question 1-0': ' potatoes',
#   'question 1-1': ' greens',
#   'question 1-2': ' potatoes',
#   'question 1-3': ' beef broth',
#   'question 10-0': ' bring broth to a boil',
#   'question 18-0': ' 6 - hour',
#   'question 18-1': ' two',
#   'question 18-2': ' bring broth to boil',
#   'question 18-3': " `` bounce mat ''",
#   'question 2-0': ' ladle',
#   'question 2-1': ' ladle soup into bowls',
#   'question 4-0': ' beans',
#   'question 4-1': ' soup',
#   'question 4-2': ' beans',
#   'question 4-3': ' cooking the',
#   'question 4-4': ' green beans',
#   'question 6-0': ' bring broth to simmer',
#   'question 7-0': ' 5 minutes',
#   'question 7-1': ' bring broth to boil',
#   'question 8-0': ' at table',
#   'question 8-1': ' serving bowl',
#   'question 8-2': ' boil greens for about 5 minutes'},
#  'r-910': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 0-2': ' two',
#   'question 0-3': ' three',
#   'question 0-4': ' three',
#   'question 1-0': ' bacon',
#   'question 1-1': ' car',
#   'question 1-2': ' bacon',
#   'question 1-3': ' cabbage',
#   'question 1-4': ' bacon',
#   'question 18-0': ' bacon',
#   'question 18-1': ' heavy cream',
#   'question 18-2': ' the',
#   'question 18-3': ' two',
#   'question 18-4': ' serving bowl',
#   'question 2-0': ' frying pan',
#   'question 2-1': ' cut up the onion and garlic',
#   'question 2-2': ' cut the bacon into tiny bits',
#   'question 3-0': ' ``',
#   'question 3-1': ' the',
#   'question 3-2': ' bacon',
#   'question 3-3': ' bacon',
#   'question 4-0': ' the',
#   'question 4-1': ' the',
#   'question 9-0': ' a little'},
#  'r-98': {'question 0-0': ' two',
#   'question 0-1': ' two',
#   'question 1-0': ' lentils',
#   'question 1-1': ' lentils',
#   'question 1-2': ' as is',
#   'question 10-0': ' as is',
#   'question 18-0': ' lentils',
#   'question 18-1': ' two',
#   'question 3-0': ' lentil mixture',
#   'question 3-1': ' lentil mixture',
#   'question 3-2': ' the',
#   'question 3-3': ' the',
#   'question 4-0': ' bean vermicelli',
#   'question 4-1': ' j',
#   'question 4-2': ' fish cake',
#   'question 4-3': ' the',
#   'question 4-4': ' serve with rice',
#   'question 4-5': ' serve with rice',
#   'question 6-0': ' cooking oil',
#   'question 6-1': ' in a sauce pot',
#   'question 7-0': ' 2 - 3 minutes',
#   'question 7-1': ' 15 minutes',
#   'question 7-2': ' 10 minutes'}}

# %%
recipes_test, ingredients_test, titles_test, input_data_test  = parseFileNew('/content/drive/MyDrive/PY/SemEval2022/test_WITH_ANSWERS.csv')
df_eval = pd.DataFrame(input_data_test).sort_values(by=['doc_ID','qkey']).reset_index(drop=True)
df_eval['pred'] = df_res.sort_values(by=['doc_ID','qkeys']).reset_index(drop=True)['pred']
df_eval
# Out:
#           doc_ID  ...             pred
# 0     f-24CZS5LF  ...             four
# 1     f-24CZS5LF  ...              two
# 2     f-24CZS5LF  ...            three
# 3     f-24CZS5LF  ...              two
# 4     f-24CZS5LF  ...              two
# ...          ...  ...              ...
# 3437        r-98  ...      cooking oil
# 3438        r-98  ...   in a sauce pot
# 3439        r-98  ...    2 - 3 minutes
# 3440        r-98  ...       15 minutes
# 3441        r-98  ...       10 minutes
#
# [3442 rows x 6 columns]

# %%
# old answer
df_eval['pred'] = df_qa_test.sort_values(by=['doc_ID','qkey']).reset_index(drop=True)['answer']
df_eval
# Out:
#           doc_ID          recipeTitle  ... matched             pred_old
# 0     f-24CZS5LF  creamy-potato-salad  ...       0                  two
# 1     f-24CZS5LF  creamy-potato-salad  ...       0                  two
# 2     f-24CZS5LF  creamy-potato-salad  ...       0          three steps
# 3     f-24CZS5LF  creamy-potato-salad  ...       0                three
# 4     f-24CZS5LF  creamy-potato-salad  ...       0                  two
# ...          ...                  ...  ...     ...                  ...
# 3437        r-98         Kyarzan-Chek  ...       2       in cooking oil
# 3438        r-98         Kyarzan-Chek  ...       1  `` boiling water ''
# 3439        r-98         Kyarzan-Chek  ...       4    for 4 - 5 minutes
# 3440        r-98         Kyarzan-Chek  ...       2           15 minutes
# 3441        r-98         Kyarzan-Chek  ...       2        a few minutes
#
# [3442 rows x 9 columns]

# %%
df_eval['answer'] = df_eval.answer.astype('string')
df_eval['pred'] = df_eval.pred.astype('string')
df_eval['pred'] = [i.strip() for i in df_eval['pred']]

# %%
df_eval['pred'] = df_eval['pred'].replace('one','1').replace('two','2').replace('three','3').replace('four','4').replace('five','5').replace('six','6')

# %%
(df_eval['pred']==df_eval['answer']).value_counts()
# Out:
# False    3257
# True      185
# dtype: Int64

# %%
174/3442 , 185/3442
# Out:
# (0.0505520046484602, 0.05374782103428239)

# %%
df_eval.groupby('doc_ID').sum()['EM'].plot.hist()

# %%
df_eval['EM'] = (df_eval['pred']==df_eval['answer'])
df_eval.groupby('doc_ID').sum()['EM'].plot.hist()

# %%
df_eval
# Out:
#           doc_ID          recipeTitle  ...            pred     EM
# 0     f-24CZS5LF  creamy-potato-salad  ...               4  False
# 1     f-24CZS5LF  creamy-potato-salad  ...               2  False
# 2     f-24CZS5LF  creamy-potato-salad  ...               3  False
# 3     f-24CZS5LF  creamy-potato-salad  ...               2  False
# 4     f-24CZS5LF  creamy-potato-salad  ...               2  False
# ...          ...                  ...  ...             ...    ...
# 3437        r-98         Kyarzan-Chek  ...     cooking oil  False
# 3438        r-98         Kyarzan-Chek  ...  in a sauce pot  False
# 3439        r-98         Kyarzan-Chek  ...   2 - 3 minutes  False
# 3440        r-98         Kyarzan-Chek  ...      15 minutes  False
# 3441        r-98         Kyarzan-Chek  ...      10 minutes  False
#
# [3442 rows x 7 columns]

# %%
df_eval.to_csv('/content/drive/MyDrive/PY/SemEval2022/EVAL_test_predition.csv')

# %%
from sklearn.metrics import f1_score
from sklearn.preprocessing import MultiLabelBinarizer
word_level_true = [i.split(' ') for i in df_eval.answer]
word_level_pred = [i.split(' ') for i in df_eval.pred]
binar = MultiLabelBinarizer()
y_true = binar.fit_transform(word_level_true)
y_pred = binar.transform(word_level_pred)

f1_score(y_true, y_pred, average='macro'),f1_score(y_true, y_pred, average='micro'),f1_score(y_true, y_pred, average='weighted'),
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:876: UserWarning: unknown class(es) ["''", '--', '-limeade', '/', '1645', '2018', '2x2', '33', '350deg', '350f', 'Add', 'Adding', 'Allow', 'Bacon', 'Bake', 'Before', 'Brush', 'Chicken', 'Coarsely', 'Combine', 'Cooking', 'Cool', 'Dice', 'Dissolve', 'Divide', 'Division', 'Drop', 'Finely', 'Food', 'Halve', 'Make', 'Mix', 'Mushrooms', 'Parmesan', 'Preheat', 'Queijadinha', 'Refrigerate', 'Rinse', 'Sauteeing', 'Spread', 'Sprinkle', 'Wash', 'When', 'With', '``', '``rora', 'accent', 'actions', 'adjust', 'adjusted', 'aieve', 'airborne', 'alcohol', 'alphabetical', 'alternating', 'angel', 'appearing', 'ar', 'arm', 'artichoke', 'aspar', 'assemble,', 'b', "baker's", 'banging', 'be', 'beak', 'beet', 'biscuit', 'bite', 'bits', 'blend', 'block', 'boards', 'bob', 'bobbing', 'bones', 'bounce', 'boy', 'bread?', 'breast', "brooklin'''", 'build', 'burning', 'buttery', 'can', 'cap.', 'caps', 'car', 'caribbean', 'carrots.', 'carving', 'cashews', 'caul', 'center', 'changing', 'china', 'chip', 'christmas', 'chute', 'cleaned', 'clear', 'clingy', 'co', 'cobwebs', 'colina', 'compote', 'cooker', 'cooled', 'cousins', 'creeper', 'crepes', 'cumin?', 'curd', 'curried', "cutler's", 'd', 'days', 'de-beard', 'decorate', 'deg', 'dice', 'dicing', 'different', 'digestive', 'dip', 'divided', 'do', "drop's", 'dusting', 'easy', 'edamame', 'equally', 'excel', 'face', 'family', 'father', 'feud', 'fine', 'five', 'flight', 'flouring', 'forehead', 'four', 'freezer', 'french', 'frequently', 'freshly', 'fried', 'fruits', 'gamer', 'garret', 'germ', 'gets', 'gps', 'grandfather', 'grease', 'ground', 'gu', 'h', 'handled', 'heavy', 'her', "hess's", 'hole', 'how', 'identical', 'if', 'ineffective', 'j', 'jam', "john's", 'jr.', 'k', 'ki', "l'allegro", 'last', 'lay', 'left', 'leg', 'lemonade', 'let', 'letting', 'lightlyiments', 'lobster', 'loin', 'lump', 'ly', 'many', 'marble', 'mat', 'material', 'may', 'medium,', 'middle', 'minced', 'mini-muffin', 'mo', 'moment', 'mother', 'multi-tool', 'mushroom', 'mystery', 'newspaper', 'non-', 'non-alcoholic', 'noodle', 'not', 'oatouse', 'oats', 'order', 'p', 'packaging', 'pala', 'paprika', 'parents', 'part', 'peas', 'pecans', 'peel', 'peewee', 'perfection', 'pettis', "philippe's", 'pico', 'pictures', 'pina', 'pints', 'pitty', 'planted', 'plates', 'playground', 'poem', 'polish', 'polish_raaisin', 'polish_raaisin_scones', 'polishes', 'pots', 'pre-', 'pre-heated', 'preserve', 'prior', 'process', 'processes', 'protoplasm', 'puff', 'pulse', 'putting', 'pyaaz', 'queensland', 'quick', 'raais', 'raisin', 'reducing', 'refreshing', 'refrigerate', 'removal', 'removed', 'rivers', 'roll', "rooster's", 'rough', 'run', 'running', 'saurkraut', 'scramble', 'season', 'served', 'seven', 'sh', 'shape', 'shell', 'shredded', 'shrikand', 'shrimp', 'silly', 'simmered', 'six', 'smash', 'smear', 'spade', 'spice', 'split', 'spoonful', 'spreading', 'spreadsheets', 'sprinkles', 'squares', 'st', 'stay', 'steam', 'stem', 'stems', 'steps', 'stew', 'stiffly', 'stirred', 'str', 'strain', 'strained', 'strat', 'strips', 'stuffed', 'swirl', 'synagogue', 'take', 'task', 'tea', 'tequila', 'thirteenth', 'thopter', 'three', 'throwing', 'tights', 'tiny', 'toasters', 'toasting', 'tofu', 'tort', 'tossed', 'tracker', 'tract', 'trichotillomania', 'trolley', 'tsp', 'twice', 'ukraine', 'under', "vegetables'n'things", 'vegetarian', "veggies'n'things", 'vermicelli', 'victim', 'walnut', 'was', 'washing', 'wedge', 'were', 'where', 'where?', 'whirlywalks', 'whiskey', 'why', 'y', '°'] will be ignored
#   "unknown class(es) {0} will be ignored".format(sorted(unknown, key=str))
# (0.16058425617063649, 0.21598153440316553, 0.18635698304273923)

# %%
from sklearn.metrics import f1_score
from sklearn.preprocessing import MultiLabelBinarizer
word_level_true = [i.split(' ') for i in df_eval.answer]
word_level_pred = [i.split(' ') for i in df_eval.pred]
binar = MultiLabelBinarizer()
y_true = binar.fit_transform(word_level_true)
y_pred = binar.transform(word_level_pred)

f1_score(y_true, y_pred, average='macro'),f1_score(y_true, y_pred, average='micro'),f1_score(y_true, y_pred, average='weighted'),
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_label.py:876: UserWarning: unknown class(es) ['$1.5', '%', "''", '*', '--', '-alla', '-ginger', '/', '113', '2010', '2018', '24', '27s_', '2x2', '325', '33', '375', '400f', '45', '450', '50', '60', '8.5', '9,', 'Bananaade', 'Brush', 'Cooking', 'Courgette', 'Dissolve', 'Divide', 'Drain', 'Hass', 'Pyre', 'Queijadinha', "Rubens's", 'Sprinkle', 'Stir', 'Wash', 'Wrap', '``', 'abalone', 'accent', 'accident', 'actions', 'adjust', 'against', 'airtight', 'akeem', 'alcohol', 'alike', 'allspice', 'amanda', "amanda's", 'amish', 'any', 'appearing', 'approximately', 'artichoke', 'artichokes', 'aspartate', 'aur', 'austrian', 'baked', "baker's", 'balsamic', 'bananas', 'banging', 'barley', 'basis', 'beak', 'beetroot', 'begin', 'below', 'benedict', 'bengal', "bird's", 'bite', 'blanching', 'blend', 'bo', 'body', 'boilermaker', 'bones', 'border', 'bounce', 'boy', 'bran', 'brandy', 'breadcrumb', 'breast', 'breasts', 'broccoli', 'byron', 'c', 'camphor', 'can', 'canola', 'caps', 'caraway', 'caribbean', 'carolina', 'carrots.', 'carving', 'cascades', 'cashews', 'casserole', 'cavity', 'cheddar', 'chek', 'child', 'chives', 'chunk', 'city', 'cleaning', 'cocoa', 'colander', 'colina', 'cooler', 'coquilles', 'corer', 'corn_', 'courgette', 'crockard', 'cuisine', 'curd', 'curried', 'de', 'degf', 'dicing', 'different', 'digestive', 'dip', 'divide', 'do', 'dried,', 'drinking', 'drug', 'dusting', 'ease', 'easy', 'edamame', 'electric', 'elements', 'error', 'except', 'fillet', 'fine', 'flake', 'flattened', 'flip', 'flounder', 'folded', 'forehead', 'four', 'freezer', 'french', 'freshly', 'fruits', 'gado', 'garden', 'garret', 'gelatin', 'gentlyead', 'germ', 'gizzard', 'grain', 'gram', 'granola', 'grease', 'ground', 'guac', 'haddock', 'healthy', 'hearts', 'heavy', 'hess', 'hilton', 'hinge', 'his', 'homemade', 'horseradish', 'how', 'huevos', 'identical', 'if', 'illustrate', 'in.', 'instant', 'instructions', 'iran', 'iranian', 'iroma', 'irwell', 'italian', 'j', 'jaggery', 'jam', 'jhinga', 'june', 'ka', 'kage_med_', 'kashmiri', 'kernels', 'khira', 'ki', 'knives', 'knob', 'kounoupidi_', "kroger's", 'kyarzan', 'kyuhyun', 'layer', 'lb', 'leaf', 'left', 'leg', 'lemon_', 'lemonade', 'let', 'liquor', 'loaf', 'loin', 'long', 'lumaconus', 'malt', 'many', 'maple', 'marjoram', 'mat', 'mayo', 'meat', 'meats', 'medium,', 'method', 'middle', 'mince', 'minced', 'mini-muffin', 'moistureen', 'morton', 'multi-tool', 'muscle', 'mushroom', 'myths', 'nagaraya', 'naks', 'narrow', 'neck', 'needed', 'nelson', 'netherlands', 'new', 'nights', 'nik', 'not', 'olajuwon', 'olives', 'ons', 'opposite', 'original', 'oxtail', 'packaging', 'pancetta', 'panjiri', 'paprika', 'parmigiana', 'parts', 'party', 'pasta', "patrick's", 'patting', 'pealing', 'peanuts', 'pear', 'pearl', 'peas', 'pebbles', 'peel', 'peeling', 'peewee', 'perez', 'perfection', 'pho_', 'picnic', 'pictures', 'piece', 'pineapple', 'pizza', 'pk', 'plaice', 'playground', 'plaçade', 'plina', 'poaching', 'polla', 'prawn', 'prawns', 'pre-heated', 'prior', 'process', 'processes', 'pumpkin', 'putting', 'pyaaz', 'quality', 'raisin', 'raspberry', 'reaper', 'recipe', 'reconstitute', 'reduce', 'refrigerate', 'reheat', 'removal', 'removing', 'rest', 'river', 'roll', "rooster's", 'rosemary', 'roti', 'rotor', 'rough', 'roughly', "rubens's", 'running', 'sauerkraut', 'saurkraut', 'sauteing', 'scallions', 'scramble', 'sea', 'sealing', 'season', 'seconds', 'serratus', 'server', 'setting', 'shahi', 'shallot', 'shallots', 'shape', 'shell', 'sherry', 'shiitake', 'shoulder', 'shoulder,', 'shredded', 'shrimp', 'sirloin', 'slotted', 'sm', 'smaller', 'snack', 'soak', 'south', 'spade', 'spice', 'spinach', 'spit', 'splash', 'split', 'spoonful', 'spreading', 'spri', 'stack', 'standing', 'stem', 'stems', 'steps', 'stewing', 'stirred', 'strain', 'strained', 'string', 'strips', 'stuffing', 'stən', 'summer', 'synagogue', 'tabbouleh', 'takayama', 'taylor', 'tblspn', 'tea', 'teaspoonful', 'teaspoonfuls', 'techn ...
#   "unknown class(es) {0} will be ignored".format(sorted(unknown, key=str))
# (0.16548598443789686, 0.22855620671283963, 0.1987922901254874)

# %%
set_true  = [set(i.split(' ')) for i in df_eval.answer]
set_pred  = [set(i.split(' ')) for i in df_eval.pred]
match_num = []
for i in range(len(set_true)):
  match_num.append(len(set_true[i] & set_pred[i]))
df_eval['matched'] = match_num
df_eval
# Out:
#           doc_ID          recipeTitle  ...     EM matched
# 0     f-24CZS5LF  creamy-potato-salad  ...  False       0
# 1     f-24CZS5LF  creamy-potato-salad  ...  False       0
# 2     f-24CZS5LF  creamy-potato-salad  ...  False       0
# 3     f-24CZS5LF  creamy-potato-salad  ...  False       0
# 4     f-24CZS5LF  creamy-potato-salad  ...  False       0
# ...          ...                  ...  ...    ...     ...
# 3437        r-98         Kyarzan-Chek  ...  False       2
# 3438        r-98         Kyarzan-Chek  ...  False       1
# 3439        r-98         Kyarzan-Chek  ...  False       4
# 3440        r-98         Kyarzan-Chek  ...  False       2
# 3441        r-98         Kyarzan-Chek  ...  False       2
#
# [3442 rows x 8 columns]

# %%
df_eval.matched.plot.hist(bins=20)
df_eval.matched.value_counts()
# Out:
# 0     2346
# 1      679
# 2      170
# 3      118
# 4       81
# 5       30
# 6       12
# 7        4
# 8        1
# 10       1
# Name: matched, dtype: int64

# %%
with open('/content/drive/MyDrive/PY/SemEval2022/res0-100.pickle', 'wb') as handle:
    pickle.dump(pred_answers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for question in df_qa_test.question[100:500]:
    # Retrieve related documents from retriever
    retriever_results = retriever.retrieve(
        query=question
    )

    # Now generate answer from question and retrieved documents
    predicted_result = generator.predict(
        query=question,
        documents=retriever_results,
        top_k=1
    )

    # Print you answer
    answers = predicted_result["answers"]
    pred_answers.append(answers[0].answer)
    # print(f'Generated answer is \'{answers[0].answer}\' for the question = \'{question}\'')
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/rag/tokenization_rag.py:97: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1749: UserWarning: `max_length` is deprecated in this function, use `stopping_criteria=StoppingCriteriaList(MaxLengthCriteria(max_length=max_length))` instead.
#   UserWarning,

# %%
with open('/content/drive/MyDrive/PY/SemEval2022/res0-500.pickle', 'wb') as handle:
    pickle.dump(pred_answers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for question in df_qa_test.question[500:1000]:
    # Retrieve related documents from retriever
    retriever_results = retriever.retrieve(
        query=question
    )

    # Now generate answer from question and retrieved documents
    predicted_result = generator.predict(
        query=question,
        documents=retriever_results,
        top_k=1
    )

    # Print you answer
    answers = predicted_result["answers"]
    pred_answers.append(answers[0].answer)
    # print(f'Generated answer is \'{answers[0].answer}\' for the question = \'{question}\'')
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/rag/tokenization_rag.py:97: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1749: UserWarning: `max_length` is deprecated in this function, use `stopping_criteria=StoppingCriteriaList(MaxLengthCriteria(max_length=max_length))` instead.
#   UserWarning,

# %%
with open('/content/drive/MyDrive/PY/SemEval2022/res0-1000.pickle', 'wb') as handle:
    pickle.dump(pred_answers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for question in df_qa_test.question[1000:2000]:
    # Retrieve related documents from retriever
    retriever_results = retriever.retrieve(
        query=question
    )

    # Now generate answer from question and retrieved documents
    predicted_result = generator.predict(
        query=question,
        documents=retriever_results,
        top_k=1
    )

    # Print you answer
    answers = predicted_result["answers"]
    pred_answers.append(answers[0].answer)
    # print(f'Generated answer is \'{answers[0].answer}\' for the question = \'{question}\'')
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/rag/tokenization_rag.py:97: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1749: UserWarning: `max_length` is deprecated in this function, use `stopping_criteria=StoppingCriteriaList(MaxLengthCriteria(max_length=max_length))` instead.
#   UserWarning,

# %%
with open('/content/drive/MyDrive/PY/SemEval2022/res0-2000.pickle', 'wb') as handle:
    pickle.dump(pred_answers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
for question in df_qa_test.question[2000:]:
    # Retrieve related documents from retriever
    retriever_results = retriever.retrieve(
        query=question
    )

    # Now generate answer from question and retrieved documents
    predicted_result = generator.predict(
        query=question,
        documents=retriever_results,
        top_k=1
    )

    # Print you answer
    answers = predicted_result["answers"]
    pred_answers.append(answers[0].answer)
    # print(f'Generated answer is \'{answers[0].answer}\' for the question = \'{question}\'')

# %%
with open('/content/drive/MyDrive/PY/SemEval2022/res2000-.pickle', 'wb') as handle:
    pickle.dump(pred_answers, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
import pickle
import pandas as pd
with open('/content/drive/MyDrive/PY/SemEval2022/res2000-.pickle', 'rb') as handle:
    old_pred_answers = pickle.load(handle)
with open('/content/drive/MyDrive/PY/SemEval2022/df_qa_test.pickle', 'rb') as handle:
    df_qa_test = pickle.load(handle)

# %%
len(old_pred_answers)
# Out:
# 3442

# %%
df_qa_test['answer'] = old_pred_answers
df_qa_test
# Out:
#       doc_ID  recipeID recipeTitle  ...           qkey                 answer dummy
# 0      r-378         0     Zaalouk  ...   question_2-3                   sink   in
# 1      r-378         0     Zaalouk  ...   question_0-1                    two   in
# 2      r-378         0     Zaalouk  ...  question_12-0           the tomatoes   in
# 3      r-378         0     Zaalouk  ...   question_4-0               heat oil   in
# 4      r-378         0     Zaalouk  ...  question_18-0   cutting the tomatoes   in
# ...      ...       ...         ...  ...            ...                    ...   ...
# 3437  r-1165        99  Huzarensla  ...   question_3-0   pickled pearl onions   in
# 3438  r-1165        99  Huzarensla  ...  question_17-0                    the   in
# 3439  r-1165        99  Huzarensla  ...   question_3-2         2 cooked beets   in
# 3440  r-1165        99  Huzarensla  ...   question_0-1                  n / a   in
# 3441  r-1165        99  Huzarensla  ...   question_7-0      a couple of hours   in
#
# [3442 rows x 7 columns]

# %%
df_qa_test['qkey'] = df_qa_test.qkey.apply(lambda x: x.replace('_',' '))

# %%
df_qa_test['answer'] = df_qa_test['answer'].apply(lambda x:x.strip())

# %%
dict_res = dict(df_qa_test.groupby('doc_ID').apply(lambda x: dict(zip(x['qkey'],x['answer']))))
dict_res
# Out:
# {'f-24CZS5LF': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'three steps',
#   'question 0-3': 'three',
#   'question 0-4': 'two',
#   'question 0-5': 'a large bowl',
#   'question 1-0': 'potatoes',
#   'question 1-1': 'potatoes',
#   'question 1-2': 'peas',
#   'question 18-0': 'spoonfuls',
#   'question 18-1': 'three',
#   'question 18-2': 'creamy - potato - salad',
#   'question 18-3': 'on a tray',
#   'question 2-0': 'in a large bowl',
#   'question 2-1': 'sliced into bite size pieces',
#   'question 3-0': 'mayonnaise',
#   'question 3-1': 'by mashing the egg yolks',
#   'question 4-0': 'mayonnaise',
#   'question 4-1': "`` peewee ''",
#   'question 4-2': 'potatoes',
#   'question 4-3': 'mayonnaise',
#   'question 4-4': 'celery',
#   'question 4-5': 'pealing potatoes',
#   'question 5-0': 'until fork tender',
#   'question 8-0': 'in a small bowl',
#   'question 8-1': 'in a large bowl'},
#  'f-26NF6ZNY': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 1-0': 'the',
#   'question 1-1': 'seltzer',
#   'question 1-2': 'seltzer',
#   'question 1-3': '2 parts seltzer',
#   'question 1-4': 'the',
#   'question 1-5': 'strawberries',
#   'question 10-0': 'using a whisk',
#   'question 12-0': 'the pitcher',
#   'question 12-1': 'the',
#   'question 12-2': 'a bowl',
#   'question 17-0': 'a bowl',
#   'question 18-0': 'the',
#   'question 18-1': 'sugar',
#   'question 2-0': 'in a large pitcher',
#   'question 3-0': 'by',
#   'question 3-1': 'strawberry',
#   'question 3-2': 'lemon lime',
#   'question 3-3': 'sugar',
#   'question 3-4': 'in a mixer',
#   'question 3-5': 'by',
#   'question 4-0': '1 lime',
#   'question 4-1': 'lemon lime soda',
#   'question 4-2': 'lemon lime soda',
#   'question 4-3': 'if needed',
#   'question 5-0': 'smooth',
#   'question 7-0': '30 minutes',
#   'question 8-0': 'the pitcher',
#   'question 8-1': 'in a large pitcher',
#   'question 9-0': '2 parts seltzer'},
#  'f-2PMMKJ2X': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'three',
#   'question 0-3': 'three',
#   'question 1-0': 'oxtail',
#   'question 1-1': 'curd',
#   'question 1-2': 'stirred with kashmiri',
#   'question 1-3': 'dry fruits',
#   'question 10-0': 'in a bowl',
#   'question 10-1': "`` saute ''",
#   'question 12-0': 'a pan',
#   'question 15-0': 'put a pan to heat',
#   'question 18-0': 'nuts',
#   'question 18-1': 'the',
#   'question 18-2': 'the tiraṅgā',
#   'question 18-3': 'two',
#   'question 18-4': 'the',
#   'question 3-0': 'by mixing the ingredients',
#   'question 3-1': 'bengal gram flour',
#   'question 3-2': 'curd',
#   'question 3-3': 'by dipping the dough ball',
#   'question 4-0': 'jaggery',
#   'question 4-1': 'the',
#   'question 4-2': 'pyaaz - ki - kadhi',
#   'question 4-3': 'shahi - panjiri',
#   'question 5-0': 'Stir the mixture continuously',
#   'question 6-0': 'on low heat',
#   'question 8-0': 'in a bowl'},
#  'f-3PMSLV76': {'question 0-0': '1',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': '8 - 10 minutes',
#   'question 0-4': '1 / 2 tsp',
#   'question 1-0': 'vanilla',
#   'question 1-1': 'tortilla',
#   'question 1-2': 'the eggs',
#   'question 1-3': 'pineapple',
#   'question 1-4': 'eggs',
#   'question 10-0': 'with a multi-tool',
#   'question 10-1': 'by using a whisk',
#   'question 14-0': 'preheat oven to 350 degrees f',
#   'question 16-0': 'from shells',
#   'question 17-0': 'on a cooling rack',
#   'question 17-1': 'cookie sheet',
#   'question 18-0': 'eggs',
#   'question 18-1': 'nagaraya',
#   'question 2-0': 'spoon a teaspoon of coconut mixture',
#   'question 2-1': '1 / 2 tsp vanilla',
#   'question 2-2': 'each muffin cup',
#   'question 2-3': 'each muffin cup',
#   'question 2-4': 'in a casserole',
#   'question 3-0': 'eggs',
#   'question 3-1': 'eggs',
#   'question 3-2': 'the',
#   'question 3-3': 'vanilla',
#   'question 3-4': 'vanilla',
#   'question 3-5': 'by combining the breadcrumbs',
#   'question 3-6': 'the',
#   'question 3-7': 'pineapple preserves',
#   'question 4-0': '2 cups shredded coconut',
#   'question 4-1': 'in a medium saucepan',
#   'question 4-2': 'the first layer',
#   'question 5-0': 'by using a spoon',
#   'question 5-1': 'by using a spoon',
#   'question 5-2': '23 - 33 minutes',
#   'question 6-0': 'by using a hand mixer',
#   'question 6-1': 'in a processor or blender',
#   'question 7-0': '10 - 12 minutes',
#   'question 7-1': 'for 10 - 12 minutes',
#   'question 7-2': '12 to 15 minutes',
#   'question 7-3': '12 to 16 minutes',
#   'question 8-0': 'in a smaller bowl',
#   'question 8-1': 'the oven',
#   'question 8-2': 'each muffin cup',
#   'question 8-3': 'in a smaller bowl',
#   'question 8-4': 'in each cup',
#   'question 8-5': 'in bottom and up',
#   'question 8-6': 'in a casserole dish'},
#  'f-3X45Z8TR': {'question 0-0': '1 / 2 tsp baking soda',
#   'question 0-1': '12 - 14 minutes',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'two',
#   'question 1-0': 'spoonful of cookie dough',
#   'question 1-1': 'vanilla',
#   'question 1-2': 'vanilla',
#   'question 1-3': 'the zucchini filling',
#   'question 1-4': 'vanilla',
#   'question 10-0': 'baking soda',
#   'question 10-1': 'by using a mixer',
#   'question 12-0': 'add flour mixture gradually',
#   'question 15-0': ',',
#   'question 16-0': 'by teaspoons',
#   'question 17-0': 'on',
#   'question 17-1': 'cookies',
#   'question 18-0': 'to',
#   'question 18-1': 'placed prior to the bagel',
#   'question 2-0': 'on greased pans',
#   'question 2-1': 'on a tray',
#   'question 2-2': 'by using a whisk',
#   'question 2-3': 'beat the butter',
#   'question 2-4': 'by teaspoonful',
#   'question 3-0': 'vanilla',
#   'question 3-1': 'fennel',
#   'question 3-2': 'apricot preserves',
#   'question 3-3': 'vanilla',
#   'question 3-4': 'by whisking',
#   'question 3-5': 'by using a whisk',
#   'question 3-6': 'by using a whisk',
#   'question 3-7': 'by using a whisk',
#   'question 4-0': 'vanilla instant pudding mix',
#   'question 4-1': 'vanilla instant pudding mix',
#   'question 4-2': 'the',
#   'question 4-3': 'n / a',
#   'question 4-4': 'n / a',
#   'question 4-5': 'craisins',
#   'question 5-0': 'beat the butter with a mixer',
#   'question 5-1': 'to',
#   'question 5-2': 'twelve to fifteen minutes',
#   'question 5-3': 'beat the butter',
#   'question 6-0': 'beat the butter at medium speed',
#   'question 7-0': '12 to 15 minutes',
#   'question 7-1': '12 to 15 minutes',
#   'question 8-0': 'on wire racks',
#   'question 8-1': 'in a large bowl',
#   'question 8-2': 'onto a buttered baking pan'},
#  'f-4BPH5RC2': {'question 0-0': 'three steps',
#   'question 0-1': 'three',
#   'question 0-2': 'one',
#   'question 0-3': 'two',
#   'question 1-0': 'prosecco',
#   'question 1-1': 'egg',
#   'question 1-2': 'the',
#   'question 1-3': 'sugar',
#   'question 1-4': 'the egg',
#   'question 10-0': 'an cold glass of prosecco',
#   'question 15-0': 'a thin batter',
#   'question 18-0': 'beat the egg white',
#   'question 18-1': 'n / a',
#   'question 18-2': 'mashing',
#   'question 18-3': 'with the',
#   'question 18-4': "the rooster's beak",
#   'question 2-0': 'scramble the egg',
#   'question 3-0': '2018',
#   'question 4-0': 'in',
#   'question 4-1': 'june 9, 2010',
#   'question 4-2': 'in a bowl',
#   'question 5-0': 'until golden brown',
#   'question 6-0': 'scramble the egg',
#   'question 8-0': 'the surface of the water',
#   'question 8-1': 'in a bowl',
#   'question 8-2': 'in the fridge'},
#  'f-4HWM88HF': {'question 12-0': 'besan',
#   'question 18-0': 'potato slices',
#   'question 18-1': 'for 10 - 24 minutes',
#   'question 18-2': ',',
#   'question 18-3': 'by using a spatula',
#   'question 4-0': 'besan',
#   'question 4-1': 'karahi',
#   'question 4-2': 'besan',
#   'question 4-3': 'oil for frying',
#   'question 4-4': 'karahi',
#   'question 4-5': 'besan',
#   'question 5-0': 'to',
#   'question 8-0': 'in besan',
#   'question 8-1': 'in large sauce pot'},
#  'f-4Z5SV5FY': {'question 0-0': 'two identical 2x2 pictures',
#   'question 0-1': 'three steps',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 10-0': 'flip the scaloppine over',
#   'question 16-0': 'the spit',
#   'question 18-0': 'two',
#   'question 18-1': '6 - hour',
#   'question 18-2': 'the',
#   'question 18-3': 'toaster',
#   'question 4-0': 'chopped fresh parsley',
#   'question 4-1': 'chopped fresh parsley',
#   'question 4-2': 'the',
#   'question 4-3': 'the other side',
#   'question 4-4': 'saute pancetta',
#   'question 6-0': 'minced garlic',
#   'question 6-1': 'in a skillet',
#   'question 7-0': '1 - 2 minutes',
#   'question 7-1': '2 - 3 minutes',
#   'question 8-0': 'the caribbean',
#   'question 8-1': 'the surface of the flour',
#   'question 8-2': 'in a skillet',
#   'question 8-3': "`` tequila ''"},
#  'f-67M2BXM3': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'n / a',
#   'question 0-3': 'two',
#   'question 1-0': 'cake flour',
#   'question 1-1': 'sugar',
#   'question 10-0': 'vanilla extract',
#   'question 10-1': 'by using a electric mixer',
#   'question 16-0': 'butter',
#   'question 18-0': 'bittersweet chocolate chips',
#   'question 18-1': 'by using a cookie cutter',
#   'question 18-2': 'in a cookie sheet',
#   'question 18-3': 'in a mixing bowl',
#   'question 2-0': 'n / a',
#   'question 3-0': 'vanilla',
#   'question 3-1': 'vanilla',
#   'question 3-2': 'chocolate',
#   'question 3-3': 'sugar',
#   'question 3-4': 'whisk your water',
#   'question 3-5': 'by mixing the ingredients',
#   'question 3-6': 'in',
#   'question 3-7': 'by adding the flour',
#   'question 4-0': 'n / a',
#   'question 5-0': 'for 8 - 10 minutes',
#   'question 7-0': '12 to 15 minutes',
#   'question 8-0': 'in a medium bowl'},
#  'f-88XKC27N': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': '2',
#   'question 1-0': 'rice',
#   'question 10-0': 'as is',
#   'question 18-0': 'two',
#   'question 18-1': 'potatoes',
#   'question 18-2': 'in the large pot',
#   'question 18-3': 'vinegar',
#   'question 2-0': 'a saucepot',
#   'question 2-1': 'the sheet pan',
#   'question 3-0': 'garlic',
#   'question 3-1': 'water',
#   'question 3-2': 'chicken broth',
#   'question 3-3': '6 cups of chicken broth',
#   'question 3-4': '6 cups of chicken broth',
#   'question 3-5': 'by adding the olive oil',
#   'question 3-6': 'by using a blender',
#   'question 3-7': 'by frying',
#   'question 3-8': 'by frying',
#   'question 3-9': 'by frying',
#   'question 4-0': '2 cups of chicken broth',
#   'question 4-1': '2 cups uncooked lentils',
#   'question 4-2': '2 cups of chicken broth',
#   'question 4-3': 'lentils',
#   'question 4-4': 'uncooked lentils',
#   'question 6-0': 'rinse the lentils with water'},
#  'f-8KG2VBC7': {'question 0-0': 'two',
#   'question 0-1': '5',
#   'question 0-2': '3',
#   'question 1-0': 'black beans',
#   'question 1-1': 'black beans',
#   'question 1-2': 'food',
#   'question 10-0': 'in a blender',
#   'question 13-0': 'with your favourite soup',
#   'question 15-0': 'healthy snack',
#   'question 16-0': 'by using a spatula',
#   'question 18-0': 'two',
#   'question 18-1': 'ginger',
#   'question 3-0': 'edamame',
#   'question 3-1': 'by mixing the ingredients',
#   'question 4-0': 'n',
#   'question 4-1': 'soy beans',
#   'question 4-2': 'removal of bones',
#   'question 4-3': 'instructions for edamame',
#   'question 4-4': 'cooking the rice',
#   'question 4-5': 'soy beans',
#   'question 7-0': 'about 15 minutes',
#   'question 7-1': 'for 10 to 15 minutes',
#   'question 8-0': 'in a air - tight container'},
#  'f-8Q86RWDJ': {'question 0-0': 'four',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'three',
#   'question 1-0': 'stirred with the spoon',
#   'question 1-1': 'stirred with the spoon',
#   'question 1-2': '1 / 2 tsp. sea salt',
#   'question 1-3': '1 / 2 tsp. sea salt',
#   'question 10-0': 'how to do it',
#   'question 12-0': 'the top layer',
#   'question 12-1': 'melt the butter',
#   'question 14-0': 'preheat the oven',
#   'question 15-0': 'n / a',
#   'question 18-0': 'beetroot',
#   'question 18-1': 'by putting the mixture in',
#   'question 2-0': 'in a large stock pot',
#   'question 2-1': 'by using a strainer',
#   'question 2-2': 'stir the cognac',
#   'question 2-3': 'stir the onion mixture',
#   'question 2-4': 'n / a',
#   'question 2-5': 'the middle of the soup',
#   'question 2-6': 'the large skillet',
#   'question 3-0': 'by putting the mixture in',
#   'question 3-1': 'egg',
#   'question 4-0': 'vegetarian - french - onion - soup',
#   'question 4-1': 'n / a',
#   'question 4-2': 'n / a',
#   'question 4-3': 'n / a',
#   'question 4-4': '1 / 2 tsp. sea salt',
#   'question 5-0': 'n / a',
#   'question 6-0': 'saute spinach with a knob',
#   'question 7-0': 'for about 30 seconds',
#   'question 7-1': '5 minutes',
#   'question 8-0': '1 / 2 tsp. sea salt',
#   'question 8-1': 'on a tray',
#   'question 8-2': 'in a small sauce pan'},
#  'f-CKJFC4NR': {'question 0-0': 'three',
#   'question 0-1': 'two',
#   'question 0-2': '3 minutes',
#   'question 0-3': 'two or four actions',
#   'question 1-0': 'tomatoes',
#   'question 18-0': 'by combining',
#   'question 18-1': 'bacon',
#   'question 18-2': 'the packaging',
#   'question 2-0': 'in a large bowl',
#   'question 2-1': 'in a small bowl',
#   'question 2-2': "`` cascades ''",
#   'question 2-3': 'a large bowl',
#   'question 2-4': 'whisk together jam and water',
#   'question 3-0': 'sugar',
#   'question 3-1': 'vinegar',
#   'question 3-2': 'by mashing the egg yolks',
#   'question 3-3': 'by combining the all ingredient',
#   'question 4-0': 'strawberry jam',
#   'question 4-1': 'strawberry jam',
#   'question 4-2': 'cashews',
#   'question 4-3': 'the dressing',
#   'question 4-4': 'dressing',
#   'question 4-5': 'in a blender',
#   'question 5-0': 'to',
#   'question 8-0': 'in a large mixing bowl',
#   'question 8-1': 'in a large bowl'},
#  'f-CYTQDZKG': {'question 0-0': 'three steps',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'two',
#   'question 1-0': 'egg',
#   'question 1-1': 'strained milk',
#   'question 1-2': 'chopped coriander',
#   'question 1-3': 'water',
#   'question 1-4': 'gelatin',
#   'question 1-5': 'gelatin',
#   'question 1-6': '10 to 14 hours',
#   'question 10-0': '10 to 14 hours',
#   'question 11-0': '10 to 14 hours',
#   'question 12-0': 'in a',
#   'question 12-1': 'in a large saucepan',
#   'question 12-2': 'in a smaller bowl',
#   'question 14-0': 'how to cool the milk',
#   'question 17-0': '10 to 14 hours',
#   'question 17-1': '10 to 14 hours',
#   'question 17-10': '10 to 14 hours',
#   'question 17-2': '10 to 14 hours',
#   'question 17-3': '10 to 14 hours',
#   'question 17-4': 'in a sterile glass bowl',
#   'question 17-5': 'in a mixer jar',
#   'question 17-6': '10 to 14 hours',
#   'question 17-7': '10 to 14 hours',
#   'question 17-8': '10 to 14 hours',
#   'question 17-9': '10 to 14 hours',
#   'question 18-0': 'in the digestive tract',
#   'question 18-1': 'method of poaching',
#   'question 18-2': 'the',
#   'question 18-3': 'on greased pans',
#   'question 2-0': '10 to 14 hours',
#   'question 2-1': 'mix yogurt and cheese',
#   'question 2-10': '10 to 14 hours',
#   'question 2-11': 'the milk cooler',
#   'question 2-2': 'freezer',
#   'question 2-3': 'in a smaller bowl',
#   'question 2-4': 'in a smaller bowl',
#   'question 2-5': 'strain the mixture',
#   'question 2-6': 'iroma',
#   'question 2-7': '10 to 14 hours',
#   'question 2-8': 'in a small bowl',
#   'question 2-9': '10 to 14 hours',
#   'question 3-0': 'by blending the eggs',
#   'question 3-1': 'oil',
#   'question 4-0': 'putting a coffee filter in a strainer',
#   'question 4-1': 'n / a',
#   'question 4-2': '10 to 14 hours',
#   'question 5-0': '10 to 14 hours',
#   'question 5-1': 'for garnish',
#   'question 5-2': 'heat the milk',
#   'question 6-0': 'in',
#   'question 7-0': 'for 30 minutes',
#   'question 8-0': 'in a skillet',
#   'question 8-1': 'in a smaller bowl',
#   'question 8-2': 'in a large saucepan',
#   'question 8-3': 'in the digestive tract',
#   'question 8-4': 'in a smaller bowl',
#   'question 9-0': 'by using a spoon',
#   'question 9-1': '10 to 14 hours'},
#  'f-D7RYT56T': {'question 0-0': 'two steps',
#   'question 0-1': 'two steps',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 1-0': 'peanut butter',
#   'question 1-1': 'bittersweet chocolate chips',
#   'question 10-0': 'gentlyead the pasty dough',
#   'question 14-0': 'preheat oven to 350 ° f',
#   'question 15-0': 'form small crumbs',
#   'question 18-0': 'in a large mixing bowl',
#   'question 18-1': 'in a large mixing bowl',
#   'question 18-2': "patrick's",
#   'question 18-3': 'sugar',
#   'question 18-4': 'in a large skillet',
#   'question 2-0': 'form small crumbs',
#   'question 2-1': 'pasty dough',
#   'question 2-2': 'on a floured work surface',
#   'question 2-3': 'in a large mixing bowl',
#   'question 2-4': 'pasty dough',
#   'question 3-0': 'by',
#   'question 3-1': 'canola oil',
#   'question 4-0': 'pasty dough',
#   'question 4-1': 'cake flour',
#   'question 4-2': 'the',
#   'question 6-0': 'with your hands',
#   'question 6-1': 'separate the dough with your multi-tool',
#   'question 7-0': '30 minutes before serving',
#   'question 8-0': 'in a large mixing bowl'},
#  'f-F5SF7H44': {'question 0-0': 'three',
#   'question 0-1': 'two',
#   'question 0-2': '2 tblspn tomato sauce',
#   'question 0-3': '2 tblspn tomato sauce',
#   'question 1-0': 'tortilla',
#   'question 10-0': '1 / 2 tsp nutmeg',
#   'question 10-1': 'grill it in the oven',
#   'question 12-0': '1 tsp oregano',
#   'question 13-0': '2 tblspn tomato sauce',
#   'question 15-0': '2 tblspn tomato sauce',
#   'question 18-0': 'two',
#   'question 18-1': '1 tsp oregano',
#   'question 18-2': '1 / 2 tsp',
#   'question 18-3': 'three',
#   'question 18-4': 'alcohol',
#   'question 2-0': 'small bowl',
#   'question 2-1': 'by using a whisk',
#   'question 4-0': '1 tsp oregano',
#   'question 4-1': 'in',
#   'question 4-2': 'meat -',
#   'question 5-0': 'grill it in the oven',
#   'question 8-0': 'in a saucepan',
#   'question 8-1': '2 tblspn tomato sauce',
#   'question 8-2': 'on cooling rack'},
#  'f-FS6V8XD5': {'question 0-0': 'an ungreased cookie sheet',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'two different processes',
#   'question 0-5': 'two',
#   'question 1-0': 'potatoes',
#   'question 1-1': 'the',
#   'question 1-2': 'abalone',
#   'question 1-3': 'the flour',
#   'question 10-0': 'by using a whisk',
#   'question 10-1': 'gently wash the tops of the scones',
#   'question 14-0': 'preheat your oven to 400 ° f',
#   'question 17-0': 'the',
#   'question 17-1': 'in a mixing bowl',
#   'question 18-0': 'by using a spatula',
#   'question 18-1': 'in the chicken cavity',
#   'question 18-2': 'in the digestive tract',
#   'question 2-0': 'cooling rack',
#   'question 2-1': 'by using a spatula',
#   'question 2-2': 'in a large bowl',
#   'question 2-3': 'with your fingers',
#   'question 2-4': 'whisk in.',
#   'question 2-5': 'with your fingers',
#   'question 2-6': 'in the large saucepan',
#   'question 2-7': 'with a fork',
#   'question 3-0': 'pear',
#   'question 3-1': 'coriander',
#   'question 3-2': 'coriander',
#   'question 3-3': 'by sealing the packaging',
#   'question 3-4': 'by mixing the molasses',
#   'question 3-5': 'by adding',
#   'question 3-6': 'by using a whisk',
#   'question 4-0': 'by using a spatula',
#   'question 4-1': 'mixing bowl',
#   'question 4-2': '1 pear',
#   'question 4-3': 'in a',
#   'question 4-4': 'the',
#   'question 4-5': 'the',
#   'question 5-0': 'with your fingers',
#   'question 5-1': 'preheat oven to 400 ° f',
#   'question 5-2': 'until smooth',
#   'question 6-0': 'saute the mixture on low heat',
#   'question 6-1': 'gently wash the tops of the scones',
#   'question 7-0': 'about 30 minutes',
#   'question 8-0': 'the bowl',
#   'question 8-1': 'in a mixing bowl',
#   'question 8-2': 'on an ungreased cookie sheet',
#   'question 8-3': 'between two pieces of wax paper'},
#  'f-HX4T28NM': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 1-0': 'crushed roasted chickpeas',
#   'question 1-1': 'cream',
#   'question 1-2': 'onion',
#   'question 1-3': 'cauliflower',
#   'question 1-4': 'cauliflower',
#   'question 1-5': 'cauliflower',
#   'question 1-6': 'cauliflower',
#   'question 1-7': 'salt and pepper',
#   'question 10-0': 'crushed roasted chickpeas',
#   'question 16-0': 'from the oven',
#   'question 18-0': 'water',
#   'question 18-1': 'crushed powder',
#   'question 18-2': 'baking',
#   'question 18-3': 'by using a spatula',
#   'question 18-4': 'two',
#   'question 2-0': 'place the cauliflower in the pot',
#   'question 2-1': 'the',
#   'question 2-2': 'in a medium - sized dutch oven',
#   'question 3-0': 'cauliflower',
#   'question 3-1': 'cream',
#   'question 3-2': 'by combining the two',
#   'question 3-3': 'cauliflower',
#   'question 3-4': 'saute onion in olive oil',
#   'question 4-0': 'add - ons',
#   'question 4-1': 'add - ons',
#   'question 4-2': 'curried - cauliflower - and -ginger',
#   'question 4-3': 'in a skillet',
#   'question 4-4': 'by using a blender',
#   'question 4-5': 'by using a blender',
#   'question 5-0': 'saute onion in olive oil',
#   'question 5-1': 'to',
#   'question 5-2': 'to',
#   'question 6-0': 'over medium - low heat',
#   'question 6-1': 'using an immersion blender',
#   'question 7-0': 'approximately 30 minutes',
#   'question 8-0': 'the sheet pan',
#   'question 8-1': 'in large skillet'},
#  'f-JLH74DCR': {'question 0-0': 'rough chop cucumbers',
#   'question 0-1': 'two',
#   'question 0-2': 'a medium, securely sealable container',
#   'question 0-3': 'a medium, securely sealable container',
#   'question 0-4': 'three',
#   'question 1-0': 'soy sauce',
#   'question 12-0': 'the marinade',
#   'question 18-0': 'rough chop',
#   'question 18-1': 'two or four',
#   'question 18-2': 'three',
#   'question 2-0': 'rough chop cucumbers',
#   'question 3-0': '1 / 2 c mayonnaise',
#   'question 3-1': '1 / 2 c mayonnaise',
#   'question 3-2': 'sesame oil',
#   'question 3-3': 'sesame oil',
#   'question 4-0': 'soy sauce',
#   'question 4-1': 'pickled cucumber',
#   'question 8-0': 'the marinade',
#   'question 8-1': 'in a medium, securely sealable container'},
#  'f-KTQ82N6L': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'n / a',
#   'question 0-5': '2 -- 4 hours',
#   'question 1-0': 'potatoes',
#   'question 1-1': 'chives',
#   'question 1-2': 'cream',
#   'question 10-0': 'over low heat',
#   'question 10-1': 'crusty bread chunks',
#   'question 16-0': '3 / 4 of the bacon',
#   'question 17-0': 'in a saucepan',
#   'question 18-0': 'how to saffron threads',
#   'question 18-1': 'a saucepan',
#   'question 18-2': 'three',
#   'question 18-3': 'n / a',
#   'question 2-0': 'in a saucepan',
#   'question 2-1': 'over low heat',
#   'question 2-2': 'in a saucepan',
#   'question 2-3': 'in a saucepan',
#   'question 2-4': 'whisk the flour in the saucepan',
#   'question 3-0': 'shredded cheddar cheese',
#   'question 3-1': 'shredded cheddar cheese',
#   'question 3-2': 'cheese',
#   'question 3-3': 'cheese',
#   'question 4-0': 'easy - beer - cheese',
#   'question 4-1': 'shredded cheddar cheese',
#   'question 4-2': 'bacon grease',
#   'question 4-3': 'cream',
#   'question 4-4': 'easy - beer - cheese',
#   'question 4-5': 'saute spinach in a pan',
#   'question 5-0': 'slightly thickened',
#   'question 8-0': 'cream',
#   'question 8-1': 'in a saucepan'},
#  'f-KWBKC77L': {'question 0-0': 'three',
#   'question 0-1': 'three',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'two',
#   'question 1-0': 'pancetta',
#   'question 1-1': 'garlic',
#   'question 1-2': 'olive oil',
#   'question 1-3': 'olive oil',
#   'question 1-4': 'onions',
#   'question 1-5': 'the',
#   'question 1-6': 'the',
#   'question 1-7': 'potatoes',
#   'question 13-0': 'a serving bowl',
#   'question 15-0': 'why not',
#   'question 17-0': 'the',
#   'question 17-1': 'in',
#   'question 17-2': 'in',
#   'question 17-3': ',',
#   'question 17-4': ',',
#   'question 17-5': 'the',
#   'question 17-6': 'sliced onion',
#   'question 17-7': 'in the digestive tract',
#   'question 17-8': 'in the',
#   'question 18-0': 'two',
#   'question 18-1': "`` tridents ''",
#   'question 18-2': 'set the ham - bacon - onion mixture',
#   'question 18-3': 'stir the soup well',
#   'question 2-0': 'on a hot griddle',
#   'question 2-1': 'a serving bowl',
#   'question 2-2': 'the peel',
#   'question 2-3': 'a large frying pan',
#   'question 2-4': 'olive oil',
#   'question 2-5': 'in the',
#   'question 2-6': 'by using a spatula',
#   'question 4-0': 'the butter',
#   'question 4-1': 'serving',
#   'question 4-2': 'sauteing the potatoes',
#   'question 5-0': 'saute onion in olive oil',
#   'question 5-1': 'to',
#   'question 6-0': 'by using a spatula',
#   'question 8-0': 'into a serving bowl',
#   'question 8-1': 'on a hot griddle',
#   'question 8-2': 'in the serving bowl',
#   'question 8-3': 'in the heated pan'},
#  'f-PT5ZVJYJ': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 1-0': 'n',
#   'question 1-1': 'the',
#   'question 1-2': 'pancetta',
#   'question 1-3': "the bird's beak",
#   'question 18-0': 'polla -alla - parmigiana',
#   'question 18-1': 'the serratus ventralis muscle',
#   'question 18-2': 'aspartate',
#   'question 18-3': 'marjoram',
#   'question 18-4': 'mozzarella',
#   'question 2-0': 'by using a spatula',
#   'question 2-1': 'by using a spatula',
#   'question 2-2': 'both sides',
#   'question 2-3': 'the',
#   'question 2-4': 'the',
#   'question 2-5': 'pound the chicken breast or tights',
#   'question 2-6': 'remove the neck end',
#   'question 3-0': 'parmesan cheese',
#   'question 3-1': 'by accident',
#   'question 4-0': 'mozzarella slice tomato sauce',
#   'question 4-1': 'chicken loin',
#   'question 4-2': 'bread crumbs',
#   'question 4-3': 'chicken breast or tights',
#   'question 4-4': 'chicken loin',
#   'question 4-5': 'Cooking breaded thighs',
#   'question 5-0': 'pound the chicken breast or tights',
#   'question 5-1': 'to perfection',
#   'question 6-0': 'saute pancetta',
#   'question 6-1': 'with 1 tablespoon of water',
#   'question 7-0': '2 to 3 minutes',
#   'question 8-0': 'chicken breast or tights',
#   'question 8-1': 'from where',
#   'question 8-10': 'on a shallow dish',
#   'question 8-2': 'on a third dish',
#   'question 8-3': 'both sides',
#   'question 8-4': 'the chicken on both sides',
#   'question 8-5': 'on a shallow dish',
#   'question 8-6': 'both sides',
#   'question 8-7': 'the egg mixture',
#   'question 8-8': 'in a large saute pan',
#   'question 8-9': 'chicken breast or tights'},
#  'f-Q7FS58VW': {'question 0-0': 'two',
#   'question 0-1': '3',
#   'question 0-2': '8',
#   'question 0-3': 'two',
#   'question 1-0': '2 tomatoes',
#   'question 1-1': '2 tomatoes',
#   'question 1-10': 'herring',
#   'question 1-11': '2 / 4 tsp sugar',
#   'question 1-12': 'the skin',
#   'question 1-13': 'egg',
#   'question 1-14': 'prawns',
#   'question 1-2': '2 tomatoes',
#   'question 1-3': 'salt',
#   'question 1-4': 'top sirloin',
#   'question 1-5': 'cream',
#   'question 1-6': '2 tomatoes',
#   'question 1-7': 'salt',
#   'question 1-8': 'cream',
#   'question 1-9': 'herring',
#   'question 10-0': '2 tomatoes',
#   'question 10-1': 'in a blender',
#   'question 10-2': 'by using a fork',
#   'question 12-0': '2 tomatoes',
#   'question 13-0': '2 tomatoes',
#   'question 14-0': 'by using a whisk',
#   'question 17-0': 'the',
#   'question 17-1': 'the packaging',
#   'question 17-2': 'the packaging',
#   'question 17-3': '2 tomatoes',
#   'question 17-4': 'in',
#   'question 18-0': 'in a large mixing bowl',
#   'question 18-1': '2 / 4 tsp sugar',
#   'question 2-0': 'in a blender',
#   'question 2-1': 'in a blender',
#   'question 2-2': 'the mixing bowl',
#   'question 2-3': 'by using a knife',
#   'question 2-4': '2 tomatoes',
#   'question 2-5': '2 tomatoes',
#   'question 2-6': 'cut in half',
#   'question 2-7': 'in a colander',
#   'question 2-8': 'the caribbean',
#   'question 2-9': 'by using a whisk',
#   'question 3-0': 'in a blender',
#   'question 3-1': 'shallots',
#   'question 4-0': 'blanching the squid',
#   'question 4-1': 'in',
#   'question 4-2': 'mint leave',
#   'question 4-3': 'j',
#   'question 4-4': '2 tomatoes',
#   'question 6-0': 'by using a spatula',
#   'question 8-0': '2 tomatoes',
#   'question 8-1': '2 tomatoes',
#   'question 8-2': '2 tomatoes'},
#  'f-RYVXFZFV': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 1-0': 'gremolata',
#   'question 1-1': 'the beans',
#   'question 1-2': 'french green beans',
#   'question 12-0': 'the large saute pan',
#   'question 18-0': 'saute pancetta',
#   'question 18-1': 'the first layer',
#   'question 18-2': 'the rotor',
#   'question 18-3': 'green beans',
#   'question 2-0': 'the',
#   'question 2-1': 'in a large saute pan',
#   'question 2-2': 'a large pot of water',
#   'question 2-3': 'by using a strainer',
#   'question 2-4': 'pat them dry',
#   'question 4-0': 'french string beans',
#   'question 4-1': 'n / a',
#   'question 6-0': 'preheat oven to 400f',
#   'question 8-0': 'in a large saute pan',
#   'question 8-1': 'in a small bowl'},
#  'f-SJGXB864': {'question 0-0': '3',
#   'question 0-1': 'three',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'by using a knife',
#   'question 0-5': 'three',
#   'question 1-0': 'the beets',
#   'question 1-1': 'thyme',
#   'question 10-0': 'divide the beets into small groups',
#   'question 10-1': 'warm or chilled',
#   'question 10-2': 'gently toss the beets',
#   'question 10-3': 'wrap the beets and onion in aluminum foil',
#   'question 10-4': 'Wrap the beets and the onions carefully',
#   'question 13-0': 'aluminum foil',
#   'question 14-0': 'preheat the oven',
#   'question 15-0': 'why not',
#   'question 17-0': 'the garden',
#   'question 17-1': 'beets',
#   'question 17-2': 'the',
#   'question 17-3': 'in the garden',
#   'question 18-0': 'by using a blender',
#   'question 18-1': 'beets',
#   'question 18-2': 'by using a knife',
#   'question 18-3': '1 / 2 tsp balsamic vinegar',
#   'question 18-4': 'by using a spatula',
#   'question 2-0': 'warm or chilled',
#   'question 2-1': 'cut them lengthwise',
#   'question 2-2': '1 / 3 - inch - thick',
#   'question 2-3': 'in a bowl',
#   'question 2-4': 'the',
#   'question 3-0': 'beets',
#   'question 3-1': 'beets',
#   'question 3-2': 'in a blender',
#   'question 3-3': 'divide the beets into small groups',
#   'question 4-0': "`` throwing ''",
#   'question 4-1': 'peeling the beets',
#   'question 4-2': 'the',
#   'question 5-0': 'in the oven',
#   'question 6-0': 'roast the beets and onion groups',
#   'question 7-0': '1 1 / 2 to 2 hours',
#   'question 8-0': 'in a bowl',
#   'question 8-1': 'the packaging'},
#  'f-SJPFNVTY': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'a stack of many types of chocolate',
#   'question 1-0': 'the',
#   'question 1-1': 'the flour',
#   'question 1-2': 'an ice cream',
#   'question 1-3': 'garnish',
#   'question 1-4': 'baking soda',
#   'question 10-0': 'whisk your water',
#   'question 10-1': 'by using a spatula',
#   'question 12-0': 'tortilla',
#   'question 17-0': 'the',
#   'question 17-1': 'the middle of the playground',
#   'question 17-2': 'the',
#   'question 17-3': 'in the',
#   'question 18-0': '12 to 16 minutes',
#   'question 18-1': 'by adding the flour',
#   'question 18-2': 'the',
#   'question 2-0': 'in a smaller bowl',
#   'question 2-1': 'the',
#   'question 2-2': 'by using a spatula',
#   'question 2-3': 'the bowl',
#   'question 2-4': 'in a moderate oven',
#   'question 2-5': 'garnish the surface',
#   'question 3-0': 'by accident',
#   'question 3-1': 'vanilla',
#   'question 4-0': 'by using a spatula',
#   'question 4-1': 'baking',
#   'question 4-2': 'n / a',
#   'question 4-3': 'by using a whisk',
#   'question 4-4': 'tortilla',
#   'question 4-5': 'tortilla',
#   'question 5-0': 'for 8 - 10 minutes',
#   'question 6-0': 'blend eggs and seasonings',
#   'question 6-1': 'spoon the batter in',
#   'question 7-0': '30 to 35 minutes',
#   'question 8-0': 'in a medium bowl',
#   'question 9-0': 'in a medium bowl'},
#  'f-XNVJGJVP': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'two',
#   'question 0-5': 'two',
#   'question 1-0': 'the excess oil',
#   'question 1-1': 'vegetable oil',
#   'question 1-2': 'potatoes',
#   'question 1-3': 'potatoes',
#   'question 1-4': 'the excess juice',
#   'question 1-5': 'the',
#   'question 10-0': 'vegetable oil for frying',
#   'question 10-1': 'carefully turn over',
#   'question 15-0': 'to drain the excess oil',
#   'question 17-0': 'the',
#   'question 17-1': 'the',
#   'question 17-2': 'the',
#   'question 17-3': 'in the',
#   'question 17-4': 'in a kitchen towel',
#   'question 17-5': 'in a kitchen towel',
#   'question 17-6': 'in a kitchen towel',
#   'question 18-0': '2 cooked beets',
#   'question 18-1': 'in a food processor',
#   'question 18-2': 'heat 2 tablespoons of olive oil',
#   'question 18-3': 'the',
#   'question 18-4': '1 / 2 tsp. black pepper',
#   'question 2-0': 'using two tablespoons',
#   'question 2-1': 'the oil',
#   'question 2-2': 'in a large cast iron frying pan',
#   'question 2-3': 'in the food processor',
#   'question 2-4': 'in a food processor',
#   'question 3-0': 'by using a tonga',
#   'question 3-1': 'by using a tonga',
#   'question 3-2': '1 egg',
#   'question 3-3': '1 egg',
#   'question 4-0': 'the other side',
#   'question 4-1': 'vegetable oil',
#   'question 4-2': 'potatoes',
#   'question 4-3': 'placing on paper towels',
#   'question 4-4': 'vegetable oil for frying',
#   'question 4-5': 'by using a spatula',
#   'question 6-0': 'using two tablespoons',
#   'question 6-1': 'place slices of the potatoes and onion',
#   'question 8-0': 'in the food processor',
#   'question 8-1': 'in a large cast iron frying pan',
#   'question 8-2': 'in a kitchen towel',
#   'question 8-3': 'in the food processor',
#   'question 8-4': 'on paper towels',
#   'question 8-5': 'the oil'},
#  'f-YGBD7J2L': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'puree kidney beans and beets',
#   'question 0-3': 'two',
#   'question 0-4': '8 * 8 inch',
#   'question 1-0': 'beets',
#   'question 1-1': 'beets',
#   'question 1-2': 'milk',
#   'question 1-3': 'heart shapes',
#   'question 14-0': 'by using a spatula',
#   'question 14-1': 'preheat oven to 325 ° f',
#   'question 17-0': 'the',
#   'question 17-1': 'the',
#   'question 17-2': 'food processor',
#   'question 17-3': 'bag',
#   'question 18-0': 'on a piece of folded foil',
#   'question 18-1': 'heart shapes',
#   'question 18-2': 'the first layer',
#   'question 2-0': 'the refrigerator',
#   'question 2-1': 'a large bowl',
#   'question 2-2': 'the bowl before you begin',
#   'question 2-3': 'by hand',
#   'question 3-0': 'cooked beets',
#   'question 3-1': 'cocoa powder',
#   'question 4-0': 'add stock',
#   'question 4-1': 'akeem olajuwon',
#   'question 4-2': 'by hand',
#   'question 4-3': '1 / 2 cup red kidney beans',
#   'question 4-4': 'pan',
#   'question 5-0': 'by hand',
#   'question 6-0': 'by hand',
#   'question 6-1': 'in a food processor',
#   'question 7-0': '35 to 40 minutes',
#   'question 7-1': 'one hour',
#   'question 8-0': 'the toothpick',
#   'question 8-1': 'the greased pan',
#   'question 8-2': 'a large bowl'},
#  'f-Z82FPVW4': {'question 0-0': '3',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': '3',
#   'question 1-0': 'artichokes',
#   'question 1-1': 'pumpkin',
#   'question 1-2': 'beans',
#   'question 10-0': 'pumpkin - tomato soup',
#   'question 17-0': 'the',
#   'question 17-1': 'the',
#   'question 17-2': '1 cup of fresh breadcrumbs',
#   'question 18-0': 'lentils',
#   'question 18-1': 'the middle of the soup',
#   'question 2-0': 'the baking pan',
#   'question 2-1': 'a sauce pot',
#   'question 2-2': 'a sauce pot',
#   'question 2-3': 'a sauce pot',
#   'question 2-4': 'a sauce pot',
#   'question 2-5': 'n',
#   'question 2-6': 'a sauce pot',
#   'question 3-0': 'n / a',
#   'question 3-1': 'artichokes',
#   'question 4-0': 'taylor',
#   'question 4-1': 'the',
#   'question 4-2': 'with',
#   'question 4-3': 'the',
#   'question 4-4': 'by using a spatula',
#   'question 4-5': 'by using a spatula',
#   'question 5-0': 'to',
#   'question 6-0': 'by using a strainer',
#   'question 7-0': 'about 12 minutes'},
#  'r-1007': {'question 0-0': 'two',
#   'question 0-1': 'three',
#   'question 0-2': '12',
#   'question 0-3': 'two',
#   'question 1-0': 'baked in the oven',
#   'question 1-1': 'lemonade',
#   'question 17-0': 'in a bun tin',
#   'question 17-1': 'the',
#   'question 17-2': 'n / a',
#   'question 18-0': 'two',
#   'question 18-1': 'pre-heated oven',
#   'question 2-0': 'over the tops',
#   'question 2-1': 'pre-heated oven',
#   'question 2-2': 'piping - bag',
#   'question 2-3': 'pipe',
#   'question 3-0': 'lemon zest',
#   'question 3-1': 'drinking wine',
#   'question 3-2': 'drinking wine',
#   'question 4-0': 'lemonade',
#   'question 4-1': 'by using a spatula',
#   'question 4-2': 'by using a whisk',
#   'question 4-3': 'by using a spatula',
#   'question 4-4': 'by using a strainer',
#   'question 4-5': 'by using a circular movement',
#   'question 5-0': 'preheat oven to 350 degf',
#   'question 6-0': 'in a pre-heated oven',
#   'question 6-1': 'by using a spatula',
#   'question 8-0': 'in the centre',
#   'question 8-1': 'over the tops',
#   'question 8-2': 'a piping - bag',
#   'question 8-3': 'in a bun tin',
#   'question 8-4': "`` trinkets ''",
#   'question 8-5': 'in a bun tin',
#   'question 8-6': 'in a piping - bag'},
#  'r-103': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'three steps',
#   'question 0-3': 'reduce the peas to a paste',
#   'question 0-4': 'two',
#   'question 1-0': 'tiraṅgā',
#   'question 12-0': 'in a large bowl',
#   'question 14-0': 'by using a turner',
#   'question 18-0': 'puree the cauliflower in a blender',
#   'question 18-1': 'two',
#   'question 18-2': 'split peas',
#   'question 18-3': 'khira aur jhinga ka thanda',
#   'question 2-0': 'let the peas soak overnight',
#   'question 2-1': 'slightly flatten the balls',
#   'question 2-2': 'chile',
#   'question 4-0': 'split peas',
#   'question 4-1': 'split peas',
#   'question 8-0': 'in a large bowl',
#   'question 9-0': 'slightly flatten the balls'},
#  'r-1031': {'question 0-0': 'three',
#   'question 0-1': 'three',
#   'question 0-2': 'two',
#   'question 0-3': 'three',
#   'question 0-4': 'three',
#   'question 1-0': 'egg',
#   'question 1-1': 'tomatoes',
#   'question 1-2': 'egg',
#   'question 1-3': 'wine',
#   'question 1-4': 'eggs',
#   'question 1-5': 'bacon',
#   'question 12-0': 'lettuce',
#   'question 12-1': 'in a large serving bowl',
#   'question 17-0': 'the',
#   'question 17-1': 'in the',
#   'question 18-0': 'sherry',
#   'question 18-1': 'potatoes',
#   'question 2-0': 'in the digestive tract',
#   'question 2-1': 'in the',
#   'question 2-2': 'in a blender',
#   'question 2-3': 'in a large bowl',
#   'question 2-4': 'over hot dressing',
#   'question 2-5': 'lettuce',
#   'question 2-6': 'in a large serving bowl',
#   'question 3-0': 'by tossing the potatoes',
#   'question 3-1': 'the',
#   'question 3-2': 'n / a',
#   'question 3-3': '1 / 2 lb leaf lettuce',
#   'question 3-4': 'black olives',
#   'question 4-0': 'hot dutch potatoes',
#   'question 4-1': 'bacon',
#   'question 4-2': 'chopped bacon',
#   'question 4-3': 'bacon',
#   'question 4-4': "`` throwing ''",
#   'question 4-5': "`` apricot ''",
#   'question 8-0': 'in a small bowl',
#   'question 8-1': 'over hot dressing'},
#  'r-1043': {'question 0-0': 'two different processes',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 1-0': 'milk',
#   'question 1-1': 'flour',
#   'question 1-2': 'ham',
#   'question 1-3': 'salt',
#   'question 1-4': 'ham',
#   'question 1-5': 'flour',
#   'question 1-6': 'salt',
#   'question 1-7': 'the',
#   'question 12-0': '1 tablespoon flour',
#   'question 15-0': 'to rise',
#   'question 15-1': 'to rise',
#   'question 15-2': 'setting',
#   'question 15-3': 'to make a soft batter',
#   'question 17-0': 'in the',
#   'question 17-1': 'the',
#   'question 17-2': 'in',
#   'question 18-0': 'a large bowl',
#   'question 18-1': 'the middle of the playground',
#   'question 18-2': 'spade',
#   'question 18-3': 'the large bowl',
#   'question 2-0': 'in warm water',
#   'question 2-1': 'a large bowl',
#   'question 2-2': 'the frying pan',
#   'question 2-3': 'by using a spatula',
#   'question 2-4': 'beat eggs in a large bowl',
#   'question 2-5': 'frying pan',
#   'question 2-6': 'dissolve yeast in warm water',
#   'question 2-7': 'the middle of the playground',
#   'question 2-8': 'by using a mixer',
#   'question 3-0': 'cheese',
#   'question 3-1': 'cheese',
#   'question 3-2': 'by using a spatula',
#   'question 3-3': 'saute onion and garlic in olive oil',
#   'question 3-4': 'by using a whisk',
#   'question 4-0': 'the',
#   'question 4-1': 'egg benedict',
#   'question 4-2': 'cake of yeast',
#   'question 4-3': 'n / a',
#   'question 4-4': 'the',
#   'question 4-5': 'ham',
#   'question 5-0': 'preheat the oven',
#   'question 6-0': 'in warm water',
#   'question 7-0': '2 minutes',
#   'question 7-1': 'about 2 or 3 hours',
#   'question 7-2': 'about 1 hour',
#   'question 8-0': 'a large bowl'},
#  'r-1094': {'question 0-0': 'three',
#   'question 0-1': 'two',
#   'question 0-2': 'three steps',
#   'question 0-3': 'three steps',
#   'question 0-4': 'two',
#   'question 1-0': 'chicken',
#   'question 1-1': 'celery',
#   'question 10-0': 'by itself',
#   'question 15-0': ',',
#   'question 17-0': 'in a large mixing bowl',
#   'question 17-1': 'in',
#   'question 18-0': 'by using a spoon',
#   'question 18-1': 'the',
#   'question 18-2': 'egg',
#   'question 18-3': 'chicken breasts',
#   'question 2-0': 'over chicken mixture',
#   'question 2-1': 'in a large bowl',
#   'question 2-2': 'a large bowl',
#   'question 2-3': 'in a blender',
#   'question 3-0': 'celery',
#   'question 3-1': 'can chunk chicken breasts',
#   'question 4-0': 'celery',
#   'question 4-1': 'chicken mixture',
#   'question 4-2': 'chicken breasts',
#   'question 4-3': 'chicken',
#   'question 4-4': 'chicken',
#   'question 4-5': 'chicken',
#   'question 8-0': 'in a large bowl',
#   'question 8-1': 'over chicken mixture'},
#  'r-1159': {'question 0-0': '5',
#   'question 0-1': 'three',
#   'question 0-2': 'two',
#   'question 1-0': 'plain greek style yogurt',
#   'question 1-1': 'plain greek style yogurt',
#   'question 1-2': 'saffron',
#   'question 1-3': 'sugar',
#   'question 1-4': 'saffron',
#   'question 15-0': 'for ease',
#   'question 18-0': 'the',
#   'question 18-1': 'water',
#   'question 18-2': 'in the refrigerator',
#   'question 2-0': 'in a bowl',
#   'question 2-1': 'in a bowl',
#   'question 2-2': 'in a bowl',
#   'question 2-3': 'press the yogurt against the wall',
#   'question 2-4': 'in muslin cloth',
#   'question 3-0': 'by mixing the ingredients',
#   'question 4-0': 'plain greek style yogurt',
#   'question 4-1': 'plain greek style yogurt',
#   'question 7-0': '5 - 6 hours',
#   'question 8-0': 'in a bowl',
#   'question 8-1': 'in muslin cloth'},
#  'r-1165': {'question 0-0': 'two',
#   'question 0-1': 'n / a',
#   'question 0-2': 'two',
#   'question 0-3': 'three',
#   'question 0-4': 'two',
#   'question 1-0': 'pasta',
#   'question 1-1': 'lettuce',
#   'question 1-2': 'pickled pearl onions',
#   'question 10-0': 'sliced hard boiled egg',
#   'question 10-1': 'salt and pepper',
#   'question 15-0': 'for best flavor',
#   'question 17-0': 'the',
#   'question 17-1': 'the',
#   'question 18-0': 'potatoes',
#   'question 18-1': 'two',
#   'question 18-2': 'the cooling rack',
#   'question 2-0': 'over the top',
#   'question 2-1': 'a dusting of paprika',
#   'question 2-2': 'the refrigerator',
#   'question 2-3': 'the large mixing bowl',
#   'question 3-0': 'pickled pearl onions',
#   'question 3-1': 'pickled pearl onions',
#   'question 3-2': '2 cooked beets',
#   'question 3-3': ',',
#   'question 4-0': 'sliced hard boiled egg',
#   'question 4-1': 'the huzarensla',
#   'question 4-2': 'first',
#   'question 4-3': 'the',
#   'question 4-4': 'the huzarensla',
#   'question 4-5': 'the',
#   'question 7-0': 'a couple of hours',
#   'question 8-0': 'on a platter lined with lettuce leaves',
#   'question 8-1': 'over the top'},
#  'r-1166': {'question 0-0': 'n / a',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'three',
#   'question 0-4': 'three',
#   'question 1-0': 'pickled herring',
#   'question 1-1': 'lettuce leaves',
#   'question 1-2': 'lettuce leaves',
#   'question 1-3': 'prawn',
#   'question 1-4': 'cream',
#   'question 10-0': 'lettuce leaves',
#   'question 10-1': 'gherkin',
#   'question 10-2': 'spread the batter evenly',
#   'question 12-0': 'herring',
#   'question 15-0': 'for the garnish',
#   'question 17-0': 'lettuce leaves',
#   'question 17-1': 'in',
#   'question 18-0': 'three',
#   'question 18-1': 'saute onion in olive oil',
#   'question 18-2': 'in',
#   'question 2-0': 'chop the egg whites',
#   'question 2-1': 'by using a peeler',
#   'question 2-2': 'the',
#   'question 2-3': 'the dressing',
#   'question 2-4': 'spread the mixture evenly',
#   'question 2-5': 'cover the mayonnaise with flour',
#   'question 2-6': 'over the lettuce leaves',
#   'question 2-7': 'over the lettuce',
#   'question 3-0': '3 pickled herring',
#   'question 3-1': 'pickled herring',
#   'question 4-0': 'egg whites',
#   'question 4-1': 'the',
#   'question 4-2': 'for garnish',
#   'question 4-3': 'for',
#   'question 4-4': 'n / a',
#   'question 4-5': 'n / a',
#   'question 8-0': 'in'},
#  'r-117': {'question 0-0': 'three steps',
#   'question 0-1': 'three steps',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': '10 - 12 minutes',
#   'question 0-5': 'two',
#   'question 1-0': 'fish fritters',
#   'question 1-1': 'the fish',
#   'question 1-2': 'turmeric',
#   'question 1-3': 'his body',
#   'question 1-4': 'a cookie',
#   'question 14-0': '1 / 2 tsp salt',
#   'question 16-0': 'in a mortar',
#   'question 17-0': 'his garret',
#   'question 18-0': 'by using a spoon',
#   'question 18-1': 'salt',
#   'question 2-0': 'in a mortar',
#   'question 2-1': 'moistureen your hands with water',
#   'question 2-2': '1 / 2 tsp salt',
#   'question 2-3': "`` banging ''",
#   'question 2-4': 'in a mortar',
#   'question 2-5': 'in a mortar',
#   'question 3-0': 'fillet the fish and flake the flesh',
#   'question 3-1': 'turmeric',
#   'question 4-0': 'the flesh',
#   'question 4-1': 'fish fritters',
#   'question 4-2': 'fish fritters',
#   'question 5-0': 'deep - fry',
#   'question 6-0': 'water',
#   'question 6-1': 'in absorbent paper',
#   'question 7-0': '10 - 12 minutes',
#   'question 7-1': 'for 2 minutes',
#   'question 8-0': 'fillet the fish and flake the flesh',
#   'question 8-1': 'on your palm',
#   'question 8-2': 'in a pan'},
#  'r-1275': {'question 0-0': 'three',
#   'question 0-1': 'two',
#   'question 0-2': '5',
#   'question 0-3': 'three',
#   'question 1-0': 'mayonnaise',
#   'question 1-1': 'the',
#   'question 1-2': 'kage_med_ sm',
#   'question 1-3': 'alcohol',
#   'question 1-4': 'sugar',
#   'question 1-5': 'bread',
#   'question 10-0': 'beat the eggs and sugar',
#   'question 10-1': 'beat the batter',
#   'question 10-2': 'layer 3',
#   'question 10-3': 'press the top of the cake',
#   'question 17-0': 'bottom of the pan',
#   'question 18-0': 'two',
#   'question 18-1': 'a plate of sliced up water',
#   'question 18-2': 'morton',
#   'question 18-3': 'leave the raspberry sauce cold',
#   'question 2-0': 'by using a blender',
#   'question 2-1': 'spread the rest of the filling',
#   'question 2-2': 'cut it into two layers',
#   'question 2-3': 'press chopped almonds lightly',
#   'question 2-4': 'beat the batter',
#   'question 2-5': 'beat the eggs and sugar',
#   'question 2-6': 'in medium bowl',
#   'question 3-0': 'cake flour',
#   'question 3-1': 'water',
#   'question 3-2': 'drug trafficking',
#   'question 3-3': 'by accident',
#   'question 4-0': 'the first layer',
#   'question 4-1': 'beating the eggs',
#   'question 4-2': 'preheat oven to 350degf',
#   'question 4-3': 'second layer',
#   'question 4-4': 'spreading with the filling',
#   'question 6-0': 'how - stən',
#   'question 7-0': 'for 20 to 25 minutes',
#   'question 7-1': 'for 20 to 25 minutes',
#   'question 8-0': "`` bounce mat ''",
#   'question 8-1': 'on a cake rack',
#   'question 8-2': 'over the top',
#   'question 8-3': 'the edge of the cake'},
#  'r-1304': {'question 0-0': '5',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'two',
#   'question 1-0': 'rye bread',
#   'question 1-1': 'rye bread',
#   'question 1-2': 'saurkraut',
#   'question 1-3': 'the accent',
#   'question 10-0': 'criss - crossed cheese slices',
#   'question 16-0': 'Drain the saurkraut',
#   'question 17-0': 'in the',
#   'question 18-0': "rubens's recipe",
#   'question 18-1': "Rubens's original recipe",
#   'question 18-2': 'three',
#   'question 2-0': 'Brush rye bread with butter',
#   'question 2-1': 'remove the saurkraut',
#   'question 2-2': 'the packaging',
#   'question 2-3': 'baking sheet',
#   'question 2-4': 'the synagogue',
#   'question 2-5': 'butter on both sides',
#   'question 2-6': 'in small skillet',
#   'question 2-7': 'slice saurkraut into 1 / 4 inch',
#   'question 2-8': 'criss - crossed cheese slices',
#   'question 4-0': 'cheese slices',
#   'question 4-1': 'cheese slices',
#   'question 4-2': 'cheese slices',
# ...
#   'question 0-4': 'two',
#   'question 1-0': 'the remaining ingredients',
#   'question 1-1': 'walnut sized balls',
#   'question 1-2': 'peanut butter',
#   'question 1-3': 'a half peanut',
#   'question 1-4': 'the',
#   'question 1-5': 'peanuts',
#   'question 10-0': 'on wire racks',
#   'question 10-1': 'first melt fat',
#   'question 17-0': 'in',
#   'question 18-0': 'three',
#   'question 18-1': 'onto cookie',
#   'question 18-2': 'two',
#   'question 18-3': 'heat the butter in oil',
#   'question 2-0': 'on greased pans',
#   'question 2-1': 'the 12 - inch pizza pan',
#   'question 3-0': 'by mixing the batter',
#   'question 3-1': 'vanilla',
#   'question 3-2': ',',
#   'question 3-3': 'by combining the elements',
#   'question 3-4': 'milk',
#   'question 3-5': 'peanut butter',
#   'question 4-0': 'cake flour',
#   'question 4-1': '1 / 2 tsp baking soda',
#   'question 4-2': "`` flour ''",
#   'question 4-3': 'oil',
#   'question 4-4': 'peanut butter',
#   'question 4-5': 'heat the oven to 375degf',
#   'question 6-0': 'drop by teaspoonfuls',
#   'question 6-1': 'roll into balls',
#   'question 7-0': '3 hours',
#   'question 7-1': '30 to 40 minutes',
#   'question 8-0': 'a half peanut'},
#  'r-4969': {'question 0-0': 'two',
#   'question 0-1': '2',
#   'question 0-2': 'two',
#   'question 1-0': 'tomato',
#   'question 1-1': 'tortilla chips',
#   'question 10-0': 'mash avocado roughly',
#   'question 10-1': 'tortilla chips',
#   'question 18-0': 'south - of - the - border',
#   'question 18-1': 'milk',
#   'question 18-2': '3 / 4 tsp',
#   'question 18-3': 'stir all ingredients together',
#   'question 2-0': 'mash avocado roughly',
#   'question 3-0': 'red pepper sauce',
#   'question 3-1': 'red pepper sauce',
#   'question 3-2': 'by combining the avocados',
#   'question 4-0': 'mashing avocados',
#   'question 4-1': "`` apricot ''",
#   'question 4-2': 'saute scallions over low heat',
#   'question 4-3': 'the',
#   'question 4-4': 'tomato',
#   'question 4-5': 'n / a',
#   'question 8-0': 'food processor'},
#  'r-5062': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'two',
#   'question 1-0': 'sliced zucchini',
#   'question 1-1': 'sliced zucchini',
#   'question 10-0': "dip suggested veggies '",
#   'question 10-1': 'sliced zucchini',
#   'question 14-0': 'heat oil to 375 degf',
#   'question 18-0': 'two',
#   'question 18-1': 'sliced zucchini',
#   'question 2-0': 'in large bowl',
#   'question 2-1': 'smooth and well blended',
#   'question 3-0': 'sliced zucchini',
#   'question 3-1': 'by beating the flour mixture',
#   'question 3-2': 'by accident',
#   'question 3-3': 'bread',
#   'question 4-0': 'n',
#   'question 4-1': 'n',
#   'question 4-2': 'sliced zucchini',
#   'question 4-3': 'n / a',
#   'question 4-4': 'sliced zucchini',
#   'question 5-0': 'smooth and well blended',
#   'question 5-1': 'to',
#   'question 6-0': 'preheat oven to 375degf',
#   'question 7-0': '10 minutes',
#   'question 8-0': 'on paper towels',
#   'question 8-1': 'into hot oil',
#   'question 8-2': 'n',
#   'question 8-3': 'in large bowl'},
#  'r-5079': {'question 0-0': 'in one bowl',
#   'question 0-1': '3',
#   'question 0-2': 'one',
#   'question 0-3': 'two',
#   'question 0-4': 'two',
#   'question 1-0': 'tortilla chips',
#   'question 1-1': 'tomato',
#   'question 10-0': 'tortilla chips',
#   'question 18-0': 'tortilla',
#   'question 18-1': 'preheat oven to 375degf',
#   'question 18-2': 'in one bowl',
#   'question 18-3': 'in the top of a double boiler',
#   'question 18-4': 'in the caribbean',
#   'question 2-0': 'in another bowl',
#   'question 2-1': 'in another bowl',
#   'question 3-0': '4 Hass avocados',
#   'question 3-1': 'by combining the avocados',
#   'question 3-2': 'california chile',
#   'question 4-0': 'tomato mixture',
#   'question 4-1': "amanda's guacamole",
#   'question 4-2': "amanda's guacamole",
#   'question 4-3': 'amanda % 27s_ guac',
#   'question 4-4': "amanda's guacamole",
#   'question 4-5': 'a plate',
#   'question 8-0': 'in one bowl',
#   'question 8-1': 'in another bowl'},
#  'r-5105': {'question 0-0': 'three steps',
#   'question 0-1': 'two different processes',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': 'two',
#   'question 1-0': 'alcohol',
#   'question 1-1': 'all filling ingredients',
#   'question 1-2': 'salt',
#   'question 1-3': 'honey',
#   'question 1-4': 'aluminum foil',
#   'question 1-5': 'the',
#   'question 1-6': 'eggs',
#   'question 1-7': 'any remaining excess flour',
#   'question 1-8': 'air',
#   'question 1-9': 'pumpkin',
#   'question 10-0': 'press pizza dough evenly',
#   'question 10-1': 'gradually beat in about 4 cups',
#   'question 10-2': 'beat the yeast mix',
#   'question 15-0': 'to make a soft dough',
#   'question 15-1': 'to make a stiff dough',
#   'question 15-2': 'to flatten slightly',
#   'question 17-0': 'the',
#   'question 17-1': 'the',
#   'question 17-2': 'the middle of the playground',
#   'question 17-3': 'the',
#   'question 17-4': 'in a bowl',
#   'question 18-0': 'preheat oven to 450 degf',
#   'question 18-1': 'into the',
#   'question 18-2': 'n / a',
#   'question 2-0': 'in a large bowl',
#   'question 2-1': 'the middle of the playground',
#   'question 2-10': '8.5 - inch',
#   'question 2-11': 'the packaging',
#   'question 2-12': 'narrow strips of aluminum foil',
#   'question 2-13': 'the middle of the playground',
#   'question 2-14': 'a floured board',
#   'question 2-2': 'press pizza dough evenly',
#   'question 2-3': 'press pizza dough evenly',
#   'question 2-4': 'in a large bowl',
#   'question 2-5': 'beat well',
#   'question 2-6': 'beat the yeast mix',
#   'question 2-7': 'by using a spoon',
#   'question 2-8': 'in a large bowl',
#   'question 2-9': 'in a large bowl',
#   'question 3-0': 'by using a spatula',
#   'question 3-1': 'yeast',
#   'question 4-0': 'n / a',
#   'question 4-1': 'spices',
#   'question 4-2': 'n',
#   'question 4-3': 'press pizza dough evenly',
#   'question 4-4': '4 cups of the combined flours',
#   'question 5-0': 'until doubled',
#   'question 5-1': 'until doubled',
#   'question 5-2': 'almost double',
#   'question 6-0': 'dissolve yeast in a large bowl',
#   'question 7-0': '5 minutes',
#   'question 7-1': '11 to 2 hours',
#   'question 8-0': 'in 2 greased 9 - inch round baking pans',
#   'question 8-1': 'in a large bowl',
#   'question 8-2': 'in a bowl',
#   'question 8-3': '2 greased 9 - inch round baking pans',
#   'question 8-4': 'in a warm place',
#   'question 8-5': 'on floured surface'},
#  'r-648': {'question 0-0': 'three',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 18-0': 'bean sprouts',
#   'question 18-1': '15 minutes',
#   'question 18-2': 'opposite side of the hinge',
#   'question 2-0': 'in the netherlands',
#   'question 2-1': 'in water',
#   'question 4-0': 'pho_ bo',
#   'question 4-1': 'a',
#   'question 4-2': 'bean sprouts',
#   'question 4-3': 'seasonings',
#   'question 4-4': 'the',
#   'question 4-5': 'n',
#   'question 6-0': 'in water',
#   'question 7-0': '15 minutes'},
#  'r-679': {'question 0-0': 'three',
#   'question 0-1': '6',
#   'question 1-0': 'the',
#   'question 1-1': 'chopped chives',
#   'question 15-0': 'once mushrooms are cooked',
#   'question 18-0': 'in',
#   'question 18-1': 'in a bowl',
#   'question 18-2': 'by using a spatula',
#   'question 4-0': 'in',
#   'question 4-1': 'soup',
#   'question 4-2': 'soup',
#   'question 4-3': 'the',
#   'question 4-4': 'the',
#   'question 4-5': "`` tequila ''",
#   'question 6-0': 'by using a whisk'},
#  'r-716': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 1-0': 'potatoes',
#   'question 1-1': 'sliced egg',
#   'question 10-0': 'gently but thoroughly',
#   'question 10-1': 'whisk together the salt and pepper',
#   'question 18-0': 'sugar',
#   'question 18-1': 'three',
#   'question 18-2': 'potatoes',
#   'question 18-3': 'the skin',
#   'question 18-4': 'by using a spatula',
#   'question 2-0': 'in a bowl',
#   'question 3-0': ',',
#   'question 3-1': 'n / a',
#   'question 3-2': 'white wine',
#   'question 3-3': '2 hard - boiling eggs',
#   'question 4-0': 'n',
#   'question 4-1': 'garnish with beets',
#   'question 4-2': 'n',
#   'question 4-3': 'austrian potato salad',
#   'question 4-4': 'potatoes',
#   'question 4-5': 'n / a',
#   'question 5-0': 'whisk together the salt and pepper',
#   'question 8-0': 'in a bowl',
#   'question 8-1': 'in a bowl'},
#  'r-815': {'question 0-0': 'three steps',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': '8',
#   'question 1-0': 'lamb',
#   'question 1-1': 'lamb',
#   'question 1-2': 'turmeric',
#   'question 1-3': 'lamb shoulder',
#   'question 1-4': 'lamb',
#   'question 1-5': 'lamb shoulder, sliced',
#   'question 1-6': 'turmeric',
#   'question 1-7': 'salt',
#   'question 10-0': 'serve hot',
#   'question 12-0': 'the butter',
#   'question 17-0': ',',
#   'question 17-1': 'in the',
#   'question 17-2': ',',
#   'question 17-3': 'the',
#   'question 17-4': 'the',
#   'question 18-0': 'two',
#   'question 18-1': 'flattened rice',
#   'question 2-0': 'the camphor',
#   'question 2-1': 'the large frying pan',
#   'question 2-10': 'by using a knife',
#   'question 2-2': 'the butter',
#   'question 2-3': 'the',
#   'question 2-4': 'the yogurt',
#   'question 2-5': 'yogurt',
#   'question 2-6': 'the',
#   'question 2-7': 'the bowl below',
#   'question 2-8': 'the butter',
#   'question 2-9': 'Divide the lamb in two',
#   'question 3-0': 'turmeric',
#   'question 3-1': 'ginger powder',
#   'question 3-2': 'by using a mixer',
#   'question 3-3': 'by mixing the meat mixture',
#   'question 4-0': "a rooster's beak",
#   'question 4-1': 'the',
#   'question 4-2': "a rooster's beak",
#   'question 4-3': 'cover up',
#   'question 4-4': 'the',
#   'question 7-0': 'about 40 minutes',
#   'question 7-1': '10 minutes',
#   'question 8-0': 'the yogurt'},
#  'r-857': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two or four',
#   'question 0-4': 'two or four',
#   'question 1-0': 'olive oil',
#   'question 1-1': 'mozzarella',
#   'question 10-0': 'in a circle',
#   'question 10-1': 'serve with salt and pepper',
#   'question 17-0': 'the middle of the playground',
#   'question 17-1': 'the',
#   'question 17-2': 'in the caribbean',
#   'question 17-3': 'in',
#   'question 17-4': 'the',
#   'question 17-5': 'new york city',
#   'question 18-0': 'mozzarella',
#   'question 18-1': 'cut off the top',
#   'question 18-2': 'cut the dough into shape',
#   'question 2-0': 'slice tomatoes and mozzarella cheese same thickness',
#   'question 2-1': 'around a decorative serving dish',
#   'question 2-2': 'olive oil',
#   'question 2-3': 'a decorative serving dish',
#   'question 4-0': 'serve with salt and pepper',
#   'question 4-1': 'sliced tomatoes',
#   'question 4-2': '2 large tomatoes',
#   'question 4-3': 'serve with salt and pepper',
#   'question 4-4': '2 large tomatoes',
#   'question 4-5': '2 large tomatoes',
#   'question 6-0': 'drizzle with olive oil',
#   'question 8-0': 'around a decorative serving dish',
#   'question 9-0': 'sliced tomatoes and mozzarella cheese'},
#  'r-872': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': '1',
#   'question 0-3': 'two',
#   'question 1-0': 'knives',
#   'question 1-1': 'n',
#   'question 1-2': 'scallops',
#   'question 1-3': 'potatoes',
#   'question 1-4': 'chicken stock',
#   'question 1-5': 'potatoes',
#   'question 1-6': 'potatoes',
#   'question 1-7': 'placed prior to the bake',
#   'question 10-0': 'pouring the brandy',
#   'question 10-1': 'into a blender',
#   'question 10-2': 'nik naks',
#   'question 12-0': 'wash and dry the scallops',
#   'question 16-0': 'from the pan',
#   'question 17-0': 'courgette',
#   'question 17-1': 'the skin',
#   'question 17-10': 'coquilles',
#   'question 17-2': 'the skin',
#   'question 17-3': 'the',
#   'question 17-4': 'Courgette',
#   'question 17-5': 'the',
#   'question 17-6': 'the',
#   'question 17-7': 'the synagogue',
#   'question 17-8': 'the skin',
#   'question 17-9': 'in the digestive tract',
#   'question 18-0': 'by putting the mixture in',
#   'question 18-1': 'in a saucepan',
#   'question 18-2': 'for 35 to 40 minutes',
#   'question 18-3': 'by using a blender',
#   'question 18-4': 'by using a blender',
#   'question 2-0': 'into a blender',
#   'question 2-1': 'peewee',
#   'question 2-2': 'the netherlands',
#   'question 2-3': 'n / a',
#   'question 2-4': 'the netherlands',
#   'question 2-5': 'n / a',
#   'question 2-6': 'into a blender',
#   'question 2-7': 'a saucepan',
#   'question 2-8': 'on the plate',
#   'question 3-0': 'by putting the mixture in',
#   'question 3-1': 'potatoes',
#   'question 4-0': 'n / a',
#   'question 4-1': 'n / a',
#   'question 5-0': 'to',
#   'question 7-0': 'for 35 to 40 minutes',
#   'question 7-1': 'for 3 minutes',
#   'question 8-0': 'over the forehead',
#   'question 8-1': 'in the netherlands'},
#  'r-900': {'question 0-0': 'three',
#   'question 0-1': 'two',
#   'question 0-2': 'two',
#   'question 0-3': 'two',
#   'question 0-4': '2 - 3 minutes',
#   'question 1-0': 'cornstarch',
#   'question 1-1': 'cornstarch',
#   'question 1-2': 'chicken stock',
#   'question 10-0': 'serve with grated parmesan cheese',
#   'question 10-1': 'in a slow stream',
#   'question 16-0': 'the Pyre',
#   'question 18-0': '113 minutes',
#   'question 18-1': '3 / 4 tsp bacon drippings',
#   'question 18-2': 'by using a spatula',
#   'question 2-0': 'whisk in a slow stream',
#   'question 3-0': 'chicken stock',
#   'question 3-1': 'chicken stock',
#   'question 3-2': 'by using a whisk',
#   'question 3-3': 'by using a whisk',
#   'question 4-0': "`` boiling ''",
#   'question 4-1': 'removal of pancetta',
#   'question 4-2': '1 / 4 c water',
#   'question 4-3': 'n / a',
#   'question 4-4': 'the',
#   'question 4-5': 'removal of pancetta',
#   'question 6-0': 'whisk in cornstarch',
#   'question 7-0': '2 - 3 minutes'},
#  'r-901': {'question 0-0': 'two',
#   'question 0-1': 'two',
#   'question 0-2': 'four',
#   'question 0-3': 'three',
#   'question 0-4': 'three',
#   'question 1-0': 'greens',
#   'question 1-1': 'greens',
#   'question 1-2': 'watermelon',
#   'question 1-3': 'white beans',
#   'question 10-0': 'simmer it on the stove',
#   'question 18-0': 'for about 2 minutes',
#   'question 18-1': 'two',
#   'question 18-2': 'tomato sauce',
#   'question 18-3': 'n / a',
#   'question 2-0': 'right or left leg',
#   'question 2-1': "`` ladle ''",
#   'question 4-0': 'removal of the excess sodium',
#   'question 4-1': 'italian cuisine',
#   'question 4-2': 'beans',
#   'question 4-3': 'n',
#   'question 4-4': 'n / a',
#   'question 6-0': 'bring broth in large pot',
#   'question 7-0': '5 minutes',
#   'question 7-1': '35 minutes',
#   'question 8-0': 'at table',
#   'question 8-1': 'the middle of the playground',
#   'question 8-2': 'the middle of the playground'},
#  'r-910': {'question 0-0': 'three',
#   'question 0-1': 'three',
#   'question 0-2': 'two',
#   'question 0-3': 'three',
#   'question 0-4': 'four',
#   'question 1-0': 'bacon',
#   'question 1-1': 'tomato',
#   'question 1-2': 'tomato',
#   'question 1-3': 'cabbage',
#   'question 1-4': 'bacon',
#   'question 18-0': 'tomato',
#   'question 18-1': 'n / a',
#   'question 18-2': 'byron nelson',
#   'question 18-3': 'two',
#   'question 18-4': 'in a large pan',
#   'question 2-0': 'in a big deep frying pan',
#   'question 2-1': 'fry them in the bacon fat',
#   'question 2-2': 'fry it in a big deep frying pan',
#   'question 3-0': 'n / a',
#   'question 3-1': 'by putting the mixture in',
#   'question 3-2': 'chopped veggy',
#   'question 3-3': 'tomato',
#   'question 4-0': 'n / a',
#   'question 4-1': 'bacon',
#   'question 9-0': 'a little'},
#  'r-98': {'question 0-0': 'three',
#   'question 0-1': '8',
#   'question 1-0': 'fish cake',
#   'question 1-1': 'fish cake',
#   'question 1-2': 'fish cake',
#   'question 10-0': 'bean vermicelli ( bean thread )',
#   'question 18-0': 'fish cake',
#   'question 18-1': 'two',
#   'question 3-0': 'fish cake',
#   'question 3-1': 'fish cake',
#   'question 3-2': 'by using a spoon',
#   'question 3-3': 'from the',
#   'question 4-0': 'kyarzan - chek',
#   'question 4-1': 'kyarzan - chek',
#   'question 4-2': 'kyarzan - chek',
#   'question 4-3': 'kyarzan - chek',
#   'question 4-4': 'kyarzan - chek',
#   'question 4-5': 'kyarzan - chek',
#   'question 6-0': 'in cooking oil',
#   'question 6-1': "`` boiling water ''",
#   'question 7-0': 'for 4 - 5 minutes',
#   'question 7-1': '15 minutes',
#   'question 7-2': 'a few minutes'}}

# %%
import json
with open("/content/drive/MyDrive/PY/SemEval2022/res.json", "w") as outfile:
    json.dump(dict_res, outfile)

# %%
with open('/content/drive/MyDrive/PY/SemEval2022/df_new.pickle', 'wb') as handle:
    pickle.dump(df_new, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('/content/drive/MyDrive/PY/SemEval2022/df_qa.pickle', 'wb') as handle:
    pickle.dump(df_qa, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('/content/drive/MyDrive/PY/SemEval2022/df_qa_test.pickle', 'wb') as handle:
    pickle.dump(df_qa_test, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('/content/drive/MyDrive/PY/SemEval2022/res0-100.pickle', 'wb') as handle:
    pickle.dump(pred_answers, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
#       doc_ID  recipeID recipeTitle  ...           qkey answer dummy
# 0      r-378         0     Zaalouk  ...   question_2-3          in
# 1      r-378         0     Zaalouk  ...   question_0-1          in
# 2      r-378         0     Zaalouk  ...  question_12-0          in
# 3      r-378         0     Zaalouk  ...   question_4-0          in
# 4      r-378         0     Zaalouk  ...  question_18-0          in
# ...      ...       ...         ...  ...            ...    ...   ...
# 3437  r-1165        99  Huzarensla  ...   question_3-0          in
# 3438  r-1165        99  Huzarensla  ...  question_17-0          in
# 3439  r-1165        99  Huzarensla  ...   question_3-2          in
# 3440  r-1165        99  Huzarensla  ...   question_0-1          in
# 3441  r-1165        99  Huzarensla  ...   question_7-0          in
#
# [3442 rows x 7 columns]

# %%
# pred_answers = [] 
# for question in df_qa.questions[:50]:
#     # Retrieve related documents from retriever
#     retriever_results = retriever.retrieve(
#         query=question
#     )

#     # Now generate answer from question and retrieved documents
#     predicted_result = generator.predict(
#         query=question,
#         documents=retriever_results,
#         top_k=1
#     )

#     # Print you answer
#     answers = predicted_result["answers"]
#     pred_answers.append(answers[0].answer)
#     # print(f'Generated answer is \'{answers[0].answer}\' for the question = \'{question}\'')
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/models/rag/tokenization_rag.py:97: FutureWarning: `prepare_seq2seq_batch` is deprecated and will be removed in version 5 of 🤗 Transformers. Use the regular `__call__` method to prepare your inputs and the tokenizer under the `with_target_tokenizer` context manager to prepare your targets. See the documentation of your specific tokenizer for more details
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:1749: UserWarning: `max_length` is deprecated in this function, use `stopping_criteria=StoppingCriteriaList(MaxLengthCriteria(max_length=max_length))` instead.
#   UserWarning,

# %%
# new: add questions & answers [100:]
df_res = pd.DataFrame({'ques':df_qa['question'][:50],'answer':df_qa['answer'][:50],'pred':pred_answers})
df_res.head(50)
# Out:
#                                                                                ques  ...                                      pred
# 0   How many actions does it take to process the minced meat in vegetables-and-m...  ...                                       two
# 1   What do you serve the vegetables and minced meat casserole with in vegetable...  ...                                   chicken
# 2                  What's in the ingred mix in vegetables-and-minced-meat-casserole  ...                                  potatoes
# 3   How do you cut the carrots and zucchini in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 4                     What should be served in vegetables-and-minced-meat-casserole  ...                                         ,
# 5   Where should you add the chopped vegetables in vegetables-and-minced-meat-ca...  ...                    place the lemon slices
# 6   Cooking the ingredient over a low heat until the water is absorbed and putti...  ...                       in a large saucepan
# 7                    How do you saute onion in vegetables-and-minced-meat-casserole  ...                  saute onion in olive oil
# 8                How many spatulas are used in vegetables-and-minced-meat-casserole  ...                                 a spatula
# 9   Cutting the stem into bite - size pieces into bite - size pieces and sauting...  ...                            in a large pan
# 10     How did you get the cooked vegetable in vegetables-and-minced-meat-casserole  ...                                         ,
# 11  What's in the vegetables and minced meat casserole in vegetables-and-minced-...  ...                             chicken stock
# 12  To what extent do you cut carrots and zucchini in vegetables-and-minced-meat...  ...                          by using a knife
# 13         Where should you saute the onion in vegetables-and-minced-meat-casserole  ...                        in a large skillet
# 14    How did you get the chopped vegetable in vegetables-and-minced-meat-casserole  ...                           by using a fork
# 15     Where do you add the tinned tomatoes in vegetables-and-minced-meat-casserole  ...                  in a large, low side pan
# 16  Sauting minced meat in a separate pan and cutting carrots and zucchini into ...  ...   cutting carrots and zucchini into cubes
# 17           Where do you saute minced meat in vegetables-and-minced-meat-casserole  ...                            in a large pan
# 18     How do you cut the broccoli and stem in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 19  Transferring the meat into the pan with the vegetables and adding chopped ve...  ...                                        in
# 20  Transferring the meat into the pan with the vegetables and seasoning the mea...  ...                          saute the steaks
# 21           What's in the cooked vegetable in vegetables-and-minced-meat-casserole  ...                                    carrot
# 22          What's in the chopped vegetable in vegetables-and-minced-meat-casserole  ...                         chopped vegetable
# 23  Cutting carrots and zucchini into cubes and adding the tinned tomatoes, whic...  ...                        by using a spatula
# 24           Where do you transfer the meat in vegetables-and-minced-meat-casserole  ...                                to a plate
# 25  How many actions does it take to process the mashed potato in vegetables-and...  ...                                       two
# 26  Combining all ingredients and transferring the meat into the pan with the ve...  ...                       meat - and - cheese
# 27  Stirring the reserved bacon , the caramelized onions , and 1/2 cup provolone...  ...                       1 / 2 cup provolone
# 28    Where should you sprinkle the pecorino cheese in caramelized-onion-bacon-tart  ...                    in the digestive tract
# 29  Melting the butter and stirring the reserved bacon , the caramelized onions ...  ...                       1 / 2 cup provolone
# 30       What should be sauted in the large skillet in caramelized-onion-bacon-tart  ...                                     onion
# 31                Where should you saute the onions in caramelized-onion-bacon-tart  ...                                  in a pan
# 32                        How do you serve the tart in caramelized-onion-bacon-tart  ...               caramelized - onion - bacon
# 33                    How do you roll the pie crust in caramelized-onion-bacon-tart  ...                 how to roll the pie crust
# 34          Where do you cook the bacon until crisp in caramelized-onion-bacon-tart  ...                            in a large pan
# 35           What should be mixed in the large bowl in caramelized-onion-bacon-tart  ...                                     onion
# 36  To what extent do you saute the onion about 15 minutes in caramelized-onion-...  ...                  saute the onion in a pan
# 37              How do you prick the dough slightly in caramelized-onion-bacon-tart  ...                  prick the dough slightly
# 38                      How do you preheat the oven in caramelized-onion-bacon-tart  ...               preheat the oven to 400 ° f
# 39  Where was the tart before it was removed from the oven in caramelized-onion-...  ...                                        ``
# 40  Where was the reserved bacon before it was drained on a paper towel in caram...  ...                                        on
# 41                            What should be served in caramelized-onion-bacon-tart  ...                                       egg
# 42                  Where do you press it meanwhile in caramelized-onion-bacon-tart  ...                                the accent
# 43          Where was the dough before it was baked in caramelized-onion-bacon-tart  ...                                    in the
# 44  To what extent do you cook the bacon in a small skillet in caramelized-onion...  ...                                        to
# 45                 Where should you prick the dough in caramelized-onion-bacon-tart  ...                                 where the
# 46    What should be poured on the 9 inch pie plate in caramelized-onion-bacon-tart  ...                                   vanilla
# 47  How do you whisk the heavy cream and eggs from the large bowl in caramelized...  ...                        by using a spatula
# 48  How many actions does it take to process the olive oil in caramelized-onion-...  ...                                       two
# 49             Where should you mix the egg mixture in caramelized-onion-bacon-tart  ...                            `` trinkets ''
#
# [50 rows x 3 columns]

# %%
questions[:100]
# Out:
# 0     How many actions does it take to process the minced meat in vegetables-and-m...
# 1     What do you serve the vegetables and minced meat casserole with in vegetable...
# 2                    What's in the ingred mix in vegetables-and-minced-meat-casserole
# 3     How do you cut the carrots and zucchini in vegetables-and-minced-meat-casserole
# 4                       What should be served in vegetables-and-minced-meat-casserole
#                                            ...
# 95    How do you cook pasta according to pasta package directions in ink-pasta-wit...
# 96    How do you mix the shrimp, pasta, butter and parsley in ink-pasta-with-shrim...
# 97    What's in the pasta with tomato garlic and shrimp in ink-pasta-with-shrimps-...
# 98    Reserving 1/2 cup of the cooking water and adding the garlic and shrimps, wh...
# 99    Where should you add the shrimps, butter and parsley in ink-pasta-with-shrim...
# Length: 100, dtype: object

# %%
# new: add questions & answers [100:]
df_res = pd.DataFrame({'ques':df_qa['question'][:100],'answer':df_qa['answer'][:100],'pred':pred_answers})
df_res.head(50)
# Out:
#                                                                                ques  ...                                      pred
# 0                          How many actions does it take to process the minced meat  ...                                       two
# 1                   What do you serve the vegetables and minced meat casserole with  ...                                   chicken
# 2                                                          What's in the ingred mix  ...                                  potatoes
# 3                                           How do you cut the carrots and zucchini  ...                          by using a knife
# 4                                                             What should be served  ...                                         ,
# 5                                       Where should you add the chopped vegetables  ...                    place the lemon slices
# 6   Cooking the ingredient over a low heat until the water is absorbed and putti...  ...                       in a large saucepan
# 7                                                            How do you saute onion  ...                  saute onion in olive oil
# 8                                                        How many spatulas are used  ...                                       two
# 9   Cutting the stem into bite - size pieces into bite - size pieces and sauting...  ...                            in a large pan
# 10                                             How did you get the cooked vegetable  ...                                         ,
# 11                               What's in the vegetables and minced meat casserole  ...                             chicken stock
# 12                                   To what extent do you cut carrots and zucchini  ...                          by using a knife
# 13                                                 Where should you saute the onion  ...                        in a large skillet
# 14                                            How did you get the chopped vegetable  ...                          by using a knife
# 15                                             Where do you add the tinned tomatoes  ...                  in a large, low side pan
# 16  Sauting minced meat in a separate pan and cutting carrots and zucchini into ...  ...   cutting carrots and zucchini into cubes
# 17                                                   Where do you saute minced meat  ...                            in a large pan
# 18                                             How do you cut the broccoli and stem  ...                          by using a knife
# 19  Transferring the meat into the pan with the vegetables and adding chopped ve...  ...                                        in
# 20  Transferring the meat into the pan with the vegetables and seasoning the mea...  ...                          saute the steaks
# 21                                                   What's in the cooked vegetable  ...                                  broccoli
# 22                                                  What's in the chopped vegetable  ...                         chopped vegetable
# 23  Cutting carrots and zucchini into cubes and adding the tinned tomatoes, whic...  ...                        by using a spatula
# 24                                                   Where do you transfer the meat  ...                                to a plate
# 25                       How many actions does it take to process the mashed potato  ...                                       two
# 26  Combining all ingredients and transferring the meat into the pan with the ve...  ...                       meat - and - cheese
# 27  Stirring the reserved bacon , the caramelized onions , and 1/2 cup provolone...  ...                       1 / 2 cup provolone
# 28                                    Where should you sprinkle the pecorino cheese  ...                    in the digestive tract
# 29  Melting the butter and stirring the reserved bacon , the caramelized onions ...  ...                       1 / 2 cup provolone
# 30                                       What should be sauted in the large skillet  ...                                     onion
# 31                                                Where should you saute the onions  ...                                  in a pan
# 32                                                        How do you serve the tart  ...               caramelized - onion - bacon
# 33                                                    How do you roll the pie crust  ...                 how to roll the pie crust
# 34                                          Where do you cook the bacon until crisp  ...                            in a large pan
# 35                                           What should be mixed in the large bowl  ...                                     onion
# 36                           To what extent do you saute the onion about 15 minutes  ...                  saute the onion in a pan
# 37                                              How do you prick the dough slightly  ...                  prick the dough slightly
# 38                                                      How do you preheat the oven  ...               preheat the oven to 400 ° f
# 39                           Where was the tart before it was removed from the oven  ...                                        ``
# 40              Where was the reserved bacon before it was drained on a paper towel  ...                                        on
# 41                                                            What should be served  ...                                       egg
# 42                                                  Where do you press it meanwhile  ...                                the accent
# 43                                          Where was the dough before it was baked  ...                                    in the
# 44                          To what extent do you cook the bacon in a small skillet  ...                                        to
# 45                                                 Where should you prick the dough  ...                                 where the
# 46                                    What should be poured on the 9 inch pie plate  ...                                   vanilla
# 47                    How do you whisk the heavy cream and eggs from the large bowl  ...                        by using a spatula
# 48                           How many actions does it take to process the olive oil  ...                                       two
# 49                                             Where should you mix the egg mixture  ...                            `` trinkets ''
#
# [50 rows x 3 columns]

# %%
# new: add questions & answers 
3, 4, 7, 9, 11
df_res = pd.DataFrame({'ques':df_qa['question'][:100],'answer':df_qa['answer'][:100],'pred':pred_answers})
df_res.head(50)
# Out:
#                                                                                ques  ...                                      pred
# 0   How many actions does it take to process the minced meat in vegetables-and-m...  ...                                       two
# 1   What do you serve the vegetables and minced meat casserole with in vegetable...  ...                                   chicken
# 2                  What's in the ingred mix in vegetables-and-minced-meat-casserole  ...                                  potatoes
# 3   How do you cut the carrots and zucchini in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 4                     What should be served in vegetables-and-minced-meat-casserole  ...                                  the meat
# 5   Where should you add the chopped vegetables in vegetables-and-minced-meat-ca...  ...                    place the lemon slices
# 6   Cooking the ingredient over a low heat until the water is absorbed and putti...  ...                       in a large saucepan
# 7                    How do you saute onion in vegetables-and-minced-meat-casserole  ...                  saute onion in olive oil
# 8                How many spatulas are used in vegetables-and-minced-meat-casserole  ...                                       two
# 9   Cutting the stem into bite - size pieces into bite - size pieces and sauting...  ...                           the first event
# 10     How did you get the cooked vegetable in vegetables-and-minced-meat-casserole  ...                                         ,
# 11  What's in the vegetables and minced meat casserole in vegetables-and-minced-...  ...                                  the meat
# 12  To what extent do you cut carrots and zucchini in vegetables-and-minced-meat...  ...                          by using a knife
# 13         Where should you saute the onion in vegetables-and-minced-meat-casserole  ...                        in a large skillet
# 14    How did you get the chopped vegetable in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 15     Where do you add the tinned tomatoes in vegetables-and-minced-meat-casserole  ...                  in a large, low side pan
# 16  Sauting minced meat in a separate pan and cutting carrots and zucchini into ...  ...   cutting carrots and zucchini into cubes
# 17           Where do you saute minced meat in vegetables-and-minced-meat-casserole  ...                            in a large pan
# 18     How do you cut the broccoli and stem in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 19  Transferring the meat into the pan with the vegetables and adding chopped ve...  ...                          the second event
# 20  Transferring the meat into the pan with the vegetables and seasoning the mea...  ...                                  the meat
# 21           What's in the cooked vegetable in vegetables-and-minced-meat-casserole  ...                                  the meat
# 22          What's in the chopped vegetable in vegetables-and-minced-meat-casserole  ...                         chopped vegetable
# 23  Cutting carrots and zucchini into cubes and adding the tinned tomatoes, whic...  ...                        by using a spatula
# 24           Where do you transfer the meat in vegetables-and-minced-meat-casserole  ...                                       the
# 25  How many actions does it take to process the mashed potato in vegetables-and...  ...                                       two
# 26  Combining all ingredients and transferring the meat into the pan with the ve...  ...                          the second event
# 27  Stirring the reserved bacon , the caramelized onions , and 1/2 cup provolone...  ...                      into the egg mixture
# 28    Where should you sprinkle the pecorino cheese in caramelized-onion-bacon-tart  ...                    in the digestive tract
# 29  Melting the butter and stirring the reserved bacon , the caramelized onions ...  ...                           the first event
# 30       What should be sauted in the large skillet in caramelized-onion-bacon-tart  ...                                  pancetta
# 31                Where should you saute the onions in caramelized-onion-bacon-tart  ...                                  in a pan
# 32                        How do you serve the tart in caramelized-onion-bacon-tart  ...        serve the tart at room temperature
# 33                    How do you roll the pie crust in caramelized-onion-bacon-tart  ...                 how to roll the pie crust
# 34          Where do you cook the bacon until crisp in caramelized-onion-bacon-tart  ...                            in a large pan
# 35           What should be mixed in the large bowl in caramelized-onion-bacon-tart  ...                                     onion
# 36  To what extent do you saute the onion about 15 minutes in caramelized-onion-...  ...                  saute the onion in a pan
# 37              How do you prick the dough slightly in caramelized-onion-bacon-tart  ...                  prick the dough slightly
# 38                      How do you preheat the oven in caramelized-onion-bacon-tart  ...               preheat the oven to 400 ° f
# 39  Where was the tart before it was removed from the oven in caramelized-onion-...  ...                                        ``
# 40  Where was the reserved bacon before it was drained on a paper towel in caram...  ...                             small skillet
# 41                            What should be served in caramelized-onion-bacon-tart  ...                                       egg
# 42                  Where do you press it meanwhile in caramelized-onion-bacon-tart  ...                                the accent
# 43          Where was the dough before it was baked in caramelized-onion-bacon-tart  ...                                        in
# 44  To what extent do you cook the bacon in a small skillet in caramelized-onion...  ...                                        to
# 45                 Where should you prick the dough in caramelized-onion-bacon-tart  ...                            prick the base
# 46    What should be poured on the 9 inch pie plate in caramelized-onion-bacon-tart  ...                                   vanilla
# 47  How do you whisk the heavy cream and eggs from the large bowl in caramelized...  ...                        by using a spatula
# 48  How many actions does it take to process the olive oil in caramelized-onion-...  ...                                       two
# 49             Where should you mix the egg mixture in caramelized-onion-bacon-tart  ...                            `` trinkets ''
#
# [50 rows x 3 columns]

# %% [markdown]
# ## evaluation data

# %%
from conllu import parse

input_file = "/content/drive/MyDrive/PY/SemEval2022/crl_srl_eval.csv"

with open(input_file, mode='r') as fp:
    input_data = fp.read()
    
sentences = parse(input_data)

# %%
input_data = []
count = 0
for i, sentence in enumerate(sentences):
    if 'newdoc id' in sentence.metadata.keys():        
        data = dict()
        for key in sentence.metadata.keys():
            if 'question ' in key:
                question = sentence.metadata[key]
                answer = sentence.metadata[key.replace('question', 'answer')]
                #print(count)
                # text = recipes[count]
                recipeID = count

                input_data.append({'recipeID':count, 'recipeTitle':titles[count], 'question':question, 'answer':answer})
        count += 1

# %%
df_qa_new = pd.DataFrame(input_data)
df_qa_new['dummy'] = [' in '] * len(df_qa_new)
df_qa_new['question'] = df_qa_new['question'].apply(lambda x: x[:-1])
questions_new =  df_qa_new['question'] + df_qa_new['dummy'] + df_qa_new['recipeTitle']
questions_new[:5]
# Out:
# 0    What should be topped in the serving bowl in vegetables-and-minced-meat-cass...
# 1    How do you mix the eggs and milk in the small bowl in vegetables-and-minced-...
# 2    Where should you add the parsley, salt and pepper in vegetables-and-minced-m...
# 3       How do you mix the flour and mixture in vegetables-and-minced-meat-casserole
# 4          What should be rested in the bowl in vegetables-and-minced-meat-casserole
# dtype: object

# %%
df_qa_new['quiz'] = questions_new
df_qa_new
# Out:
#       recipeID  ...                                                                             quiz
# 0            0  ...  What should be topped in the serving bowl in vegetables-and-minced-meat-cass...
# 1            0  ...  How do you mix the eggs and milk in the small bowl in vegetables-and-minced-...
# 2            0  ...  Where should you add the parsley, salt and pepper in vegetables-and-minced-m...
# 3            0  ...     How do you mix the flour and mixture in vegetables-and-minced-meat-casserole
# 4            0  ...        What should be rested in the bowl in vegetables-and-minced-meat-casserole
# ...        ...  ...                                                                              ...
# 3824        99  ...  What should be coated in the pan in Carbonada_Criolla_(Veal_and_Vegetable_Stew)
# 3825        99  ...  For how long do you fry the capsicum, mushroom and potato in Carbonada_Criol...
# 3826        99  ...  What should be removed from the pan in Carbonada_Criolla_(Veal_and_Vegetable...
# 3827        99  ...             Where do you heat oil in Carbonada_Criolla_(Veal_and_Vegetable_Stew)
# 3828        99  ...   What should be fried in the pan in Carbonada_Criolla_(Veal_and_Vegetable_Stew)
#
# [3829 rows x 6 columns]

# %%
pred_answers_new = [] 
for question in questions_new[:100]:
    # Retrieve related documents from retriever
    retriever_results = retriever.retrieve(
        query=question
    )

    # Now generate answer from question and retrieved documents
    predicted_result = generator.predict(
        query=question,
        documents=retriever_results,
        top_k=1
    )

    # Print you answer
    answers = predicted_result["answers"]
    pred_answers_new.append(answers[0].answer)
    # print(f'Generated answer is \'{answers[0].answer}\' for the question = \'{question}\'')

# %%
# new: add questions & answers  topk=1
df_res_new = pd.DataFrame({'ques':df_qa_new['quiz'][:100],'answer':df_qa_new['answer'][:100],'pred':pred_answers})
df_res_new.head(50)
# Out:
#                                                                                ques  ...                                      pred
# 0   What should be topped in the serving bowl in vegetables-and-minced-meat-cass...  ...                                       two
# 1   How do you mix the eggs and milk in the small bowl in vegetables-and-minced-...  ...                                   chicken
# 2   Where should you add the parsley, salt and pepper in vegetables-and-minced-m...  ...                                  potatoes
# 3      How do you mix the flour and mixture in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 4         What should be rested in the bowl in vegetables-and-minced-meat-casserole  ...                                  the meat
# 5   Adding the speak and pancetta and saute and rolling the mixture in the cavit...  ...                    place the lemon slices
# 6   Where was the small ball before it was topped 2 - 3 canederli in vegetables-...  ...                       in a large saucepan
# 7   Where was the small ball before it was drained with a slotted spoon in veget...  ...                  saute onion in olive oil
# 8        Where do you place 2 - 3 canederli in vegetables-and-minced-meat-casserole  ...                                       two
# 9   What should be mixed in the bowl with the whisk in vegetables-and-minced-mea...  ...                           the first event
# 10  How do you mix the parsley, salt, pepper, eggs and milk in the small bowl in...  ...                                         ,
# 11  For how long do you saute the pancetta, speak, onion and butter in vegetable...  ...                                  the meat
# 12      What should be rolled with the hand in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 13  Where do you mix the eggs with the milk in vegetables-and-minced-meat-casserole  ...                        in a large skillet
# 14  What should be sauted in the small frying pan in vegetables-and-minced-meat-...  ...                          by using a knife
# 15       What should be drained in the sink in vegetables-and-minced-meat-casserole  ...                  in a large, low side pan
# 16  For how long do you boil the stock and ball in vegetables-and-minced-meat-ca...  ...   cutting carrots and zucchini into cubes
# 17  Adding jalapenos , two thirds of the cilantro and half the tomatoes and beat...  ...                            in a large pan
# 18  Where was the onion before it was placed with the bread in vegetables-and-mi...  ...                          by using a knife
# 19  How many actions does it take to process the fig in vegetables-and-minced-me...  ...                          the second event
# 20         How many times is the knife used in vegetables-and-minced-meat-casserole  ...                                  the meat
# 21  How many actions does it take to process the parsley in vegetables-and-mince...  ...                                  the meat
# 22                How do you roll the balls in vegetables-and-minced-meat-casserole  ...                         chopped vegetable
# 23  Where was the chicken stock before it was drained with a slotted spoon in ve...  ...                        by using a spatula
# 24   What should be flattened with the palm in vegetables-and-minced-meat-casserole  ...                                       the
# 25              How did you get the mixture in vegetables-and-minced-meat-casserole  ...                                       two
# 26           Where should you cut the bread in vegetables-and-minced-meat-casserole  ...                          the second event
# 27  Where should you mix the eggs and milk with the whisk in vegetables-and-minc...  ...                      into the egg mixture
# 28                   What should be covered in vegetables-and-minced-meat-casserole  ...                    in the digestive tract
# 29  Where should you drain the stock and balls with the slotted spoon in vegetab...  ...                           the first event
# 30      How did you get the bread onion mix in vegetables-and-minced-meat-casserole  ...                                  pancetta
# 31                    What's in the mixture in vegetables-and-minced-meat-casserole  ...                                  in a pan
# 32  Where should you boil the stock and balls in vegetables-and-minced-meat-cass...  ...        serve the tart at room temperature
# 33  Where was the small ball before it was placed in each serving bowl in vegeta...  ...                 how to roll the pie crust
# 34  What do you place the speak, pancetta and onion with in vegetables-and-mince...  ...                            in a large pan
# 35  Where was the mixture before it was added to the bread onion mix in vegetabl...  ...                                     onion
# 36  Where was the pancetta before it was placed with the bread in vegetables-and...  ...                  saute the onion in a pan
# 37      What should be flavored in the bowl in vegetables-and-minced-meat-casserole  ...                  prick the dough slightly
# 38        What should be placed in the bowl in vegetables-and-minced-meat-casserole  ...               preheat the oven to 400 ° f
# 39  Where should you flavor the bread onion mix in vegetables-and-minced-meat-ca...  ...                                        ``
# 40         Where should you float the balls in vegetables-and-minced-meat-casserole  ...                             small skillet
# 41       For how long do you stir the mango in vegetables-and-minced-meat-casserole  ...                                       egg
# 42                  Where do you float they in vegetables-and-minced-meat-casserole  ...                                the accent
# 43                 How did you get the ball in vegetables-and-minced-meat-casserole  ...                                        in
# 44  Where was the speak before it was placed with the bread in vegetables-and-mi...  ...                                        to
# 45  Where should you mix the parsley, salt, pepper, eggs and milk with the whisk...  ...                            prick the base
# 46             Where do you add the mixture in vegetables-and-minced-meat-casserole  ...                                   vanilla
# 47           Where do you place small cubes in vegetables-and-minced-meat-casserole  ...                        by using a spatula
# 48  Where should you mix the flour and mixture with the whisk in vegetables-and-...  ...                                       two
# 49   What should be mixed in the small bowl in vegetables-and-minced-meat-casserole  ...                            `` trinkets ''
#
# [50 rows x 3 columns]

# %%
# new: add questions & answers  topk=1
df_res_new = pd.DataFrame({'ques':df_qa_new['quiz'][:100],'answer':df_qa_new['answer'][:100],'pred':pred_answers})
df_res_new.head(50)
# Out:
#                                                                                ques  ...                                      pred
# 0   What should be topped in the serving bowl in vegetables-and-minced-meat-cass...  ...                                       two
# 1   How do you mix the eggs and milk in the small bowl in vegetables-and-minced-...  ...                                   chicken
# 2   Where should you add the parsley, salt and pepper in vegetables-and-minced-m...  ...                                  potatoes
# 3      How do you mix the flour and mixture in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 4         What should be rested in the bowl in vegetables-and-minced-meat-casserole  ...                                  the meat
# 5   Adding the speak and pancetta and saute and rolling the mixture in the cavit...  ...                    place the lemon slices
# 6   Where was the small ball before it was topped 2 - 3 canederli in vegetables-...  ...                       in a large saucepan
# 7   Where was the small ball before it was drained with a slotted spoon in veget...  ...                  saute onion in olive oil
# 8        Where do you place 2 - 3 canederli in vegetables-and-minced-meat-casserole  ...                                       two
# 9   What should be mixed in the bowl with the whisk in vegetables-and-minced-mea...  ...                           the first event
# 10  How do you mix the parsley, salt, pepper, eggs and milk in the small bowl in...  ...                                         ,
# 11  For how long do you saute the pancetta, speak, onion and butter in vegetable...  ...                                  the meat
# 12      What should be rolled with the hand in vegetables-and-minced-meat-casserole  ...                          by using a knife
# 13  Where do you mix the eggs with the milk in vegetables-and-minced-meat-casserole  ...                        in a large skillet
# 14  What should be sauted in the small frying pan in vegetables-and-minced-meat-...  ...                          by using a knife
# 15       What should be drained in the sink in vegetables-and-minced-meat-casserole  ...                  in a large, low side pan
# 16  For how long do you boil the stock and ball in vegetables-and-minced-meat-ca...  ...   cutting carrots and zucchini into cubes
# 17  Adding jalapenos , two thirds of the cilantro and half the tomatoes and beat...  ...                            in a large pan
# 18  Where was the onion before it was placed with the bread in vegetables-and-mi...  ...                          by using a knife
# 19  How many actions does it take to process the fig in vegetables-and-minced-me...  ...                          the second event
# 20         How many times is the knife used in vegetables-and-minced-meat-casserole  ...                                  the meat
# 21  How many actions does it take to process the parsley in vegetables-and-mince...  ...                                  the meat
# 22                How do you roll the balls in vegetables-and-minced-meat-casserole  ...                         chopped vegetable
# 23  Where was the chicken stock before it was drained with a slotted spoon in ve...  ...                        by using a spatula
# 24   What should be flattened with the palm in vegetables-and-minced-meat-casserole  ...                                       the
# 25              How did you get the mixture in vegetables-and-minced-meat-casserole  ...                                       two
# 26           Where should you cut the bread in vegetables-and-minced-meat-casserole  ...                          the second event
# 27  Where should you mix the eggs and milk with the whisk in vegetables-and-minc...  ...                      into the egg mixture
# 28                   What should be covered in vegetables-and-minced-meat-casserole  ...                    in the digestive tract
# 29  Where should you drain the stock and balls with the slotted spoon in vegetab...  ...                           the first event
# 30      How did you get the bread onion mix in vegetables-and-minced-meat-casserole  ...                                  pancetta
# 31                    What's in the mixture in vegetables-and-minced-meat-casserole  ...                                  in a pan
# 32  Where should you boil the stock and balls in vegetables-and-minced-meat-cass...  ...        serve the tart at room temperature
# 33  Where was the small ball before it was placed in each serving bowl in vegeta...  ...                 how to roll the pie crust
# 34  What do you place the speak, pancetta and onion with in vegetables-and-mince...  ...                            in a large pan
# 35  Where was the mixture before it was added to the bread onion mix in vegetabl...  ...                                     onion
# 36  Where was the pancetta before it was placed with the bread in vegetables-and...  ...                  saute the onion in a pan
# 37      What should be flavored in the bowl in vegetables-and-minced-meat-casserole  ...                  prick the dough slightly
# 38        What should be placed in the bowl in vegetables-and-minced-meat-casserole  ...               preheat the oven to 400 ° f
# 39  Where should you flavor the bread onion mix in vegetables-and-minced-meat-ca...  ...                                        ``
# 40         Where should you float the balls in vegetables-and-minced-meat-casserole  ...                             small skillet
# 41       For how long do you stir the mango in vegetables-and-minced-meat-casserole  ...                                       egg
# 42                  Where do you float they in vegetables-and-minced-meat-casserole  ...                                the accent
# 43                 How did you get the ball in vegetables-and-minced-meat-casserole  ...                                        in
# 44  Where was the speak before it was placed with the bread in vegetables-and-mi...  ...                                        to
# 45  Where should you mix the parsley, salt, pepper, eggs and milk with the whisk...  ...                            prick the base
# 46             Where do you add the mixture in vegetables-and-minced-meat-casserole  ...                                   vanilla
# 47           Where do you place small cubes in vegetables-and-minced-meat-casserole  ...                        by using a spatula
# 48  Where should you mix the flour and mixture with the whisk in vegetables-and-...  ...                                       two
# 49   What should be mixed in the small bowl in vegetables-and-minced-meat-casserole  ...                            `` trinkets ''
#
# [50 rows x 3 columns]

# %% [markdown]
# original url title

# %%
1,4,7,14,17,21,24,30,31,37,38,47,49, 52, 85, 90, 93, 99
31, 37, 38, 47, 49, 52

# %%
df_res = pd.DataFrame({'ques':df_qa['question'][:100],'answer':df_qa['answer'][:100],'pred':pred_answers})
df_res.head(50)
# Out:
#                                                                                ques  ...                                pred
# 0                          How many actions does it take to process the minced meat  ...                 two or four actions
# 1                   What do you serve the vegetables and minced meat casserole with  ...                         cooked rice
# 2                                                          What's in the ingred mix  ...                            broccoli
# 3                                           How do you cut the carrots and zucchini  ...   cut the broccoli into bite - size
# 4                                                             What should be served  ...                         cooked rice
# 5                                       Where should you add the chopped vegetables  ...              the middle of the dish
# 6   Cooking the ingredient over a low heat until the water is absorbed and putti...  ...                       `` boiling ''
# 7                                                            How do you saute onion  ...                  saute onion in oil
# 8                                                        How many spatulas are used  ...                                 two
# 9   Cutting the stem into bite - size pieces into bite - size pieces and sauting...  ...                            broccoli
# 10                                             How did you get the cooked vegetable  ...                              tomato
# 11                               What's in the vegetables and minced meat casserole  ...                            zucchini
# 12                                   To what extent do you cut carrots and zucchini  ...   cut carrots and zucchini in cubes
# 13                                                 Where should you saute the onion  ...          in 2 tablespoons olive oil
# 14                                            How did you get the chopped vegetable  ...   cut the broccoli into bite - size
# 15                                             Where do you add the tinned tomatoes  ...                                 the
# 16  Sauting minced meat in a separate pan and cutting carrots and zucchini into ...  ...                  1 / 2 tsp sea salt
# 17                                                   Where do you saute minced meat  ...                  a large frying pan
# 18                                             How do you cut the broccoli and stem  ...   cut the broccoli into bite - size
# 19  Transferring the meat into the pan with the vegetables and adding chopped ve...  ...                    1 / 2 tsp pepper
# 20  Transferring the meat into the pan with the vegetables and seasoning the mea...  ...                   400 g ground beef
# 21                                                   What's in the cooked vegetable  ...                            broccoli
# 22                                                  What's in the chopped vegetable  ...                            zucchini
# 23  Cutting carrots and zucchini into cubes and adding the tinned tomatoes, whic...  ...                    broccoli florets
# 24                                                   Where do you transfer the meat  ...                             the pan
# 25                       How many actions does it take to process the mashed potato  ...                    two large onions
# 26  Combining all ingredients and transferring the meat into the pan with the ve...  ...                     2 tbs olive oil
# 27  Stirring the reserved bacon , the caramelized onions , and 1/2 cup provolone...  ...                 1 / 2 cup provolone
# 28                                    Where should you sprinkle the pecorino cheese  ...              in the digestive tract
# 29  Melting the butter and stirring the reserved bacon , the caramelized onions ...  ...                 1 / 2 cup provolone
# 30                                       What should be sauted in the large skillet  ...                               onion
# 31                                                Where should you saute the onions  ...                  a large frying pan
# 32                                                        How do you serve the tart  ...                  tortilla de huevos
# 33                                                    How do you roll the pie crust  ...                 1 / 2 cup provolone
# 34                                          Where do you cook the bacon until crisp  ...              the cavity in the back
# 35                                           What should be mixed in the large bowl  ...                                rice
# 36                           To what extent do you saute the onion about 15 minutes  ...             to caramelize the onion
# 37                                              How do you prick the dough slightly  ...         prick the edge of the dough
# 38                                                      How do you preheat the oven  ...                           preheated
# 39                           Where was the tart before it was removed from the oven  ...        the middle of the playground
# 40              Where was the reserved bacon before it was drained on a paper towel  ...              in the digestive tract
# 41                                                            What should be served  ...                     pecorino cheese
# 42                                                  Where do you press it meanwhile  ...                   bottom of the pan
# 43                                          Where was the dough before it was baked  ...                     1 / 2 tsp. salt
# 44                          To what extent do you cook the bacon in a small skillet  ...          1 / 2 tsp of minced garlic
# 45                                                 Where should you prick the dough  ...                     the first layer
# 46                                    What should be poured on the 9 inch pie plate  ...                            zucchini
# 47                    How do you whisk the heavy cream and eggs from the large bowl  ...                   beat with a whisk
# 48                           How many actions does it take to process the olive oil  ...                         three steps
# 49                                             Where should you mix the egg mixture  ...              the middle of the bowl
#
# [50 rows x 3 columns]

# %%
df_res.tail(50)
# Out:
#                                                                                ques  ...                           pred
# 50                                     How do you bake the pie crust for 40 minutes  ...            1 / 2 cup provolone
# 51                          For how long do you bake the pie crust in the warm oven  ...               20 to 25 minutes
# 52                Where do you heat the olive oil and butter until the butter melts  ...                  large skillet
# 53                 For how long do you saute the onion until translucent and golden  ...                8 -- 10 minutes
# 54                                                             What's in the cookie  ...                    heavy cream
# 55                               Where do you whisk the heavy cream , eggs together  ...   the middle of the playground
# 56           To what extent do you heat the olive oil and butter in a large skillet  ...                 1 / 2 tsp. oil
# 57                                                     Where do you drain the bacon  ...                 1 / 2 tsp. oil
# 58                                        What should be pressed to the baking dish  ...            1 / 2 cup provolone
# 59                              How many actions does it take to process the butter  ...                  three actions
# 60                                                       How do you prick the dough  ...    prick the edge of the dough
# 61                                                        What's in the egg mixture  ...            1 / 2 cup provolone
# 62  Whisking the heavy cream , eggs in a large bowl and pricking the dough with ...  ...                  whipped cream
# 63                                             What should be removed from the oven  ...                    the topping
# 64                  Removing the tart and mixing the egg mixture, which comes first  ...                 1 / 2 tsp salt
# 65                                                 How many small skillets are used  ...                            two
# 66                                                  Where should you add the onions  ...        the middle of the table
# 67                                                   How do you mix the egg mixture  ...                 `` throwing ''
# 68                                      Where should you season the salt and pepper  ...     the bottoms of the fingers
# 69                                                From where do you remove the tart  ...                  the packaging
# 70                     Where was the pie crust before it was baked in the warm oven  ...            1 / 2 cup provolone
# 71  Where do you stir the reserved bacon , the caramelized onions , and 1/2 cup ...  ...            1 / 2 cup provolone
# 72                              Where do you sprinkle the remaining pecorino cheese  ...         in the digestive tract
# 73                                        What should be drained in the paper towel  ...                         onions
# 74                                                            What should be mashed  ...                           rice
# 75                                                      Where do you pour it evenly  ...                  1 / 2 tsp oil
# 76                                  How do you knead the flour mixture on the board  ...                 `` throwing ''
# 77  Draining the bacon on a paper towel and filling with pie weights , rice , or...  ...      1 / 2 tsp of minced bacon
# 78                   Where should you whisk the heavy cream and eggs with the whisk  ...   the middle of the playground
# 79                                  Where should you bake the dough and pie weights  ...   the middle of the playground
# 80                          How do you whisk the heavy cream , eggs in a large bowl  ...                   beat lightly
# 81                                        What should be baked in the aluminum foil  ...                pan de mallorca
# 82                                                  How did you get the egg mixture  ...                  from a victim
# 83                                                 What should be baked in the oven  ...                pecorino cheese
# 84                                                Where do you store the small ball  ...             one or two fingers
# 85                       How do you cook pasta in large salted pot of boiling water  ...           `` brooklyn '' pasta
# 86                              Where was the pasta before it was drained the pasta  ...         in the digestive tract
# 87  Reserving 1/2 cup of the cooking water and draining the cooking water, which...  ...          pasta in a large bowl
# 88  Combining about 1 1/2 teaspoons spice blend on a small dish and putting the ...  ...                    spice blend
# 89                  Where do you melt 4 tablespoons of butter over medium high heat  ...   the middle of the playground
# 90                                                            What should be served  ...                         shrimp
# 91                           Where was the pasta before it was added to the skillet  ...         in the digestive tract
# 92                                                       How many skillets are used  ...                            two
# 93                                      Where should you add the garlic and shrimps  ...             in a large skillet
# 94                                            What should be mixed with the spatula  ...                          basil
# 95                      How do you cook pasta according to pasta package directions  ...             pasta in olive oil
# 96                             How do you mix the shrimp, pasta, butter and parsley  ...                 `` throwing ''
# 97                                What's in the pasta with tomato garlic and shrimp  ...                         shrimp
# 98  Reserving 1/2 cup of the cooking water and adding the garlic and shrimps, wh...  ...                  fresh parsley
# 99                             Where should you add the shrimps, butter and parsley  ...                    the skillet
#
# [50 rows x 3 columns]

# %% [markdown]
# results 1
# split title with -

# %%
df_res = pd.DataFrame({'ques':df_qa['question'][:100],'answer':df_qa['answer'][:100],'pred':pred_answers})
df_res

# %%
df_res.head(50)
# Out:
#                                                                                ques  ...                                        pred
# 0                          How many actions does it take to process the minced meat  ...                      cut carrots into cubes
# 1                   What do you serve the vegetables and minced meat casserole with  ...                                 cooked rice
# 2                                                          What's in the ingred mix  ...                                    zucchini
# 3                                           How do you cut the carrots and zucchini  ...    cut the broccoli into bite - size pieces
# 4                                                             What should be served  ...                                 cooked rice
# 5                                       Where should you add the chopped vegetables  ...                             tinned tomatoes
# 6   Cooking the ingredient over a low heat until the water is absorbed and putti...  ...                             2 tbs olive oil
# 7                                                            How do you saute onion  ...   saute onion in 2 tablespoons of olive oil
# 8                                                        How many spatulas are used  ...                                         two
# 9   Cutting the stem into bite - size pieces into bite - size pieces and sauting...  ...                                    broccoli
# 10                                             How did you get the cooked vegetable  ...                             tinned tomatoes
# 11                               What's in the vegetables and minced meat casserole  ...                                    zucchini
# 12                                   To what extent do you cut carrots and zucchini  ...           cut carrots and zucchini in cubes
# 13                                                 Where should you saute the onion  ...               in 2 tablespoons of olive oil
# 14                                            How did you get the chopped vegetable  ...             cut the broccoli into flowerets
# 15                                             Where do you add the tinned tomatoes  ...                          in a 5 - quart pot
# 16  Sauting minced meat in a separate pan and cutting carrots and zucchini into ...  ...                             2 tbs olive oil
# 17                                                   Where do you saute minced meat  ...                           in a separate pan
# 18                                             How do you cut the broccoli and stem  ...    cut the broccoli into bite - size pieces
# 19  Transferring the meat into the pan with the vegetables and adding chopped ve...  ...                           400 g ground beef
# 20  Transferring the meat into the pan with the vegetables and seasoning the mea...  ...                     350 g whole wheat bread
# 21                                                   What's in the cooked vegetable  ...                                    broccoli
# 22                                                  What's in the chopped vegetable  ...                                    zucchini
# 23  Cutting carrots and zucchini into cubes and adding the tinned tomatoes, whic...  ...                           400 g ground beef
# 24                                                   Where do you transfer the meat  ...                                     the pan
# 25                       How many actions does it take to process the mashed potato  ...                        two to three minutes
# 26  Combining all ingredients and transferring the meat into the pan with the ve...  ...                           400 g ground beef
# 27  Stirring the reserved bacon , the caramelized onions , and 1/2 cup provolone...  ...                                 egg mixture
# 28                                    Where should you sprinkle the pecorino cheese  ...                               the packaging
# 29  Melting the butter and stirring the reserved bacon , the caramelized onions ...  ...                         1 / 2 cup provolone
# 30                                       What should be sauted in the large skillet  ...                                      onions
# 31                                                Where should you saute the onions  ...                            in the caribbean
# 32                                                        How do you serve the tart  ...                             pan de mallorca
# 33                                                    How do you roll the pie crust  ...                              `` throwing ''
# 34                                          Where do you cook the bacon until crisp  ...                the middle of the playground
# 35                                           What should be mixed in the large bowl  ...                                        eggs
# 36                           To what extent do you saute the onion about 15 minutes  ...                         1 / 2 cup provolone
# 37                                              How do you prick the dough slightly  ...                               `` cutting ''
# 38                                                      How do you preheat the oven  ...                                pre- carving
# 39                           Where was the tart before it was removed from the oven  ...                      in the digestive tract
# 40              Where was the reserved bacon before it was drained on a paper towel  ...                      in the digestive tract
# 41                                                            What should be served  ...                         1 / 2 cup provolone
# 42                                                  Where do you press it meanwhile  ...                           bottom of the pan
# 43                                          Where was the dough before it was baked  ...                      in the digestive tract
# 44                          To what extent do you cook the bacon in a small skillet  ...                         1 / 2 cup provolone
# 45                                                 Where should you prick the dough  ...                 prick the end of the finger
# 46                                    What should be poured on the 9 inch pie plate  ...                                    zucchini
# 47                    How do you whisk the heavy cream and eggs from the large bowl  ...                                beat lightly
# 48                           How many actions does it take to process the olive oil  ...                                   two steps
# 49                                             Where should you mix the egg mixture  ...                the middle of the playground
#
# [50 rows x 3 columns]

# %%
1,4,7,14,17,21,24,30,31,37,38,47,49, 52, 85, 90, 93, 99
7, 14, 17，35, 51, 55, 66, 89

# %%
df_res.tail(50)
# Out:
#                                                                                ques  ...                           pred
# 50                                     How do you bake the pie crust for 40 minutes  ...                  `` creeper ''
# 51                          For how long do you bake the pie crust in the warm oven  ...                50 - 55 minutes
# 52                Where do you heat the olive oil and butter until the butter melts  ...               large frying pan
# 53                 For how long do you saute the onion until translucent and golden  ...                  3 / 4 tsp oil
# 54                                                             What's in the cookie  ...                    heavy cream
# 55                               Where do you whisk the heavy cream , eggs together  ...                    medium bowl
# 56           To what extent do you heat the olive oil and butter in a large skillet  ...            1 / 2 cup provolone
# 57                                                     Where do you drain the bacon  ...            the digestive tract
# 58                                        What should be pressed to the baking dish  ...                  a gps tracker
# 59                              How many actions does it take to process the butter  ...                    three steps
# 60                                                       How do you prick the dough  ...     prick the end of the knife
# 61                                                        What's in the egg mixture  ...                       egg loin
# 62  Whisking the heavy cream , eggs in a large bowl and pricking the dough with ...  ...                    heavy cream
# 63                                             What should be removed from the oven  ...                    heavy cream
# 64                  Removing the tart and mixing the egg mixture, which comes first  ...            1 / 2 cup provolone
# 65                                                 How many small skillets are used  ...                            two
# 66                                                  Where should you add the onions  ...        the middle of the plate
# 67                                                   How do you mix the egg mixture  ...                 `` throwing ''
# 68                                      Where should you season the salt and pepper  ...        according to preference
# 69                                                From where do you remove the tart  ...                       the peel
# 70                     Where was the pie crust before it was baked in the warm oven  ...            1 / 2 cup provolone
# 71  Where do you stir the reserved bacon , the caramelized onions , and 1/2 cup ...  ...            1 / 2 cup provolone
# 72                              Where do you sprinkle the remaining pecorino cheese  ...                  the packaging
# 73                                        What should be drained in the paper towel  ...            1 / 2 cup provolone
# 74                                                            What should be mashed  ...                       potatoes
# 75                                                      Where do you pour it evenly  ...            1 / 2 cup provolone
# 76                                  How do you knead the flour mixture on the board  ...                 `` throwing ''
# 77  Draining the bacon on a paper towel and filling with pie weights , rice , or...  ...            1 / 2 cup provolone
# 78                   Where should you whisk the heavy cream and eggs with the whisk  ...   the middle of the playground
# 79                                  Where should you bake the dough and pie weights  ...   the middle of the playground
# 80                          How do you whisk the heavy cream , eggs in a large bowl  ...                   beat lightly
# 81                                        What should be baked in the aluminum foil  ...                pan de mallorca
# 82                                                  How did you get the egg mixture  ...          the addition of cream
# 83                                                 What should be baked in the oven  ...            1 / 2 cup provolone
# 84                                                Where do you store the small ball  ...             one or two fingers
# 85                       How do you cook pasta in large salted pot of boiling water  ...           `` brooklyn '' pasta
# 86                              Where was the pasta before it was drained the pasta  ...               in the caribbean
# 87  Reserving 1/2 cup of the cooking water and draining the cooking water, which...  ...                      ink pasta
# 88  Combining about 1 1/2 teaspoons spice blend on a small dish and putting the ...  ...                    spice blend
# 89                  Where do you melt 4 tablespoons of butter over medium high heat  ...             in a large skillet
# 90                                                            What should be served  ...                         shrimp
# 91                           Where was the pasta before it was added to the skillet  ...         in the digestive tract
# 92                                                       How many skillets are used  ...                a large skillet
# 93                                      Where should you add the garlic and shrimps  ...             in a large skillet
# 94                                            What should be mixed with the spatula  ...                     white wine
# 95                      How do you cook pasta according to pasta package directions  ...             in a large skillet
# 96                             How do you mix the shrimp, pasta, butter and parsley  ...         cook shrimp until pink
# 97                                What's in the pasta with tomato garlic and shrimp  ...                     white wine
# 98  Reserving 1/2 cup of the cooking water and adding the garlic and shrimps, wh...  ...                 2 large onions
# 99                             Where should you add the shrimps, butter and parsley  ...                    the skillet
#
# [50 rows x 3 columns]
